# %%
# !sudo apt-get update -y
# !sudo apt-get install python3.8
# !python --version
# !sudo apt-get install python3-pip
# !python -m pip install --upgrade pip
# !ln -sf /usr/bin/python3.8 /usr/bin/python3
# !python --version
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:4 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Hit:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Get:7 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Hit:8 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Get:9 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [2,863 kB]
# Hit:10 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Get:11 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1,369 kB]
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Get:13 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1,070 kB]
# Get:14 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [37.5 kB]
# Get:15 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [2,523 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3,346 kB]
# Hit:17 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [2,671 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [40.3 kB]
# Fetched 14.3 MB in 3s (4,878 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3.8 is already the newest version (3.8.10-0ubuntu1~20.04.8).
# python3.8 set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.
# Python 3.10.12
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   python-pip-whl python3-setuptools python3-wheel
# Suggested packages:
#   python-setuptools-doc
# The following NEW packages will be installed:
#   python-pip-whl python3-pip python3-setuptools python3-wheel
# 0 upgraded, 4 newly installed, 0 to remove and 15 not upgraded.
# Need to get 2,389 kB of archives.
# After this operation, 4,933 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python-pip-whl all 20.0.2-5ubuntu1.9 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-setuptools all 45.2.0-1ubuntu0.1 [330 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-wheel all 0.34.2-1ubuntu0.1 [23.9 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-pip all 20.0.2-5ubuntu1.9 [231 kB]
# Fetched 2,389 kB in 1s (2,844 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 4.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package python-pip-whl.
# (Reading database ... 123105 files and directories currently installed.)
# Preparing to unpack .../python-pip-whl_20.0.2-5ubuntu1.9_all.deb ...
# Unpacking python-pip-whl (20.0.2-5ubuntu1.9) ...
# Selecting previously unselected package python3-setuptools.
# Preparing to unpack .../python3-setuptools_45.2.0-1ubuntu0.1_all.deb ...
# Unpacking python3-setuptools (45.2.0-1ubuntu0.1) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../python3-wheel_0.34.2-1ubuntu0.1_all.deb ...
# Unpacking python3-wheel (0.34.2-1ubuntu0.1) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../python3-pip_20.0.2-5ubuntu1.9_all.deb ...
# Unpacking python3-pip (20.0.2-5ubuntu1.9) ...
# Setting up python3-setuptools (45.2.0-1ubuntu0.1) ...
# Setting up python3-wheel (0.34.2-1ubuntu0.1) ...
# Setting up python-pip-whl (20.0.2-5ubuntu1.9) ...
# Setting up python3-pip (20.0.2-5ubuntu1.9) ...
# Processing triggers for man-db (2.9.1-1) ...
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (23.1.2)
# Python 3.8.10

# %%
# %rm -R opentf/
# !git clone --recursive https://github.com/Fani-Lab/opentf
# %cd opentf
# !pip install virtualenv
# !virtualenv opentf
# !opentf/bin/pip install -r requirements.txt
# !opentf/bin/pip install ipykernel
import sys
sys.path.append("opentf/lib/python3.8/site-packages")
# %cd src/
# Out:
# rm: cannot remove 'opentf/': No such file or directory
# Cloning into 'opentf'...
# remote: Enumerating objects: 6612, done.
# remote: Counting objects: 100% (1593/1593), done.
# remote: Compressing objects: 100% (1102/1102), done.
# remote: Total 6612 (delta 556), reused 1436 (delta 479), pack-reused 5019
# Receiving objects: 100% (6612/6612), 110.81 MiB | 19.12 MiB/s, done.
# Resolving deltas: 100% (2681/2681), done.
# Updating files: 100% (1745/1745), done.
# Submodule 'src/Adila' (https://github.com/fani-lab/Adila.git) registered for path 'src/Adila'
# Cloning into '/content/opentf/src/Adila'...
# remote: Enumerating objects: 773, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 773 (delta 62), reused 28 (delta 13), pack-reused 668
# Receiving objects: 100% (773/773), 16.68 MiB | 14.88 MiB/s, done.
# Resolving deltas: 100% (346/346), done.
# Submodule path 'src/Adila': checked out 'ed7b732ab165177f652a49d6fbf1fa033cfb008e'
# /content/opentf
# Collecting virtualenv
#   Downloading virtualenv-20.23.1-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 8.5 MB/s
# Collecting platformdirs<4,>=3.5.1
#   Downloading platformdirs-3.8.1-py3-none-any.whl (16 kB)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      |████████████████████████████████| 468 kB 59.5 MB/s
# Collecting filelock<4,>=3.12
#   Downloading filelock-3.12.2-py3-none-any.whl (10 kB)
# Installing collected packages: platformdirs, distlib, filelock, virtualenv
# Successfully installed distlib-0.3.6 filelock-3.12.2 platformdirs-3.8.1 virtualenv-20.23.1
# created virtual environment CPython3.8.10.final.0-64 in 1421ms
#   creator CPython3Posix(dest=/content/opentf/opentf, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==23.1.2, setuptools==67.8.0, wheel==0.40.0
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator
# Collecting torch>=1.9.0 (from -r requirements.txt (line 1))
#   Downloading torch-2.0.1-cp38-cp38-manylinux1_x86_64.whl (619.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 1.2 MB/s eta 0:00:00
# Collecting scipy==1.9.3 (from -r requirements.txt (line 2))
#   Downloading scipy-1.9.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 36.6 MB/s eta 0:00:00
# Collecting numpy==1.20.3 (from -r requirements.txt (line 3))
#   Downloading numpy-1.20.3-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 60.5 MB/s eta 0:00:00
# Collecting tqdm==4.60.0 (from -r requirements.txt (line 4))
#   Downloading tqdm-4.60.0-py2.py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.8/75.8 kB 8.8 MB/s eta 0:00:00
# Collecting PyYAML==5.4 (from -r requirements.txt (line 5))
#   Downloading PyYAML-5.4-cp38-cp38-manylinux1_x86_64.whl (662 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.2/662.2 kB 43.4 MB/s eta 0:00:00
# Collecting scikit_learn==0.24.2 (from -r requirements.txt (line 6))
#   Downloading scikit_learn-0.24.2-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 40.5 MB/s eta 0:00:00
# Collecting pandas==1.3.3 (from -r requirements.txt (line 7))
#   Downloading pandas-1.3.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 64.8 MB/s eta 0:00:00
# Collecting gensim==3.8.3 (from -r requirements.txt (line 8))
#   Downloading gensim-3.8.3-cp38-cp38-manylinux1_x86_64.whl (24.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 64.6 MB/s eta 0:00:00
# Collecting pytrec-eval-terrier==0.5.2 (from -r requirements.txt (line 9))
#   Downloading pytrec_eval_terrier-0.5.2-cp38-cp38-manylinux2010_x86_64.whl (287 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.4/287.4 kB 29.5 MB/s eta 0:00:00
# Collecting matplotlib==3.4.2 (from -r requirements.txt (line 10))
#   Downloading matplotlib-3.4.2-cp38-cp38-manylinux1_x86_64.whl (10.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 103.6 MB/s eta 0:00:00
# Collecting OpenNMT-py==2.2.0 (from -r requirements.txt (line 11))
#   Downloading OpenNMT_py-2.2.0-py3-none-any.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.8/216.8 kB 929.6 kB/s eta 0:00:00
# Collecting reranking==0.3.6 (from -r requirements.txt (line 12))
#   Downloading reranking-0.3.6-py3-none-any.whl (17 kB)
# Collecting python-dateutil==2.8.2 (from -r requirements.txt (line 14))
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 24.0 MB/s eta 0:00:00
# Collecting joblib>=0.11 (from scikit_learn==0.24.2->-r requirements.txt (line 6))
#   Downloading joblib-1.3.1-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 36.4 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0 (from scikit_learn==0.24.2->-r requirements.txt (line 6))
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting pytz>=2017.3 (from pandas==1.3.3->-r requirements.txt (line 7))
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.3/502.3 kB 34.8 MB/s eta 0:00:00
# Collecting six>=1.5.0 (from gensim==3.8.3->-r requirements.txt (line 8))
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting smart-open>=1.8.1 (from gensim==3.8.3->-r requirements.txt (line 8))
#   Downloading smart_open-6.3.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 6.3 MB/s eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib==3.4.2->-r requirements.txt (line 10))
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib==3.4.2->-r requirements.txt (line 10))
#   Downloading kiwisolver-1.4.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 73.5 MB/s eta 0:00:00
# Collecting pillow>=6.2.0 (from matplotlib==3.4.2->-r requirements.txt (line 10))
#   Downloading Pillow-10.0.0-cp38-cp38-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 93.3 MB/s eta 0:00:00
# Collecting pyparsing>=2.2.1 (from matplotlib==3.4.2->-r requirements.txt (line 10))
#   Downloading pyparsing-3.1.0-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 kB 14.2 MB/s eta 0:00:00
# Collecting torchtext==0.5.0 (from OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading torchtext-0.5.0-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 9.3 MB/s eta 0:00:00
# Collecting configargparse (from OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading ConfigArgParse-1.5.5-py3-none-any.whl (25 kB)
# Collecting tensorboard>=2.3 (from OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 96.3 MB/s eta 0:00:00
# Collecting flask (from OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading Flask-2.3.2-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 13.1 MB/s eta 0:00:00
# Collecting waitress (from OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading waitress-2.1.2-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 8.0 MB/s eta 0:00:00
# Collecting pyonmttok<2,>=1.23 (from OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading pyonmttok-1.37.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 68.3 MB/s eta 0:00:00
# Collecting requests (from torchtext==0.5.0->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 8.4 MB/s eta 0:00:00
# Collecting sentencepiece (from torchtext==0.5.0->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading sentencepiece-0.1.99-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 69.4 MB/s eta 0:00:00
# Collecting filelock (from torch>=1.9.0->-r requirements.txt (line 1))
#   Using cached filelock-3.12.2-py3-none-any.whl (10 kB)
# Collecting typing-extensions (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting sympy (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 95.3 MB/s eta 0:00:00
# Collecting networkx (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 89.9 MB/s eta 0:00:00
# Collecting jinja2 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 16.0 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 81.1 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 67.5 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 106.6 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.4 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 1.9 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 5.2 MB/s eta 0:00:00
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 14.7 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 9.0 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 2.3 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu11==2.14.3 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 3.3 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 12.5 MB/s eta 0:00:00
# Collecting triton==2.0.0 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading triton-2.0.0-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.2/63.2 MB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in ./opentf/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.9.0->-r requirements.txt (line 1)) (67.8.0)
# Requirement already satisfied: wheel in ./opentf/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.9.0->-r requirements.txt (line 1)) (0.40.0)
# Collecting cmake (from triton==2.0.0->torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading cmake-3.26.4-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (24.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 39.8 MB/s eta 0:00:00
# Collecting lit (from triton==2.0.0->torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading lit-16.0.6.tar.gz (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.7/153.7 kB 14.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting absl-py>=0.4 (from tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 14.2 MB/s eta 0:00:00
# Collecting grpcio>=1.48.2 (from tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading grpcio-1.56.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 85.6 MB/s eta 0:00:00
# Collecting google-auth<3,>=1.6.3 (from tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading google_auth-2.21.0-py2.py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.1/182.1 kB 22.3 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8 (from tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading Markdown-3.4.3-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 kB 11.5 MB/s eta 0:00:00
# Collecting protobuf>=3.19.6 (from tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 28.5 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading tensorboard_data_server-0.7.1-py3-none-manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 57.6 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1 (from tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading Werkzeug-2.3.6-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 23.5 MB/s eta 0:00:00
# Collecting itsdangerous>=2.1.2 (from flask->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting click>=8.1.3 (from flask->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading click-8.1.4-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 12.1 MB/s eta 0:00:00
# Collecting blinker>=1.6.2 (from flask->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Collecting importlib-metadata>=3.6.0 (from flask->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading importlib_metadata-6.7.0-py3-none-any.whl (22 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading MarkupSafe-2.1.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting mpmath>=0.19 (from sympy->torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 41.8 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 19.7 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting urllib3<2.0 (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 13.4 MB/s eta 0:00:00
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting zipp>=0.5 (from importlib-metadata>=3.6.0->flask->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Collecting charset-normalizer<4,>=2 (from requests->torchtext==0.5.0->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading charset_normalizer-3.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.9/195.9 kB 19.4 MB/s eta 0:00:00
# Collecting idna<4,>=2.5 (from requests->torchtext==0.5.0->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 8.2 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17 (from requests->torchtext==0.5.0->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading certifi-2023.5.7-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.0/157.0 kB 18.6 MB/s eta 0:00:00
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 9.6 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 13.8 MB/s eta 0:00:00
# Building wheels for collected packages: lit
#   Building wheel for lit (pyproject.toml) ... done
#   Created wheel for lit: filename=lit-16.0.6-py3-none-any.whl size=93582 sha256=8846ebcbd8b7d88a50e679f4b90090fea3c681ee87848d884bd0348054771ccb
#   Stored in directory: /root/.cache/pip/wheels/05/ab/f1/0102fea49a41c753f0e79a1a4012417d5d7ef0f93224694472
# Successfully built lit
# Installing collected packages: sentencepiece, pytz, mpmath, lit, cmake, zipp, waitress, urllib3, typing-extensions, tqdm, threadpoolctl, tensorboard-data-server, sympy, smart-open, six, reranking, PyYAML, pytrec-eval-terrier, pyparsing, pyonmttok, pyasn1, protobuf, pillow, oauthlib, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, numpy, networkx, MarkupSafe, kiwisolver, joblib, itsdangerous, idna, grpcio, filelock, cycler, configargparse, click, charset-normalizer, certifi, cachetools, blinker, absl-py, werkzeug, scipy, rsa, requests, python-dateutil, pyasn1-modules, nvidia-cusolver-cu11, nvidia-cudnn-cu11, jinja2, importlib-metadata, scikit_learn, requests-oauthlib, pandas, matplotlib, markdown, google-auth, gensim, flask, google-auth-oauthlib, tensorboard, triton, torch, torchtext, OpenNMT-py
# Successfully installed MarkupSafe-2.1.3 OpenNMT-py-2.2.0 PyYAML-5.4 absl-py-1.4.0 blinker-1.6.2 cachetools-5.3.1 certifi-2023.5.7 charset-normalizer-3.1.0 click-8.1.4 cmake-3.26.4 configargparse-1.5.5 cycler-0.11.0 filelock-3.12.2 flask-2.3.2 gensim-3.8.3 google-auth-2.21.0 google-auth-oauthlib-1.0.0 grpcio-1.56.0 idna-3.4 importlib-metadata-6.7.0 itsdangerous-2.1.2 jinja2-3.1.2 joblib-1.3.1 kiwisolver-1.4.4 lit-16.0.6 markdown-3.4.3 matplotlib-3.4.2 mpmath-1.3.0 networkx-3.1 numpy-1.20.3 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 oauthlib-3.2.2 pandas-1.3.3 pillow-10.0.0 protobuf-4.23.4 pyasn1-0.5.0 pyasn1-modules-0.3.0 pyonmttok-1.37.1 pyparsing-3.1.0 python-dateutil-2.8.2 pytrec-eval-terrier-0.5.2 pytz-2023.3 requests-2.31.0 requests-oauthlib-1.3.1 reranking-0.3.6 rsa-4.9 scikit_learn-0.24.2 scipy-1.9.3 sentencepiece-0.1.99 six-1.16.0 smart-open-6.3.0 sympy-1.12 tensorboard-2.13.0 tensorboard-data-server-0.7.1 threadpoolctl-3.1.0 torch-2.0.1 torchtext-0.5.0 tqdm-4.60.0 triton-2.0.0 typing-extensions-4.7.1 urllib3-1.26.16 waitress-2.1.2 werkzeug-2.3.6 zipp-3.15.0
# Collecting ipykernel
#   Downloading ipykernel-6.24.0-py3-none-any.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.8/152.8 kB 5.4 MB/s eta 0:00:00
# Collecting comm>=0.1.1 (from ipykernel)
#   Downloading comm-0.1.3-py3-none-any.whl (6.6 kB)
# Collecting debugpy>=1.6.5 (from ipykernel)
#   Downloading debugpy-1.6.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 32.4 MB/s eta 0:00:00
# Collecting ipython>=7.23.1 (from ipykernel)
#   Downloading ipython-8.12.2-py3-none-any.whl (797 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.8/797.8 kB 60.3 MB/s eta 0:00:00
# Collecting jupyter-client>=6.1.12 (from ipykernel)
#   Downloading jupyter_client-8.3.0-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 13.8 MB/s eta 0:00:00
# Collecting jupyter-core!=5.0.*,>=4.12 (from ipykernel)
#   Downloading jupyter_core-5.3.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.7/93.7 kB 12.6 MB/s eta 0:00:00
# Collecting matplotlib-inline>=0.1 (from ipykernel)
#   Downloading matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# Collecting nest-asyncio (from ipykernel)
#   Downloading nest_asyncio-1.5.6-py3-none-any.whl (5.2 kB)
# Collecting packaging (from ipykernel)
#   Downloading packaging-23.1-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 5.2 MB/s eta 0:00:00
# Collecting psutil (from ipykernel)
#   Downloading psutil-5.9.5-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (282 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.1/282.1 kB 29.0 MB/s eta 0:00:00
# Collecting pyzmq>=20 (from ipykernel)
#   Downloading pyzmq-25.1.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 54.9 MB/s eta 0:00:00
# Collecting tornado>=6.1 (from ipykernel)
#   Downloading tornado-6.3.2-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (426 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.9/426.9 kB 33.4 MB/s eta 0:00:00
# Collecting traitlets>=5.4.0 (from ipykernel)
#   Downloading traitlets-5.9.0-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.4/117.4 kB 13.7 MB/s eta 0:00:00
# Collecting backcall (from ipython>=7.23.1->ipykernel)
#   Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting decorator (from ipython>=7.23.1->ipykernel)
#   Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel)
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 62.2 MB/s eta 0:00:00
# Collecting pickleshare (from ipython>=7.23.1->ipykernel)
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 (from ipython>=7.23.1->ipykernel)
#   Downloading prompt_toolkit-3.0.39-py3-none-any.whl (385 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.2/385.2 kB 26.2 MB/s eta 0:00:00
# Collecting pygments>=2.4.0 (from ipython>=7.23.1->ipykernel)
#   Downloading Pygments-2.15.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 36.5 MB/s eta 0:00:00
# Collecting stack-data (from ipython>=7.23.1->ipykernel)
#   Downloading stack_data-0.6.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: typing-extensions in ./opentf/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel) (4.7.1)
# Collecting pexpect>4.3 (from ipython>=7.23.1->ipykernel)
#   Downloading pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=4.8.3 in ./opentf/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel) (6.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./opentf/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Collecting platformdirs>=2.5 (from jupyter-core!=5.0.*,>=4.12->ipykernel)
#   Using cached platformdirs-3.8.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: zipp>=0.5 in ./opentf/lib/python3.8/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel) (3.15.0)
# Collecting parso<0.9.0,>=0.8.0 (from jedi>=0.16->ipython>=7.23.1->ipykernel)
#   Downloading parso-0.8.3-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 10.7 MB/s eta 0:00:00
# Collecting ptyprocess>=0.5 (from pexpect>4.3->ipython>=7.23.1->ipykernel)
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting wcwidth (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel)
#   Downloading wcwidth-0.2.6-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: six>=1.5 in ./opentf/lib/python3.8/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Collecting executing>=1.2.0 (from stack-data->ipython>=7.23.1->ipykernel)
#   Downloading executing-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting asttokens>=2.1.0 (from stack-data->ipython>=7.23.1->ipykernel)
#   Downloading asttokens-2.2.1-py2.py3-none-any.whl (26 kB)
# Collecting pure-eval (from stack-data->ipython>=7.23.1->ipykernel)
#   Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Installing collected packages: wcwidth, pure-eval, ptyprocess, pickleshare, executing, backcall, traitlets, tornado, pyzmq, pygments, psutil, prompt-toolkit, platformdirs, pexpect, parso, packaging, nest-asyncio, decorator, debugpy, asttokens, stack-data, matplotlib-inline, jupyter-core, jedi, comm, jupyter-client, ipython, ipykernel
# Successfully installed asttokens-2.2.1 backcall-0.2.0 comm-0.1.3 debugpy-1.6.7 decorator-5.1.1 executing-1.2.0 ipykernel-6.24.0 ipython-8.12.2 jedi-0.18.2 jupyter-client-8.3.0 jupyter-core-5.3.1 matplotlib-inline-0.1.6 nest-asyncio-1.5.6 packaging-23.1 parso-0.8.3 pexpect-4.8.0 pickleshare-0.7.5 platformdirs-3.8.1 prompt-toolkit-3.0.39 psutil-5.9.5 ptyprocess-0.7.0 pure-eval-0.2.2 pygments-2.15.1 pyzmq-25.1.0 stack-data-0.6.2 tornado-6.3.2 traitlets-5.9.0 wcwidth-0.2.6
# /content/opentf/src

# %%
#!apt-get install --assume-yes p7zip-full
#!wget -O ../data/raw/imdb/name.basics.tsv.gz https://datasets.imdbws.com/name.basics.tsv.gz
#!wget -O ../data/raw/imdb/title.basics.tsv.gz https://datasets.imdbws.com/title.basics.tsv.gz
#!wget -O ../data/raw/imdb/title.principals.tsv.gz https://datasets.imdbws.com/title.principals.tsv.gz
#!7z e ../data/raw/imdb/name.basics.tsv.gz -o../data/raw/imdb/
#!mv ../data/raw/imdb/data.tsv ../data/raw/imdb/name.basics.tsv
#!7z e ../data/raw/imdb/title.basics.tsv.gz -o../data/raw/imdb/
#!mv ../data/raw/imdb/data.tsv ../data/raw/imdb/title.basics.tsv
#!7z e ../data/raw/imdb/title.principals.tsv.gz -o../data/raw/imdb/
#!mv ../data/raw/imdb/data.tsv ../data/raw/imdb/title.principals.tsv

# %%
#!apt-get install --assume-yes p7zip-full
#!wget -O ../data/raw/dblp/dblp.v12.7z https://originalstatic.aminer.cn/misc/dblp.v12.7z
#!7z e ../data/raw/dblp/dblp.v12.7z -o../data/raw/dblp/

# %%
# !cat param.py
# Out:
# import random
# import torch
# import numpy as np
#
# random.seed(0)
# torch.manual_seed(0)
# torch.cuda.manual_seed_all(0)
#
# np.random.seed(0)
#
# settings = {
#     'model':{
#         'baseline': {
#             'random': {
#                 'b': 128
#             },
#             'fnn':{
#                 'l': [128],  # list of number of nodes in each layer
#                 'lr': 0.1,  # learning rate
#                 'b': 128,  # batch size
#                 'e': 20,  # epoch
#                 'nns': 3,  # number of negative samples
#                 'ns': 'unigram_b',  # 'uniform', 'unigram', 'unigram_b'
#             },
#             'bnn':{
#                 'l': [128],  # list of number of nodes in each layer
#                 'lr': 0.1,  # learning rate
#                 'b': 128,  # batch size
#                 'e': 20,  # epoch
#                 'nns': 3,  # number of negative samples
#                 'ns': 'unigram_b',  # 'uniform', 'unigram', 'unigram_b'
#                 's': 1  # # sample_elbo for bnn
#             },
#             'nmt': {
#                 'base_config': './mdl/nmt_config.yaml'
#             },
#             'caser': {},
#             'rrn': {
#                 'with_zero': True
#             },
#             'emb':{
#                 'd': 100,# embedding dimension
#                 'e': 100,# epoch
#                 'dm': 1,# training algorithm. 1: distributed memory (PV-DM), 0: distributed bag of words (PV-DBOW)
#                 'w': 1 #cooccurrence window
#             }
#         },
#         'cmd': ['train', 'test', 'eval', 'fair'],  # 'train', 'test', 'eval', 'plot', 'agg', 'adila'
#         'nfolds': 5,
#         'train_test_split': 0.85,
#         'step_ahead': 2,#for now, it means that whatever are in the last [step_ahead] time interval will be the test set!
#     },
#     'data':{
#         'domain': {
#             'dblp':{},
#             'uspt':{},
#             'imdb':{},
#         },
#         'location_type': 'country', #should be one of 'city', 'state', 'country' and represents the location of members in teams (not the location of teams)
#         'filter': {
#             'min_nteam': 75,
#             'min_team_size': 3,
#         },
#         'parallel': 1,
#         'ncore': 0,# <= 0 for all
#         'bucket_size': 500
#     },
#     'fair': {'np_ratio': None,
#               'fairness': ['det_greedy',],
#               'k_max': None,
#               'fairness_metrics': {'ndkl'},
#               'utility_metrics': {'map_cut_2,5,10'},
#               'eq_op': False,
#               'mode': 0,
#               'core': -1,
#               'attribute': ['gender', 'popularity']},
# }

# %%
# !rm -R ../data/preprocessed/dblp/toy.dblp.v12.json/
# !rm -R ../data/preprocessed/imdb/toy.title.basics.tsv/
# !rm -R ../data/preprocessed/uspt/toy.patent.tsv/

# %%
# %ls
# Out:
# Adila/  computecanada.sh  main.py  misc/     __pycache__/
# cmn/    eval/             mdl/     param.py  readme.md

# %%
# !../opentf/bin/python3 main.py -data ../data/raw/dblp/toy.dblp.v12.json -domain dblp -model fnn bnn -fairness det_greedy -attribute popularity
# Out:
# Loading sparse matrices from ./../data/preprocessed/dblp/toy.dblp.v12.json/teamsvecs.pkl ...
# Loading indexes pickle from ./../data/preprocessed/dblp/toy.dblp.v12.json/indexes.pkl ...
# It took 0.00016021728515625 seconds to load from the pickles.
# It took 0.0006883144378662109 seconds to load the sparse matrices.
# Running for (dataset, model): (dblp, fnn) ...
# Fold 0/4, Epoch 0/19, Minibatch 0/0, Phase train, Running Loss train 63.13008117675781, Time 0.025361299514770508, Overall 0.029630184173583984
# Fold 0/4, Epoch 0/19, Running Loss train 3.1565040588378905, Time 0.025575637817382812, Overall 0.029843568801879883
# Fold 0/4, Epoch 0/19, Minibatch 0/0, Phase valid, Running Loss valid 13.52873706817627, Time 0.031148433685302734, Overall 0.035416603088378906
# Fold 0/4, Epoch 0/19, Running Loss valid 2.2547895113627114, Time 0.03132438659667969, Overall 0.035592079162597656
# Fold 0/4, Epoch 1/19, Minibatch 0/0, Phase train, Running Loss train 56.222312927246094, Time 0.05067157745361328, Overall 0.05493974685668945
# Fold 0/4, Epoch 1/19, Running Loss train 2.8111156463623046, Time 0.05083441734313965, Overall 0.05510210990905762
# Fold 0/4, Epoch 1/19, Minibatch 0/0, Phase valid, Running Loss valid 15.035648345947266, Time 0.05637001991271973, Overall 0.060638427734375
# Fold 0/4, Epoch 1/19, Running Loss valid 2.505941390991211, Time 0.05662679672241211, Overall 0.06089425086975098
# Fold 0/4, Epoch 2/19, Minibatch 0/0, Phase train, Running Loss train 43.779178619384766, Time 0.07443118095397949, Overall 0.07869935035705566
# Fold 0/4, Epoch 2/19, Running Loss train 2.188958930969238, Time 0.07458806037902832, Overall 0.07885575294494629
# Fold 0/4, Epoch 2/19, Minibatch 0/0, Phase valid, Running Loss valid 19.25861930847168, Time 0.07983994483947754, Overall 0.08410787582397461
# Fold 0/4, Epoch 2/19, Running Loss valid 3.20976988474528, Time 0.07997989654541016, Overall 0.08424735069274902
# Fold 0/4, Epoch 3/19, Minibatch 0/0, Phase train, Running Loss train 27.47565269470215, Time 0.09722232818603516, Overall 0.10149073600769043
# Fold 0/4, Epoch 3/19, Running Loss train 1.3737826347351074, Time 0.09737086296081543, Overall 0.1016383171081543
# Fold 0/4, Epoch 3/19, Minibatch 0/0, Phase valid, Running Loss valid 22.26664924621582, Time 0.10248970985412598, Overall 0.10675764083862305
# Fold 0/4, Epoch 3/19, Running Loss valid 3.7111082077026367, Time 0.1026463508605957, Overall 0.10691380500793457
# Fold 0/4, Epoch 4/19, Minibatch 0/0, Phase train, Running Loss train 22.901660919189453, Time 0.11985111236572266, Overall 0.12411952018737793
# Fold 0/4, Epoch 4/19, Running Loss train 1.1450830459594727, Time 0.11999392509460449, Overall 0.12426161766052246
# Fold 0/4, Epoch 4/19, Minibatch 0/0, Phase valid, Running Loss valid 23.263227462768555, Time 0.12537074089050293, Overall 0.129638671875
# Fold 0/4, Epoch 4/19, Running Loss valid 3.8772045771280923, Time 0.12555742263793945, Overall 0.12982487678527832
# Fold 0/4, Epoch 5/19, Minibatch 0/0, Phase train, Running Loss train 26.792465209960938, Time 0.14312458038330078, Overall 0.14739274978637695
# Fold 0/4, Epoch 5/19, Running Loss train 1.339623260498047, Time 0.14327716827392578, Overall 0.14754438400268555
# Fold 0/4, Epoch 5/19, Minibatch 0/0, Phase valid, Running Loss valid 26.65178680419922, Time 0.1485433578491211, Overall 0.15281128883361816
# Fold 0/4, Epoch 5/19, Running Loss valid 4.441964467366536, Time 0.1487128734588623, Overall 0.15298008918762207
# Fold 0/4, Epoch 6/19, Minibatch 0/0, Phase train, Running Loss train 16.378023147583008, Time 0.16630792617797852, Overall 0.1705760955810547
# Fold 0/4, Epoch 6/19, Running Loss train 0.8189011573791504, Time 0.16648364067077637, Overall 0.17075109481811523
# Fold 0/4, Epoch 6/19, Minibatch 0/0, Phase valid, Running Loss valid 29.159194946289062, Time 0.171630859375, Overall 0.17589950561523438
# Fold 0/4, Epoch 6/19, Running Loss valid 4.859865824381511, Time 0.1717672348022461, Overall 0.17603445053100586
# Fold 0/4, Epoch 7/19, Minibatch 0/0, Phase train, Running Loss train 20.885316848754883, Time 0.18952679634094238, Overall 0.19379472732543945
# Fold 0/4, Epoch 7/19, Running Loss train 1.0442658424377442, Time 0.18967580795288086, Overall 0.19394278526306152
# Fold 0/4, Epoch 7/19, Minibatch 0/0, Phase valid, Running Loss valid 30.91985321044922, Time 0.1948990821838379, Overall 0.19916701316833496
# Fold 0/4, Epoch 7/19, Running Loss valid 5.153308868408203, Time 0.1950540542602539, Overall 0.19932079315185547
# Fold 0/4, Epoch 8/19, Minibatch 0/0, Phase train, Running Loss train 21.161884307861328, Time 0.21448278427124023, Overall 0.2187519073486328
# Fold 0/4, Epoch 8/19, Running Loss train 1.0580942153930664, Time 0.21464252471923828, Overall 0.21890997886657715
# Fold 0/4, Epoch 8/19, Minibatch 0/0, Phase valid, Running Loss valid 29.88347816467285, Time 0.21988129615783691, Overall 0.22414898872375488
# Fold 0/4, Epoch 8/19, Running Loss valid 4.980579694112142, Time 0.22002077102661133, Overall 0.2242882251739502
# Fold 0/4, Epoch 9/19, Minibatch 0/0, Phase train, Running Loss train 20.808292388916016, Time 0.23706293106079102, Overall 0.2413311004638672
# Fold 0/4, Epoch 9/19, Running Loss train 1.0404146194458008, Time 0.2372112274169922, Overall 0.24147844314575195
# Fold 0/4, Epoch 9/19, Minibatch 0/0, Phase valid, Running Loss valid 28.788164138793945, Time 0.24247503280639648, Overall 0.24674320220947266
# Fold 0/4, Epoch 9/19, Running Loss valid 4.798027356465657, Time 0.24262690544128418, Overall 0.24689459800720215
# Fold 0/4, Epoch 10/19, Minibatch 0/0, Phase train, Running Loss train 9.657134056091309, Time 0.2595996856689453, Overall 0.2638685703277588
# Fold 0/4, Epoch 10/19, Running Loss train 0.48285670280456544, Time 0.2597672939300537, Overall 0.2640345096588135
# Fold 0/4, Epoch 10/19, Minibatch 0/0, Phase valid, Running Loss valid 37.51179122924805, Time 0.26517772674560547, Overall 0.26944613456726074
# Fold 0/4, Epoch 10/19, Running Loss valid 6.251965204874675, Time 0.265350341796875, Overall 0.26961803436279297
# Fold 0/4, Epoch 11/19, Minibatch 0/0, Phase train, Running Loss train 18.11969757080078, Time 0.2824103832244873, Overall 0.2866783142089844
# Fold 0/4, Epoch 11/19, Running Loss train 0.9059848785400391, Time 0.2825605869293213, Overall 0.28682780265808105
# Fold 0/4, Epoch 11/19, Minibatch 0/0, Phase valid, Running Loss valid 28.579748153686523, Time 0.28781771659851074, Overall 0.2920856475830078
# Fold 0/4, Epoch 11/19, Running Loss valid 4.763291358947754, Time 0.2879812717437744, Overall 0.2922487258911133
# Epoch 00012: reducing learning rate of group 0 to 5.0000e-02.
# Fold 0/4, Epoch 12/19, Minibatch 0/0, Phase train, Running Loss train 14.789693832397461, Time 0.305894136428833, Overall 0.31017136573791504
# Fold 0/4, Epoch 12/19, Running Loss train 0.7394846916198731, Time 0.3061835765838623, Overall 0.31045103073120117
# Fold 0/4, Epoch 12/19, Minibatch 0/0, Phase valid, Running Loss valid 29.62596893310547, Time 0.31171655654907227, Overall 0.31598520278930664
# Fold 0/4, Epoch 12/19, Running Loss valid 4.937661488850911, Time 0.31189537048339844, Overall 0.3161628246307373
# Fold 0/4, Epoch 13/19, Minibatch 0/0, Phase train, Running Loss train 17.07163429260254, Time 0.32913661003112793, Overall 0.3334050178527832
# Fold 0/4, Epoch 13/19, Running Loss train 0.853581714630127, Time 0.3293266296386719, Overall 0.33359360694885254
# Fold 0/4, Epoch 13/19, Minibatch 0/0, Phase valid, Running Loss valid 33.89955520629883, Time 0.334805965423584, Overall 0.33907389640808105
# Fold 0/4, Epoch 13/19, Running Loss valid 5.649925867716472, Time 0.33496689796447754, Overall 0.3392341136932373
# Fold 0/4, Epoch 14/19, Minibatch 0/0, Phase train, Running Loss train 11.593584060668945, Time 0.35358142852783203, Overall 0.3578498363494873
# Fold 0/4, Epoch 14/19, Running Loss train 0.5796792030334472, Time 0.3537619113922119, Overall 0.3580291271209717
# Fold 0/4, Epoch 14/19, Minibatch 0/0, Phase valid, Running Loss valid 31.612483978271484, Time 0.35933828353881836, Overall 0.36360621452331543
# Fold 0/4, Epoch 14/19, Running Loss valid 5.268747329711914, Time 0.35953688621520996, Overall 0.36380457878112793
# Fold 0/4, Epoch 15/19, Minibatch 0/0, Phase train, Running Loss train 19.137840270996094, Time 0.37720823287963867, Overall 0.38147640228271484
# Fold 0/4, Epoch 15/19, Running Loss train 0.9568920135498047, Time 0.3773539066314697, Overall 0.3816208839416504
# Fold 0/4, Epoch 15/19, Minibatch 0/0, Phase valid, Running Loss valid 36.15479278564453, Time 0.3828752040863037, Overall 0.3871431350708008
# Fold 0/4, Epoch 15/19, Running Loss valid 6.025798797607422, Time 0.38306188583374023, Overall 0.3873295783996582
# Fold 0/4, Epoch 16/19, Minibatch 0/0, Phase train, Running Loss train 17.870437622070312, Time 0.4011857509613037, Overall 0.405454158782959
# Fold 0/4, Epoch 16/19, Running Loss train 0.8935218811035156, Time 0.4013478755950928, Overall 0.40561485290527344
# Fold 0/4, Epoch 16/19, Minibatch 0/0, Phase valid, Running Loss valid 39.52485275268555, Time 0.4073505401611328, Overall 0.4116189479827881
# Fold 0/4, Epoch 16/19, Running Loss valid 6.587475458780925, Time 0.40758275985717773, Overall 0.4118499755859375
# Fold 0/4, Epoch 17/19, Minibatch 0/0, Phase train, Running Loss train 10.89444351196289, Time 0.42673277854919434, Overall 0.4310014247894287
# Fold 0/4, Epoch 17/19, Running Loss train 0.5447221755981445, Time 0.4268934726715088, Overall 0.43116068840026855
# Fold 0/4, Epoch 17/19, Minibatch 0/0, Phase valid, Running Loss valid 31.85984230041504, Time 0.43283653259277344, Overall 0.4371054172515869
# Fold 0/4, Epoch 17/19, Running Loss valid 5.30997371673584, Time 0.4330625534057617, Overall 0.4373302459716797
# Fold 0/4, Epoch 18/19, Minibatch 0/0, Phase train, Running Loss train 8.627363204956055, Time 0.4543118476867676, Overall 0.45858025550842285
# Fold 0/4, Epoch 18/19, Running Loss train 0.4313681602478027, Time 0.45448732376098633, Overall 0.4587545394897461
# Fold 0/4, Epoch 18/19, Minibatch 0/0, Phase valid, Running Loss valid 31.79159164428711, Time 0.45976972579956055, Overall 0.4640376567840576
# Fold 0/4, Epoch 18/19, Running Loss valid 5.298598607381185, Time 0.45991015434265137, Overall 0.46417808532714844
# Fold 0/4, Epoch 19/19, Minibatch 0/0, Phase train, Running Loss train 27.274261474609375, Time 0.4767954349517822, Overall 0.4810633659362793
# Fold 0/4, Epoch 19/19, Running Loss train 1.3637130737304688, Time 0.47695088386535645, Overall 0.4812183380126953
# Fold 0/4, Epoch 19/19, Minibatch 0/0, Phase valid, Running Loss valid 30.866363525390625, Time 0.4824402332305908, Overall 0.4867088794708252
# Fold 0/4, Epoch 19/19, Running Loss valid 5.1443939208984375, Time 0.4826056957244873, Overall 0.48687314987182617
# Fold 1/4, Epoch 0/19, Minibatch 0/0, Phase train, Running Loss train 63.451324462890625, Time 0.017365217208862305, Overall 0.5077195167541504
# Fold 1/4, Epoch 0/19, Running Loss train 3.0214916410900297, Time 0.017517566680908203, Overall 0.507871150970459
# Fold 1/4, Epoch 0/19, Minibatch 0/0, Phase valid, Running Loss valid 11.846322059631348, Time 0.025551557540893555, Overall 0.5159053802490234
# Fold 1/4, Epoch 0/19, Running Loss valid 2.3692644119262694, Time 0.025736093521118164, Overall 0.5160892009735107
# Fold 1/4, Epoch 1/19, Minibatch 0/0, Phase train, Running Loss train 54.58353042602539, Time 0.04526996612548828, Overall 0.5356240272521973
# Fold 1/4, Epoch 1/19, Running Loss train 2.5992157345726374, Time 0.04543304443359375, Overall 0.5357861518859863
# Fold 1/4, Epoch 1/19, Minibatch 0/0, Phase valid, Running Loss valid 10.263297080993652, Time 0.05008673667907715, Overall 0.5404403209686279
# Fold 1/4, Epoch 1/19, Running Loss valid 2.0526594161987304, Time 0.05023932456970215, Overall 0.5405924320220947
# Fold 1/4, Epoch 2/19, Minibatch 0/0, Phase train, Running Loss train 32.913604736328125, Time 0.06805872917175293, Overall 0.5584127902984619
# Fold 1/4, Epoch 2/19, Running Loss train 1.5673145112537203, Time 0.06821131706237793, Overall 0.5585644245147705
# Fold 1/4, Epoch 2/19, Minibatch 0/0, Phase valid, Running Loss valid 8.157803535461426, Time 0.07294821739196777, Overall 0.5633029937744141
# Fold 1/4, Epoch 2/19, Running Loss valid 1.631560707092285, Time 0.07313752174377441, Overall 0.563490629196167
# Fold 1/4, Epoch 3/19, Minibatch 0/0, Phase train, Running Loss train 18.072046279907227, Time 0.09092092514038086, Overall 0.5812747478485107
# Fold 1/4, Epoch 3/19, Running Loss train 0.8605736323765346, Time 0.09107708930969238, Overall 0.5814297199249268
# Fold 1/4, Epoch 3/19, Minibatch 0/0, Phase valid, Running Loss valid 11.60661506652832, Time 0.0956277847290039, Overall 0.5859811305999756
# Fold 1/4, Epoch 3/19, Running Loss valid 2.321323013305664, Time 0.09576654434204102, Overall 0.5861196517944336
# Fold 1/4, Epoch 4/19, Minibatch 0/0, Phase train, Running Loss train 23.13544464111328, Time 0.1137397289276123, Overall 0.6040933132171631
# Fold 1/4, Epoch 4/19, Running Loss train 1.1016878400530135, Time 0.11389517784118652, Overall 0.604248046875
# Fold 1/4, Epoch 4/19, Minibatch 0/0, Phase valid, Running Loss valid 6.10042667388916, Time 0.11858987808227539, Overall 0.6089437007904053
# Fold 1/4, Epoch 4/19, Running Loss valid 1.220085334777832, Time 0.11876153945922852, Overall 0.6091151237487793
# Fold 1/4, Epoch 5/19, Minibatch 0/0, Phase train, Running Loss train 32.47482681274414, Time 0.13649201393127441, Overall 0.6268458366394043
# Fold 1/4, Epoch 5/19, Running Loss train 1.5464203244163877, Time 0.1366429328918457, Overall 0.6269958019256592
# Fold 1/4, Epoch 5/19, Minibatch 0/0, Phase valid, Running Loss valid 7.951730728149414, Time 0.1411757469177246, Overall 0.6315295696258545
# Fold 1/4, Epoch 5/19, Running Loss valid 1.5903461456298829, Time 0.14134478569030762, Overall 0.6316981315612793
# Fold 1/4, Epoch 6/19, Minibatch 0/0, Phase train, Running Loss train 24.007043838500977, Time 0.15991425514221191, Overall 0.6502683162689209
# Fold 1/4, Epoch 6/19, Running Loss train 1.1431925637381417, Time 0.16008472442626953, Overall 0.6504373550415039
# Fold 1/4, Epoch 6/19, Minibatch 0/0, Phase valid, Running Loss valid 16.305021286010742, Time 0.16489195823669434, Overall 0.6552457809448242
# Fold 1/4, Epoch 6/19, Running Loss valid 3.2610042572021483, Time 0.16507601737976074, Overall 0.6554293632507324
# Fold 1/4, Epoch 7/19, Minibatch 0/0, Phase train, Running Loss train 24.405881881713867, Time 0.18595671653747559, Overall 0.6763107776641846
# Fold 1/4, Epoch 7/19, Running Loss train 1.1621848515101842, Time 0.1861283779144287, Overall 0.6764814853668213
# Fold 1/4, Epoch 7/19, Minibatch 0/0, Phase valid, Running Loss valid 13.563070297241211, Time 0.1918478012084961, Overall 0.682201623916626
# Fold 1/4, Epoch 7/19, Running Loss valid 2.712614059448242, Time 0.1920309066772461, Overall 0.6823837757110596
# Fold 1/4, Epoch 8/19, Minibatch 0/0, Phase train, Running Loss train 18.58949851989746, Time 0.21542119979858398, Overall 0.7057754993438721
# Fold 1/4, Epoch 8/19, Running Loss train 0.8852142152332124, Time 0.21559953689575195, Overall 0.7059524059295654
# Fold 1/4, Epoch 8/19, Minibatch 0/0, Phase valid, Running Loss valid 21.18507194519043, Time 0.22128772735595703, Overall 0.7116672992706299
# Fold 1/4, Epoch 8/19, Running Loss valid 4.237014389038086, Time 0.2214956283569336, Overall 0.7118484973907471
# Fold 1/4, Epoch 9/19, Minibatch 0/0, Phase train, Running Loss train 15.182930946350098, Time 0.2436985969543457, Overall 0.7340521812438965
# Fold 1/4, Epoch 9/19, Running Loss train 0.722996711730957, Time 0.2438666820526123, Overall 0.7342197895050049
# Fold 1/4, Epoch 9/19, Minibatch 0/0, Phase valid, Running Loss valid 21.20098876953125, Time 0.24999117851257324, Overall 0.7403450012207031
# Fold 1/4, Epoch 9/19, Running Loss valid 4.24019775390625, Time 0.25016283988952637, Overall 0.740516185760498
# Fold 1/4, Epoch 10/19, Minibatch 0/0, Phase train, Running Loss train 24.51752281188965, Time 0.27367353439331055, Overall 0.7640280723571777
# Fold 1/4, Epoch 10/19, Running Loss train 1.1675010862804593, Time 0.2738630771636963, Overall 0.764216423034668
# Fold 1/4, Epoch 10/19, Minibatch 0/0, Phase valid, Running Loss valid 23.83399772644043, Time 0.28018856048583984, Overall 0.7705433368682861
# Fold 1/4, Epoch 10/19, Running Loss valid 4.766799545288086, Time 0.28045105934143066, Overall 0.7708041667938232
# Fold 1/4, Epoch 11/19, Minibatch 0/0, Phase train, Running Loss train 24.366609573364258, Time 0.30446577072143555, Overall 0.7948198318481445
# Fold 1/4, Epoch 11/19, Running Loss train 1.1603147415887742, Time 0.3046433925628662, Overall 0.7949965000152588
# Fold 1/4, Epoch 11/19, Minibatch 0/0, Phase valid, Running Loss valid 25.134538650512695, Time 0.31080150604248047, Overall 0.8011558055877686
# Fold 1/4, Epoch 11/19, Running Loss valid 5.026907730102539, Time 0.31102466583251953, Overall 0.8013777732849121
# Fold 1/4, Epoch 12/19, Minibatch 0/0, Phase train, Running Loss train 16.7535457611084, Time 0.3349344730377197, Overall 0.8252887725830078
# Fold 1/4, Epoch 12/19, Running Loss train 0.7977878933861142, Time 0.3351006507873535, Overall 0.8254530429840088
# Fold 1/4, Epoch 12/19, Minibatch 0/0, Phase valid, Running Loss valid 28.020999908447266, Time 0.34341979026794434, Overall 0.8337740898132324
# Fold 1/4, Epoch 12/19, Running Loss valid 5.604199981689453, Time 0.34362125396728516, Overall 0.8339743614196777
# Fold 1/4, Epoch 13/19, Minibatch 0/0, Phase train, Running Loss train 20.90013885498047, Time 0.36418914794921875, Overall 0.8545434474945068
# Fold 1/4, Epoch 13/19, Running Loss train 0.9952447073800224, Time 0.3643643856048584, Overall 0.8547172546386719
# Fold 1/4, Epoch 13/19, Minibatch 0/0, Phase valid, Running Loss valid 31.394725799560547, Time 0.3689601421356201, Overall 0.8593134880065918
# Fold 1/4, Epoch 13/19, Running Loss valid 6.2789451599121096, Time 0.36910128593444824, Overall 0.8594546318054199
# Fold 1/4, Epoch 14/19, Minibatch 0/0, Phase train, Running Loss train 16.463218688964844, Time 0.3865025043487549, Overall 0.8768565654754639
# Fold 1/4, Epoch 14/19, Running Loss train 0.7839627947126117, Time 0.3866548538208008, Overall 0.8770077228546143
# Fold 1/4, Epoch 14/19, Minibatch 0/0, Phase valid, Running Loss valid 29.87712860107422, Time 0.3918156623840332, Overall 0.8821702003479004
# Fold 1/4, Epoch 14/19, Running Loss valid 5.975425720214844, Time 0.3920457363128662, Overall 0.8823988437652588
# Fold 1/4, Epoch 15/19, Minibatch 0/0, Phase train, Running Loss train 17.574220657348633, Time 0.41085052490234375, Overall 0.9012043476104736
# Fold 1/4, Epoch 15/19, Running Loss train 0.8368676503499349, Time 0.41101765632629395, Overall 0.9013707637786865
# Fold 1/4, Epoch 15/19, Minibatch 0/0, Phase valid, Running Loss valid 31.869495391845703, Time 0.4158596992492676, Overall 0.9062135219573975
# Fold 1/4, Epoch 15/19, Running Loss valid 6.37389907836914, Time 0.4160313606262207, Overall 0.9063844680786133
# Epoch 00016: reducing learning rate of group 0 to 5.0000e-02.
# Fold 1/4, Epoch 16/19, Minibatch 0/0, Phase train, Running Loss train 20.885934829711914, Time 0.43399500846862793, Overall 0.9243488311767578
# Fold 1/4, Epoch 16/19, Running Loss train 0.9945683252243769, Time 0.4341452121734619, Overall 0.9244976043701172
# Fold 1/4, Epoch 16/19, Minibatch 0/0, Phase valid, Running Loss valid 32.1607666015625, Time 0.4405345916748047, Overall 0.9308881759643555
# Fold 1/4, Epoch 16/19, Running Loss valid 6.4321533203125, Time 0.44069933891296387, Overall 0.9310524463653564
# Fold 1/4, Epoch 17/19, Minibatch 0/0, Phase train, Running Loss train 24.10469627380371, Time 0.46367788314819336, Overall 0.9540319442749023
# Fold 1/4, Epoch 17/19, Running Loss train 1.1478426797049386, Time 0.4638650417327881, Overall 0.9542176723480225
# Fold 1/4, Epoch 17/19, Minibatch 0/0, Phase valid, Running Loss valid 30.031116485595703, Time 0.46897363662719727, Overall 0.9593274593353271
# Fold 1/4, Epoch 17/19, Running Loss valid 6.00622329711914, Time 0.4691636562347412, Overall 0.9595165252685547
# Fold 1/4, Epoch 18/19, Minibatch 0/0, Phase train, Running Loss train 10.731204986572266, Time 0.4860231876373291, Overall 0.9763772487640381
# Fold 1/4, Epoch 18/19, Running Loss train 0.511009761265346, Time 0.48618173599243164, Overall 0.9765348434448242
# Fold 1/4, Epoch 18/19, Minibatch 0/0, Phase valid, Running Loss valid 35.042213439941406, Time 0.49080586433410645, Overall 0.9811596870422363
# Fold 1/4, Epoch 18/19, Running Loss valid 7.008442687988281, Time 0.4909660816192627, Overall 0.9813191890716553
# Fold 1/4, Epoch 19/19, Minibatch 0/0, Phase train, Running Loss train 6.079811096191406, Time 0.5087664127349854, Overall 0.9991216659545898
# Fold 1/4, Epoch 19/19, Running Loss train 0.2895148141043527, Time 0.5089175701141357, Overall 0.9992704391479492
# Fold 1/4, Epoch 19/19, Minibatch 0/0, Phase valid, Running Loss valid 29.129247665405273, Time 0.5136325359344482, Overall 1.00398588180542
# Fold 1/4, Epoch 19/19, Running Loss valid 5.825849533081055, Time 0.5138027667999268, Overall 1.0041556358337402
# Fold 2/4, Epoch 0/19, Minibatch 0/0, Phase train, Running Loss train 67.30787658691406, Time 0.01737070083618164, Overall 1.0249497890472412
# Fold 2/4, Epoch 0/19, Running Loss train 3.205136980329241, Time 0.01752328872680664, Overall 1.0251009464263916
# Fold 2/4, Epoch 0/19, Minibatch 0/0, Phase valid, Running Loss valid 13.66476058959961, Time 0.022406816482543945, Overall 1.0299859046936035
# Fold 2/4, Epoch 0/19, Running Loss valid 2.732952117919922, Time 0.022572994232177734, Overall 1.030151128768921
# Fold 2/4, Epoch 1/19, Minibatch 0/0, Phase train, Running Loss train 68.05340576171875, Time 0.040874481201171875, Overall 1.0484538078308105
# Fold 2/4, Epoch 1/19, Running Loss train 3.2406383696056547, Time 0.04101967811584473, Overall 1.0485975742340088
# Fold 2/4, Epoch 1/19, Minibatch 0/0, Phase valid, Running Loss valid 7.501473426818848, Time 0.045890092849731445, Overall 1.0534696578979492
# Fold 2/4, Epoch 1/19, Running Loss valid 1.5002946853637695, Time 0.046056509017944336, Overall 1.0536348819732666
# Fold 2/4, Epoch 2/19, Minibatch 0/0, Phase train, Running Loss train 41.792396545410156, Time 0.06403160095214844, Overall 1.0716102123260498
# Fold 2/4, Epoch 2/19, Running Loss train 1.9901141212100075, Time 0.06418037414550781, Overall 1.0717580318450928
# Fold 2/4, Epoch 2/19, Minibatch 0/0, Phase valid, Running Loss valid 6.7209649085998535, Time 0.06827473640441895, Overall 1.0758535861968994
# Fold 2/4, Epoch 2/19, Running Loss valid 1.3441929817199707, Time 0.06842279434204102, Overall 1.0760009288787842
# Fold 2/4, Epoch 3/19, Minibatch 0/0, Phase train, Running Loss train 33.16362762451172, Time 0.08477210998535156, Overall 1.0923511981964111
# Fold 2/4, Epoch 3/19, Running Loss train 1.5792203630719865, Time 0.08494210243225098, Overall 1.0925207138061523
# Fold 2/4, Epoch 3/19, Minibatch 0/0, Phase valid, Running Loss valid 4.209686279296875, Time 0.08984208106994629, Overall 1.097421407699585
# Fold 2/4, Epoch 3/19, Running Loss valid 0.841937255859375, Time 0.09001588821411133, Overall 1.0975935459136963
# Fold 2/4, Epoch 4/19, Minibatch 0/0, Phase train, Running Loss train 30.82887077331543, Time 0.11259841918945312, Overall 1.1201777458190918
# Fold 2/4, Epoch 4/19, Running Loss train 1.4680414653959728, Time 0.11275267601013184, Overall 1.120331048965454
# Fold 2/4, Epoch 4/19, Minibatch 0/0, Phase valid, Running Loss valid 3.4463939666748047, Time 0.11892414093017578, Overall 1.1265032291412354
# Fold 2/4, Epoch 4/19, Running Loss valid 0.6892787933349609, Time 0.11915206909179688, Overall 1.1267309188842773
# Fold 2/4, Epoch 5/19, Minibatch 0/0, Phase train, Running Loss train 17.287071228027344, Time 0.13770198822021484, Overall 1.1452810764312744
# Fold 2/4, Epoch 5/19, Running Loss train 0.8231938680013021, Time 0.13787245750427246, Overall 1.1454510688781738
# Fold 2/4, Epoch 5/19, Minibatch 0/0, Phase valid, Running Loss valid 3.476046323776245, Time 0.14275336265563965, Overall 1.1503324508666992
# Fold 2/4, Epoch 5/19, Running Loss valid 0.695209264755249, Time 0.14295339584350586, Overall 1.15053129196167
# Fold 2/4, Epoch 6/19, Minibatch 0/0, Phase train, Running Loss train 16.3463191986084, Time 0.16142749786376953, Overall 1.1690068244934082
# Fold 2/4, Epoch 6/19, Running Loss train 0.7783961523146856, Time 0.16158246994018555, Overall 1.1691603660583496
# Fold 2/4, Epoch 6/19, Minibatch 0/0, Phase valid, Running Loss valid 9.520225524902344, Time 0.16649436950683594, Overall 1.1740736961364746
# Fold 2/4, Epoch 6/19, Running Loss valid 1.9040451049804688, Time 0.16666102409362793, Overall 1.1742393970489502
# Fold 2/4, Epoch 7/19, Minibatch 0/0, Phase train, Running Loss train 18.542221069335938, Time 0.18674921989440918, Overall 1.1943280696868896
# Fold 2/4, Epoch 7/19, Running Loss train 0.8829629080636161, Time 0.18690943717956543, Overall 1.1944873332977295
# Fold 2/4, Epoch 7/19, Minibatch 0/0, Phase valid, Running Loss valid 15.094550132751465, Time 0.19174790382385254, Overall 1.199326515197754
# Fold 2/4, Epoch 7/19, Running Loss valid 3.018910026550293, Time 0.19192218780517578, Overall 1.199500322341919
# Fold 2/4, Epoch 8/19, Minibatch 0/0, Phase train, Running Loss train 35.74477005004883, Time 0.21167874336242676, Overall 1.2192580699920654
# Fold 2/4, Epoch 8/19, Running Loss train 1.7021319071451824, Time 0.21183133125305176, Overall 1.219409465789795
# Fold 2/4, Epoch 8/19, Minibatch 0/0, Phase valid, Running Loss valid 17.461042404174805, Time 0.2164783477783203, Overall 1.2240569591522217
# Fold 2/4, Epoch 8/19, Running Loss valid 3.492208480834961, Time 0.21663737297058105, Overall 1.2242152690887451
# Fold 2/4, Epoch 9/19, Minibatch 0/0, Phase train, Running Loss train 37.454410552978516, Time 0.2346205711364746, Overall 1.2421998977661133
# Fold 2/4, Epoch 9/19, Running Loss train 1.7835433596656436, Time 0.23477387428283691, Overall 1.24235200881958
# Fold 2/4, Epoch 9/19, Minibatch 0/0, Phase valid, Running Loss valid 20.010807037353516, Time 0.23949193954467773, Overall 1.2470710277557373
# Fold 2/4, Epoch 9/19, Running Loss valid 4.0021614074707035, Time 0.23965144157409668, Overall 1.2472295761108398
# Fold 2/4, Epoch 10/19, Minibatch 0/0, Phase train, Running Loss train 39.663970947265625, Time 0.25783371925354004, Overall 1.2654128074645996
# Fold 2/4, Epoch 10/19, Running Loss train 1.8887605212983631, Time 0.25799131393432617, Overall 1.2655694484710693
# Fold 2/4, Epoch 10/19, Minibatch 0/0, Phase valid, Running Loss valid 4.195762634277344, Time 0.262728214263916, Overall 1.2703073024749756
# Fold 2/4, Epoch 10/19, Running Loss valid 0.8391525268554687, Time 0.26290345191955566, Overall 1.2704811096191406
# Fold 2/4, Epoch 11/19, Minibatch 0/0, Phase train, Running Loss train 20.791858673095703, Time 0.280454158782959, Overall 1.2880330085754395
# Fold 2/4, Epoch 11/19, Running Loss train 0.9900885082426525, Time 0.28061509132385254, Overall 1.2881932258605957
# Fold 2/4, Epoch 11/19, Minibatch 0/0, Phase valid, Running Loss valid 6.049252033233643, Time 0.2854461669921875, Overall 1.293025255203247
# Fold 2/4, Epoch 11/19, Running Loss valid 1.2098504066467286, Time 0.2856132984161377, Overall 1.2931914329528809
# Fold 2/4, Epoch 12/19, Minibatch 0/0, Phase train, Running Loss train 32.867408752441406, Time 0.3035883903503418, Overall 1.3111677169799805
# Fold 2/4, Epoch 12/19, Running Loss train 1.5651147024972099, Time 0.3037424087524414, Overall 1.3113203048706055
# Fold 2/4, Epoch 12/19, Minibatch 0/0, Phase valid, Running Loss valid 7.984633922576904, Time 0.3086738586425781, Overall 1.316253423690796
# Fold 2/4, Epoch 12/19, Running Loss valid 1.596926784515381, Time 0.3088352680206299, Overall 1.3164129257202148
# Fold 2/4, Epoch 13/19, Minibatch 0/0, Phase train, Running Loss train 20.558448791503906, Time 0.326779842376709, Overall 1.3343582153320312
# Fold 2/4, Epoch 13/19, Running Loss train 0.9789737519763765, Time 0.32692766189575195, Overall 1.334505558013916
# Fold 2/4, Epoch 13/19, Minibatch 0/0, Phase valid, Running Loss valid 12.13774299621582, Time 0.33095550537109375, Overall 1.3385341167449951
# Fold 2/4, Epoch 13/19, Running Loss valid 2.4275485992431642, Time 0.331101655960083, Overall 1.338679552078247
# Fold 2/4, Epoch 14/19, Minibatch 0/0, Phase train, Running Loss train 17.105087280273438, Time 0.34842729568481445, Overall 1.356006383895874
# Fold 2/4, Epoch 14/19, Running Loss train 0.8145279657273066, Time 0.34857892990112305, Overall 1.3561573028564453
# Fold 2/4, Epoch 14/19, Minibatch 0/0, Phase valid, Running Loss valid 3.0496015548706055, Time 0.353287935256958, Overall 1.3608675003051758
# Fold 2/4, Epoch 14/19, Running Loss valid 0.6099203109741211, Time 0.35344672203063965, Overall 1.3610246181488037
# Fold 2/4, Epoch 15/19, Minibatch 0/0, Phase train, Running Loss train 24.785978317260742, Time 0.3717172145843506, Overall 1.379296064376831
# Fold 2/4, Epoch 15/19, Running Loss train 1.180284681774321, Time 0.37187767028808594, Overall 1.3794560432434082
# Fold 2/4, Epoch 15/19, Minibatch 0/0, Phase valid, Running Loss valid 12.096345901489258, Time 0.3766205310821533, Overall 1.3841989040374756
# Fold 2/4, Epoch 15/19, Running Loss valid 2.4192691802978517, Time 0.37682151794433594, Overall 1.384399652481079
# Fold 2/4, Epoch 16/19, Minibatch 0/0, Phase train, Running Loss train 27.145578384399414, Time 0.3945438861846924, Overall 1.402122974395752
# Fold 2/4, Epoch 16/19, Running Loss train 1.2926465897333055, Time 0.3947010040283203, Overall 1.4022789001464844
# Fold 2/4, Epoch 16/19, Minibatch 0/0, Phase valid, Running Loss valid 5.895963668823242, Time 0.399397611618042, Overall 1.4069769382476807
# Fold 2/4, Epoch 16/19, Running Loss valid 1.1791927337646484, Time 0.39955925941467285, Overall 1.407137155532837
# Fold 2/4, Epoch 17/19, Minibatch 0/0, Phase train, Running Loss train 29.911651611328125, Time 0.4243924617767334, Overall 1.4319710731506348
# Fold 2/4, Epoch 17/19, Running Loss train 1.4243643624441964, Time 0.42454004287719727, Overall 1.4321186542510986
# Fold 2/4, Epoch 17/19, Minibatch 0/0, Phase valid, Running Loss valid 7.47799825668335, Time 0.42983174324035645, Overall 1.4374110698699951
# Fold 2/4, Epoch 17/19, Running Loss valid 1.4955996513366698, Time 0.429995059967041, Overall 1.4375731945037842
# Fold 2/4, Epoch 18/19, Minibatch 0/0, Phase train, Running Loss train 19.475631713867188, Time 0.4478914737701416, Overall 1.4554705619812012
# Fold 2/4, Epoch 18/19, Running Loss train 0.9274110339936756, Time 0.44805169105529785, Overall 1.455629825592041
# Fold 2/4, Epoch 18/19, Minibatch 0/0, Phase valid, Running Loss valid 6.491040229797363, Time 0.45285868644714355, Overall 1.460437536239624
# Fold 2/4, Epoch 18/19, Running Loss valid 1.2982080459594727, Time 0.4530050754547119, Overall 1.460583209991455
# Fold 2/4, Epoch 19/19, Minibatch 0/0, Phase train, Running Loss train 16.6554012298584, Time 0.4708518981933594, Overall 1.4784307479858398
# Fold 2/4, Epoch 19/19, Running Loss train 0.7931143442789713, Time 0.4709956645965576, Overall 1.4785735607147217
# Fold 2/4, Epoch 19/19, Minibatch 0/0, Phase valid, Running Loss valid 1.961896300315857, Time 0.47566890716552734, Overall 1.4832477569580078
# Fold 2/4, Epoch 19/19, Running Loss valid 0.39237926006317136, Time 0.4758172035217285, Overall 1.4833953380584717
# Fold 3/4, Epoch 0/19, Minibatch 0/0, Phase train, Running Loss train 68.26947021484375, Time 0.01713871955871582, Overall 1.5040721893310547
# Fold 3/4, Epoch 0/19, Running Loss train 3.2509271530877974, Time 0.017302274703979492, Overall 1.5042343139648438
# Fold 3/4, Epoch 0/19, Minibatch 0/0, Phase valid, Running Loss valid 19.680465698242188, Time 0.02211761474609375, Overall 1.5090503692626953
# Fold 3/4, Epoch 0/19, Running Loss valid 3.9360931396484373, Time 0.022296905517578125, Overall 1.5092291831970215
# Fold 3/4, Epoch 1/19, Minibatch 0/0, Phase train, Running Loss train 52.242862701416016, Time 0.04043149948120117, Overall 1.5273644924163818
# Fold 3/4, Epoch 1/19, Running Loss train 2.487755366734096, Time 0.040590524673461914, Overall 1.5275225639343262
# Fold 3/4, Epoch 1/19, Minibatch 0/0, Phase valid, Running Loss valid 15.640719413757324, Time 0.045227766036987305, Overall 1.5321605205535889
# Fold 3/4, Epoch 1/19, Running Loss valid 3.128143882751465, Time 0.045380353927612305, Overall 1.5323126316070557
# Fold 3/4, Epoch 2/19, Minibatch 0/0, Phase train, Running Loss train 34.14817428588867, Time 0.06336212158203125, Overall 1.5502943992614746
# Fold 3/4, Epoch 2/19, Running Loss train 1.6261035374232702, Time 0.06410574913024902, Overall 1.5510385036468506
# Fold 3/4, Epoch 2/19, Minibatch 0/0, Phase valid, Running Loss valid 16.270498275756836, Time 0.06914305686950684, Overall 1.5560760498046875
# Fold 3/4, Epoch 2/19, Running Loss valid 3.254099655151367, Time 0.06929230690002441, Overall 1.5562243461608887
# Fold 3/4, Epoch 3/19, Minibatch 0/0, Phase train, Running Loss train 30.77960968017578, Time 0.08556389808654785, Overall 1.5724966526031494
# Fold 3/4, Epoch 3/19, Running Loss train 1.4656956990559895, Time 0.08571290969848633, Overall 1.5726451873779297
# Fold 3/4, Epoch 3/19, Minibatch 0/0, Phase valid, Running Loss valid 19.840776443481445, Time 0.09047436714172363, Overall 1.5774073600769043
# Fold 3/4, Epoch 3/19, Running Loss valid 3.968155288696289, Time 0.09063386917114258, Overall 1.5775656700134277
# Fold 3/4, Epoch 4/19, Minibatch 0/0, Phase train, Running Loss train 24.520736694335938, Time 0.10823559761047363, Overall 1.5951685905456543
# Fold 3/4, Epoch 4/19, Running Loss train 1.1676541283017112, Time 0.10839080810546875, Overall 1.595322608947754
# Fold 3/4, Epoch 4/19, Minibatch 0/0, Phase valid, Running Loss valid 21.58452796936035, Time 0.11318397521972656, Overall 1.6001167297363281
# Fold 3/4, Epoch 4/19, Running Loss valid 4.31690559387207, Time 0.1133568286895752, Overall 1.6002888679504395
# Fold 3/4, Epoch 5/19, Minibatch 0/0, Phase train, Running Loss train 11.871650695800781, Time 0.1312406063079834, Overall 1.6181731224060059
# Fold 3/4, Epoch 5/19, Running Loss train 0.5653166998000372, Time 0.13138842582702637, Overall 1.6183204650878906
# Fold 3/4, Epoch 5/19, Minibatch 0/0, Phase valid, Running Loss valid 41.892669677734375, Time 0.13609695434570312, Overall 1.6230297088623047
# Fold 3/4, Epoch 5/19, Running Loss valid 8.378533935546875, Time 0.13624954223632812, Overall 1.6231818199157715
# Fold 3/4, Epoch 6/19, Minibatch 0/0, Phase train, Running Loss train 19.970367431640625, Time 0.15384221076965332, Overall 1.6407747268676758
# Fold 3/4, Epoch 6/19, Running Loss train 0.9509698776971727, Time 0.1539933681488037, Overall 1.640925407409668
# Fold 3/4, Epoch 6/19, Minibatch 0/0, Phase valid, Running Loss valid 35.06840515136719, Time 0.1586291790008545, Overall 1.645561695098877
# Fold 3/4, Epoch 6/19, Running Loss valid 7.013681030273437, Time 0.15894269943237305, Overall 1.6458759307861328
# Fold 3/4, Epoch 7/19, Minibatch 0/0, Phase train, Running Loss train 18.719810485839844, Time 0.17720484733581543, Overall 1.6641380786895752
# Fold 3/4, Epoch 7/19, Running Loss train 0.8914195469447544, Time 0.17737221717834473, Overall 1.664304494857788
# Fold 3/4, Epoch 7/19, Minibatch 0/0, Phase valid, Running Loss valid 54.66911315917969, Time 0.1820540428161621, Overall 1.6689860820770264
# Fold 3/4, Epoch 7/19, Running Loss valid 10.933822631835938, Time 0.18221807479858398, Overall 1.66914963722229
# Fold 3/4, Epoch 8/19, Minibatch 0/0, Phase train, Running Loss train 15.147088050842285, Time 0.20019149780273438, Overall 1.6871247291564941
# Fold 3/4, Epoch 8/19, Running Loss train 0.7212899071829659, Time 0.20037150382995605, Overall 1.6873037815093994
# Fold 3/4, Epoch 8/19, Minibatch 0/0, Phase valid, Running Loss valid 39.61464309692383, Time 0.20529794692993164, Overall 1.6922307014465332
# Fold 3/4, Epoch 8/19, Running Loss valid 7.9229286193847654, Time 0.20551300048828125, Overall 1.6924455165863037
# Fold 3/4, Epoch 9/19, Minibatch 0/0, Phase train, Running Loss train 13.945464134216309, Time 0.22379374504089355, Overall 1.710726261138916
# Fold 3/4, Epoch 9/19, Running Loss train 0.6640697206769671, Time 0.22394323348999023, Overall 1.7108752727508545
# Fold 3/4, Epoch 9/19, Minibatch 0/0, Phase valid, Running Loss valid 48.67245101928711, Time 0.228651762008667, Overall 1.7155840396881104
# Fold 3/4, Epoch 9/19, Running Loss valid 9.734490203857423, Time 0.22885632514953613, Overall 1.7157888412475586
# Fold 3/4, Epoch 10/19, Minibatch 0/0, Phase train, Running Loss train 14.740314483642578, Time 0.24889421463012695, Overall 1.7358269691467285
# Fold 3/4, Epoch 10/19, Running Loss train 0.7019197373163133, Time 0.24906396865844727, Overall 1.7359962463378906
# Fold 3/4, Epoch 10/19, Minibatch 0/0, Phase valid, Running Loss valid 65.64291381835938, Time 0.2540860176086426, Overall 1.7410187721252441
# Fold 3/4, Epoch 10/19, Running Loss valid 13.128582763671876, Time 0.2542760372161865, Overall 1.7412080764770508
# Fold 3/4, Epoch 11/19, Minibatch 0/0, Phase train, Running Loss train 12.496047019958496, Time 0.2726285457611084, Overall 1.7595617771148682
# Fold 3/4, Epoch 11/19, Running Loss train 0.5950498580932617, Time 0.2728121280670166, Overall 1.7597434520721436
# Fold 3/4, Epoch 11/19, Minibatch 0/0, Phase valid, Running Loss valid 69.91461181640625, Time 0.27786707878112793, Overall 1.7648000717163086
# Fold 3/4, Epoch 11/19, Running Loss valid 13.98292236328125, Time 0.2780451774597168, Overall 1.7649774551391602
# Fold 3/4, Epoch 12/19, Minibatch 0/0, Phase train, Running Loss train 15.06256103515625, Time 0.29636263847351074, Overall 1.7832956314086914
# Fold 3/4, Epoch 12/19, Running Loss train 0.7172648111979166, Time 0.2965257167816162, Overall 1.7834570407867432
# Fold 3/4, Epoch 12/19, Minibatch 0/0, Phase valid, Running Loss valid 72.5185546875, Time 0.30159783363342285, Overall 1.7885308265686035
# Fold 3/4, Epoch 12/19, Running Loss valid 14.5037109375, Time 0.30179667472839355, Overall 1.788728952407837
# Epoch 00013: reducing learning rate of group 0 to 5.0000e-02.
# Fold 3/4, Epoch 13/19, Minibatch 0/0, Phase train, Running Loss train 8.454937934875488, Time 0.3205544948577881, Overall 1.807488203048706
# Fold 3/4, Epoch 13/19, Running Loss train 0.402616092136928, Time 0.3207085132598877, Overall 1.8076403141021729
# Fold 3/4, Epoch 13/19, Minibatch 0/0, Phase valid, Running Loss valid 71.5435791015625, Time 0.32544636726379395, Overall 1.8123793601989746
# Fold 3/4, Epoch 13/19, Running Loss valid 14.3087158203125, Time 0.32560157775878906, Overall 1.8125340938568115
# Fold 3/4, Epoch 14/19, Minibatch 0/0, Phase train, Running Loss train 22.301860809326172, Time 0.34380054473876953, Overall 1.8307335376739502
# Fold 3/4, Epoch 14/19, Running Loss train 1.0619933718726748, Time 0.34395480155944824, Overall 1.8308866024017334
# Fold 3/4, Epoch 14/19, Minibatch 0/0, Phase valid, Running Loss valid 74.59597778320312, Time 0.3489501476287842, Overall 1.8358829021453857
# Fold 3/4, Epoch 14/19, Running Loss valid 14.919195556640625, Time 0.34911632537841797, Overall 1.8360481262207031
# Fold 3/4, Epoch 15/19, Minibatch 0/0, Phase train, Running Loss train 4.173070907592773, Time 0.36879825592041016, Overall 1.85573148727417
# Fold 3/4, Epoch 15/19, Running Loss train 0.19871766226632254, Time 0.3696904182434082, Overall 1.8566224575042725
# Fold 3/4, Epoch 15/19, Minibatch 0/0, Phase valid, Running Loss valid 96.37030029296875, Time 0.37447452545166016, Overall 1.8614075183868408
# Fold 3/4, Epoch 15/19, Running Loss valid 19.27406005859375, Time 0.37484145164489746, Overall 1.8617737293243408
# Fold 3/4, Epoch 16/19, Minibatch 0/0, Phase train, Running Loss train 8.951931953430176, Time 0.39084815979003906, Overall 1.877781629562378
# Fold 3/4, Epoch 16/19, Running Loss train 0.4262824739728655, Time 0.39100122451782227, Overall 1.8779330253601074
# Fold 3/4, Epoch 16/19, Minibatch 0/0, Phase valid, Running Loss valid 113.00505065917969, Time 0.39587926864624023, Overall 1.882812738418579
# Fold 3/4, Epoch 16/19, Running Loss valid 22.601010131835938, Time 0.3961007595062256, Overall 1.8830325603485107
# Fold 3/4, Epoch 17/19, Minibatch 0/0, Phase train, Running Loss train 8.808636665344238, Time 0.4148409366607666, Overall 1.9017746448516846
# Fold 3/4, Epoch 17/19, Running Loss train 0.4194588888259161, Time 0.4150083065032959, Overall 1.9019405841827393
# Fold 3/4, Epoch 17/19, Minibatch 0/0, Phase valid, Running Loss valid 101.06735229492188, Time 0.4198603630065918, Overall 1.9067931175231934
# Fold 3/4, Epoch 17/19, Running Loss valid 20.213470458984375, Time 0.42003655433654785, Overall 1.9069688320159912
# Fold 3/4, Epoch 18/19, Minibatch 0/0, Phase train, Running Loss train 5.093909740447998, Time 0.43844056129455566, Overall 1.9253740310668945
# Fold 3/4, Epoch 18/19, Running Loss train 0.2425671304975237, Time 0.4386119842529297, Overall 1.925544023513794
# Fold 3/4, Epoch 18/19, Minibatch 0/0, Phase valid, Running Loss valid 79.31901550292969, Time 0.4434685707092285, Overall 1.930401086807251
# Fold 3/4, Epoch 18/19, Running Loss valid 15.863803100585937, Time 0.44364428520202637, Overall 1.9305760860443115
# Fold 3/4, Epoch 19/19, Minibatch 0/0, Phase train, Running Loss train 17.980775833129883, Time 0.46161627769470215, Overall 1.9485485553741455
# Fold 3/4, Epoch 19/19, Running Loss train 0.8562274206252325, Time 0.4617922306060791, Overall 1.9487237930297852
# Fold 3/4, Epoch 19/19, Minibatch 0/0, Phase valid, Running Loss valid 99.36193084716797, Time 0.4663960933685303, Overall 1.9533286094665527
# Fold 3/4, Epoch 19/19, Running Loss valid 19.872386169433593, Time 0.4683105945587158, Overall 1.9552433490753174
# Fold 4/4, Epoch 0/19, Minibatch 0/0, Phase train, Running Loss train 65.3763656616211, Time 0.017520904541015625, Overall 1.978858470916748
# Fold 4/4, Epoch 0/19, Running Loss train 3.1131602696010043, Time 0.017897605895996094, Overall 1.9792351722717285
# Fold 4/4, Epoch 0/19, Minibatch 0/0, Phase valid, Running Loss valid 17.687583923339844, Time 0.023273706436157227, Overall 1.9846107959747314
# Fold 4/4, Epoch 0/19, Running Loss valid 3.537516784667969, Time 0.023504972457885742, Overall 1.98484206199646
# Fold 4/4, Epoch 1/19, Minibatch 0/0, Phase train, Running Loss train 51.61524963378906, Time 0.04154777526855469, Overall 2.002885103225708
# Fold 4/4, Epoch 1/19, Running Loss train 2.4578690301804316, Time 0.041710853576660156, Overall 2.0030479431152344
# Fold 4/4, Epoch 1/19, Minibatch 0/0, Phase valid, Running Loss valid 13.660017013549805, Time 0.046506404876708984, Overall 2.0078444480895996
# Fold 4/4, Epoch 1/19, Running Loss valid 2.732003402709961, Time 0.04667520523071289, Overall 2.008012056350708
# Fold 4/4, Epoch 2/19, Minibatch 0/0, Phase train, Running Loss train 37.91270446777344, Time 0.06825470924377441, Overall 2.029592275619507
# Fold 4/4, Epoch 2/19, Running Loss train 1.8053668794177828, Time 0.0703573226928711, Overall 2.0316951274871826
# Fold 4/4, Epoch 2/19, Minibatch 0/0, Phase valid, Running Loss valid 15.898605346679688, Time 0.07561850547790527, Overall 2.0369555950164795
# Fold 4/4, Epoch 2/19, Running Loss valid 3.1797210693359377, Time 0.07721495628356934, Overall 2.03855299949646
# Fold 4/4, Epoch 3/19, Minibatch 0/0, Phase train, Running Loss train 34.24123764038086, Time 0.09565544128417969, Overall 2.056992769241333
# Fold 4/4, Epoch 3/19, Running Loss train 1.6305351257324219, Time 0.09581851959228516, Overall 2.057154893875122
# Fold 4/4, Epoch 3/19, Minibatch 0/0, Phase valid, Running Loss valid 18.397342681884766, Time 0.10076665878295898, Overall 2.062103748321533
# Fold 4/4, Epoch 3/19, Running Loss valid 3.679468536376953, Time 0.10093903541564941, Overall 2.0622756481170654
# Fold 4/4, Epoch 4/19, Minibatch 0/0, Phase train, Running Loss train 27.751937866210938, Time 0.11814308166503906, Overall 2.0794801712036133
# Fold 4/4, Epoch 4/19, Running Loss train 1.3215208507719494, Time 0.11827611923217773, Overall 2.0796127319335938
# Fold 4/4, Epoch 4/19, Minibatch 0/0, Phase valid, Running Loss valid 21.21490478515625, Time 0.1220083236694336, Overall 2.083345651626587
# Fold 4/4, Epoch 4/19, Running Loss valid 4.24298095703125, Time 0.12218880653381348, Overall 2.0835251808166504
# Fold 4/4, Epoch 5/19, Minibatch 0/0, Phase train, Running Loss train 25.791536331176758, Time 0.1402301788330078, Overall 2.101567506790161
# Fold 4/4, Epoch 5/19, Running Loss train 1.2281683967227028, Time 0.14045405387878418, Overall 2.1017916202545166
# Fold 4/4, Epoch 5/19, Minibatch 0/0, Phase valid, Running Loss valid 29.36288070678711, Time 0.14537310600280762, Overall 2.10671067237854
# Fold 4/4, Epoch 5/19, Running Loss valid 5.872576141357422, Time 0.1455686092376709, Overall 2.106905698776245
# Fold 4/4, Epoch 6/19, Minibatch 0/0, Phase train, Running Loss train 38.471275329589844, Time 0.16384029388427734, Overall 2.1251773834228516
# Fold 4/4, Epoch 6/19, Running Loss train 1.8319654918852306, Time 0.16399383544921875, Overall 2.125330686569214
# Fold 4/4, Epoch 6/19, Minibatch 0/0, Phase valid, Running Loss valid 32.84701919555664, Time 0.16874265670776367, Overall 2.130080461502075
# Fold 4/4, Epoch 6/19, Running Loss valid 6.569403839111328, Time 0.1689286231994629, Overall 2.1302649974823
# Fold 4/4, Epoch 7/19, Minibatch 0/0, Phase train, Running Loss train 25.092256546020508, Time 0.18475842475891113, Overall 2.1460957527160645
# Fold 4/4, Epoch 7/19, Running Loss train 1.1948693593343098, Time 0.18490982055664062, Overall 2.1462464332580566
# Fold 4/4, Epoch 7/19, Minibatch 0/0, Phase valid, Running Loss valid 30.197628021240234, Time 0.18961596488952637, Overall 2.150953769683838
# Fold 4/4, Epoch 7/19, Running Loss valid 6.0395256042480465, Time 0.18983769416809082, Overall 2.151175022125244
# Fold 4/4, Epoch 8/19, Minibatch 0/0, Phase train, Running Loss train 27.390047073364258, Time 0.20987176895141602, Overall 2.1712090969085693
# Fold 4/4, Epoch 8/19, Running Loss train 1.3042879558744884, Time 0.21003937721252441, Overall 2.1713762283325195
# Fold 4/4, Epoch 8/19, Minibatch 0/0, Phase valid, Running Loss valid 33.76799392700195, Time 0.214768648147583, Overall 2.176105499267578
# Fold 4/4, Epoch 8/19, Running Loss valid 6.75359878540039, Time 0.2149205207824707, Overall 2.1762571334838867
# Fold 4/4, Epoch 9/19, Minibatch 0/0, Phase train, Running Loss train 35.410728454589844, Time 0.23300409317016602, Overall 2.1943414211273193
# Fold 4/4, Epoch 9/19, Running Loss train 1.6862251645042783, Time 0.23317408561706543, Overall 2.1945104598999023
# Fold 4/4, Epoch 9/19, Minibatch 0/0, Phase valid, Running Loss valid 36.545738220214844, Time 0.23799896240234375, Overall 2.199336051940918
# Fold 4/4, Epoch 9/19, Running Loss valid 7.309147644042969, Time 0.23817968368530273, Overall 2.1995160579681396
# Fold 4/4, Epoch 10/19, Minibatch 0/0, Phase train, Running Loss train 21.62529945373535, Time 0.2562878131866455, Overall 2.217625379562378
# Fold 4/4, Epoch 10/19, Running Loss train 1.029776164463588, Time 0.2564582824707031, Overall 2.217794895172119
# Fold 4/4, Epoch 10/19, Minibatch 0/0, Phase valid, Running Loss valid 37.57292556762695, Time 0.2612192630767822, Overall 2.2225565910339355
# Fold 4/4, Epoch 10/19, Running Loss valid 7.51458511352539, Time 0.2614402770996094, Overall 2.2227768898010254
# Fold 4/4, Epoch 11/19, Minibatch 0/0, Phase train, Running Loss train 21.30674171447754, Time 0.2770836353302002, Overall 2.2384212017059326
# Fold 4/4, Epoch 11/19, Running Loss train 1.0146067483084542, Time 0.2772178649902344, Overall 2.2385542392730713
# Fold 4/4, Epoch 11/19, Minibatch 0/0, Phase valid, Running Loss valid 39.33412170410156, Time 0.28163790702819824, Overall 2.2429754734039307
# Fold 4/4, Epoch 11/19, Running Loss valid 7.866824340820313, Time 0.281843900680542, Overall 2.243180513381958
# Fold 4/4, Epoch 12/19, Minibatch 0/0, Phase train, Running Loss train 31.201250076293945, Time 0.3001549243927002, Overall 2.2614924907684326
# ...
# Fold 3/4, Epoch 10/19, Running Loss train 17.734114873976935, Time 0.39638376235961914, Overall 2.6106629371643066
# Fold 3/4, Epoch 10/19, Minibatch 0/0, Phase valid, Running Loss valid 25.684825897216797, Time 0.4059734344482422, Overall 2.6202540397644043
# Fold 3/4, Epoch 10/19, Running Loss valid 5.13696517944336, Time 0.4061925411224365, Overall 2.6204726696014404
# Fold 3/4, Epoch 11/19, Minibatch 0/0, Phase train, Running Loss train 182.9360809326172, Time 0.43316221237182617, Overall 2.6474432945251465
# Fold 3/4, Epoch 11/19, Running Loss train 8.711241949172248, Time 0.433333158493042, Overall 2.6476128101348877
# Fold 3/4, Epoch 11/19, Minibatch 0/0, Phase valid, Running Loss valid 57.93538284301758, Time 0.4430220127105713, Overall 2.6573028564453125
# Fold 3/4, Epoch 11/19, Running Loss valid 11.587076568603516, Time 0.44324302673339844, Overall 2.6575233936309814
# Fold 3/4, Epoch 12/19, Minibatch 0/0, Phase train, Running Loss train 252.78237915039062, Time 0.46924328804016113, Overall 2.6835243701934814
# Fold 3/4, Epoch 12/19, Running Loss train 12.037256150018601, Time 0.4694075584411621, Overall 2.683687448501587
# Fold 3/4, Epoch 12/19, Minibatch 0/0, Phase valid, Running Loss valid 38.40971374511719, Time 0.4815213680267334, Overall 2.6958024501800537
# Fold 3/4, Epoch 12/19, Running Loss valid 7.681942749023437, Time 0.4817686080932617, Overall 2.6960487365722656
# Fold 3/4, Epoch 13/19, Minibatch 0/0, Phase train, Running Loss train 72.04388427734375, Time 0.5160510540008545, Overall 2.7303318977355957
# Fold 3/4, Epoch 13/19, Running Loss train 3.430661156063988, Time 0.5162451267242432, Overall 2.730525016784668
# Fold 3/4, Epoch 13/19, Minibatch 0/0, Phase valid, Running Loss valid 93.5903091430664, Time 0.5338912010192871, Overall 2.748171806335449
# Fold 3/4, Epoch 13/19, Running Loss valid 18.71806182861328, Time 0.5341556072235107, Overall 2.7484354972839355
# Fold 3/4, Epoch 14/19, Minibatch 0/0, Phase train, Running Loss train 247.85751342773438, Time 0.5621018409729004, Overall 2.7763822078704834
# Fold 3/4, Epoch 14/19, Running Loss train 11.802738734654017, Time 0.5622596740722656, Overall 2.7765393257141113
# Fold 3/4, Epoch 14/19, Minibatch 0/0, Phase valid, Running Loss valid 58.56269073486328, Time 0.5718202590942383, Overall 2.7861008644104004
# Fold 3/4, Epoch 14/19, Running Loss valid 11.712538146972657, Time 0.5720500946044922, Overall 2.786330461502075
# Fold 3/4, Epoch 15/19, Minibatch 0/0, Phase train, Running Loss train 255.8141632080078, Time 0.5978832244873047, Overall 2.8121633529663086
# Fold 3/4, Epoch 15/19, Running Loss train 12.181626819428944, Time 0.5980696678161621, Overall 2.812349796295166
# Fold 3/4, Epoch 15/19, Minibatch 0/0, Phase valid, Running Loss valid 86.58695983886719, Time 0.6084132194519043, Overall 2.8226940631866455
# Fold 3/4, Epoch 15/19, Running Loss valid 17.31739196777344, Time 0.6086540222167969, Overall 2.822934150695801
# Fold 3/4, Epoch 16/19, Minibatch 0/0, Phase train, Running Loss train 147.16024780273438, Time 0.6367397308349609, Overall 2.851020336151123
# Fold 3/4, Epoch 16/19, Running Loss train 7.007630847749256, Time 0.6369211673736572, Overall 2.851201295852661
# Fold 3/4, Epoch 16/19, Minibatch 0/0, Phase valid, Running Loss valid 67.11148834228516, Time 0.6466758251190186, Overall 2.8609564304351807
# Fold 3/4, Epoch 16/19, Running Loss valid 13.42229766845703, Time 0.6468915939331055, Overall 2.8611717224121094
# Fold 3/4, Epoch 17/19, Minibatch 0/0, Phase train, Running Loss train 129.14463806152344, Time 0.6750178337097168, Overall 2.889298677444458
# Fold 3/4, Epoch 17/19, Running Loss train 6.1497446695963545, Time 0.6752066612243652, Overall 2.889486074447632
# Fold 3/4, Epoch 17/19, Minibatch 0/0, Phase valid, Running Loss valid 95.59001922607422, Time 0.6910252571105957, Overall 2.905306100845337
# Fold 3/4, Epoch 17/19, Running Loss valid 19.118003845214844, Time 0.6912555694580078, Overall 2.9055356979370117
# Fold 3/4, Epoch 18/19, Minibatch 0/0, Phase train, Running Loss train 178.21202087402344, Time 0.7266786098480225, Overall 2.9409592151641846
# Fold 3/4, Epoch 18/19, Running Loss train 8.48628670828683, Time 0.7268812656402588, Overall 2.9411613941192627
# Fold 3/4, Epoch 18/19, Minibatch 0/0, Phase valid, Running Loss valid 64.885986328125, Time 0.7374417781829834, Overall 2.9517221450805664
# Fold 3/4, Epoch 18/19, Running Loss valid 12.977197265625, Time 0.7376761436462402, Overall 2.951956272125244
# Fold 3/4, Epoch 19/19, Minibatch 0/0, Phase train, Running Loss train 180.5430450439453, Time 0.7633419036865234, Overall 2.9776225090026855
# Fold 3/4, Epoch 19/19, Running Loss train 8.597287859235491, Time 0.7635071277618408, Overall 2.9777870178222656
# Fold 3/4, Epoch 19/19, Minibatch 0/0, Phase valid, Running Loss valid 74.89076232910156, Time 0.7729668617248535, Overall 2.9872477054595947
# Fold 3/4, Epoch 19/19, Running Loss valid 14.978152465820312, Time 0.7731788158416748, Overall 2.9874587059020996
# Fold 4/4, Epoch 0/19, Minibatch 0/0, Phase train, Running Loss train 304.0464172363281, Time 0.0248262882232666, Overall 3.0170929431915283
# Fold 4/4, Epoch 0/19, Running Loss train 14.47840082077753, Time 0.025527238845825195, Overall 3.017793893814087
# Fold 4/4, Epoch 0/19, Minibatch 0/0, Phase valid, Running Loss valid 79.32355499267578, Time 0.03743386268615723, Overall 3.0297012329101562
# Fold 4/4, Epoch 0/19, Running Loss valid 15.864710998535156, Time 0.037671804428100586, Overall 3.029938220977783
# Fold 4/4, Epoch 1/19, Minibatch 0/0, Phase train, Running Loss train 195.0017547607422, Time 0.06784534454345703, Overall 3.060112237930298
# Fold 4/4, Epoch 1/19, Running Loss train 9.285797845749627, Time 0.06803631782531738, Overall 3.060302734375
# Fold 4/4, Epoch 1/19, Minibatch 0/0, Phase valid, Running Loss valid 62.60430145263672, Time 0.07770442962646484, Overall 3.0699715614318848
# Fold 4/4, Epoch 1/19, Running Loss valid 12.520860290527343, Time 0.07792496681213379, Overall 3.0701913833618164
# Fold 4/4, Epoch 2/19, Minibatch 0/0, Phase train, Running Loss train 268.0081481933594, Time 0.10441374778747559, Overall 3.0966811180114746
# Fold 4/4, Epoch 2/19, Running Loss train 12.762292771112351, Time 0.104583740234375, Overall 3.0968496799468994
# Fold 4/4, Epoch 2/19, Minibatch 0/0, Phase valid, Running Loss valid 81.26580810546875, Time 0.1139383316040039, Overall 3.106205940246582
# Fold 4/4, Epoch 2/19, Running Loss valid 16.25316162109375, Time 0.11417388916015625, Overall 3.106440544128418
# Fold 4/4, Epoch 3/19, Minibatch 0/0, Phase train, Running Loss train 291.9178771972656, Time 0.14015531539916992, Overall 3.13242244720459
# Fold 4/4, Epoch 3/19, Running Loss train 13.900851295107888, Time 0.14032793045043945, Overall 3.132594347000122
# Fold 4/4, Epoch 3/19, Minibatch 0/0, Phase valid, Running Loss valid 51.71771240234375, Time 0.15111565589904785, Overall 3.143383026123047
# Fold 4/4, Epoch 3/19, Running Loss valid 10.34354248046875, Time 0.15134453773498535, Overall 3.143610954284668
# Fold 4/4, Epoch 4/19, Minibatch 0/0, Phase train, Running Loss train 251.9452667236328, Time 0.17725086212158203, Overall 3.169517755508423
# Fold 4/4, Epoch 4/19, Running Loss train 11.997393653506325, Time 0.17741942405700684, Overall 3.1696860790252686
# Fold 4/4, Epoch 4/19, Minibatch 0/0, Phase valid, Running Loss valid 144.49331665039062, Time 0.1870288848876953, Overall 3.1792960166931152
# Fold 4/4, Epoch 4/19, Running Loss valid 28.898663330078126, Time 0.18725371360778809, Overall 3.1795201301574707
# Fold 4/4, Epoch 5/19, Minibatch 0/0, Phase train, Running Loss train 257.832275390625, Time 0.21306228637695312, Overall 3.205329179763794
# Fold 4/4, Epoch 5/19, Running Loss train 12.277727399553571, Time 0.21324586868286133, Overall 3.205512285232544
# Fold 4/4, Epoch 5/19, Minibatch 0/0, Phase valid, Running Loss valid 91.52389526367188, Time 0.22205352783203125, Overall 3.214320659637451
# Fold 4/4, Epoch 5/19, Running Loss valid 18.304779052734375, Time 0.22225332260131836, Overall 3.214519739151001
# Fold 4/4, Epoch 6/19, Minibatch 0/0, Phase train, Running Loss train 247.73228454589844, Time 0.24831652641296387, Overall 3.2405834197998047
# Fold 4/4, Epoch 6/19, Running Loss train 11.796775454566593, Time 0.24933195114135742, Overall 3.2415990829467773
# Fold 4/4, Epoch 6/19, Minibatch 0/0, Phase valid, Running Loss valid 88.25796508789062, Time 0.25885677337646484, Overall 3.251124143600464
# Fold 4/4, Epoch 6/19, Running Loss valid 17.651593017578126, Time 0.2590920925140381, Overall 3.2513587474823
# Fold 4/4, Epoch 7/19, Minibatch 0/0, Phase train, Running Loss train 300.32623291015625, Time 0.29181981086730957, Overall 3.2840871810913086
# Fold 4/4, Epoch 7/19, Running Loss train 14.301249186197916, Time 0.29204225540161133, Overall 3.284308910369873
# Fold 4/4, Epoch 7/19, Minibatch 0/0, Phase valid, Running Loss valid 123.93193054199219, Time 0.30176639556884766, Overall 3.2940332889556885
# Fold 4/4, Epoch 7/19, Running Loss valid 24.78638610839844, Time 0.30199360847473145, Overall 3.294260025024414
# Fold 4/4, Epoch 8/19, Minibatch 0/0, Phase train, Running Loss train 257.3625793457031, Time 0.328336238861084, Overall 3.3206028938293457
# Fold 4/4, Epoch 8/19, Running Loss train 12.255360921223959, Time 0.32849645614624023, Overall 3.3207623958587646
# Fold 4/4, Epoch 8/19, Minibatch 0/0, Phase valid, Running Loss valid 88.41411590576172, Time 0.3382985591888428, Overall 3.3305654525756836
# Fold 4/4, Epoch 8/19, Running Loss valid 17.682823181152344, Time 0.3385133743286133, Overall 3.330779552459717
# Fold 4/4, Epoch 9/19, Minibatch 0/0, Phase train, Running Loss train 312.295654296875, Time 0.3668978214263916, Overall 3.3591644763946533
# Fold 4/4, Epoch 9/19, Running Loss train 14.871221633184524, Time 0.3670775890350342, Overall 3.359344005584717
# Fold 4/4, Epoch 9/19, Minibatch 0/0, Phase valid, Running Loss valid 89.19155883789062, Time 0.3763439655303955, Overall 3.3686108589172363
# Fold 4/4, Epoch 9/19, Running Loss valid 17.838311767578126, Time 0.37653350830078125, Overall 3.368800163269043
# Fold 4/4, Epoch 10/19, Minibatch 0/0, Phase train, Running Loss train 225.1287841796875, Time 0.40227580070495605, Overall 3.394543409347534
# Fold 4/4, Epoch 10/19, Running Loss train 10.720418294270834, Time 0.4024357795715332, Overall 3.3947019577026367
# Fold 4/4, Epoch 10/19, Minibatch 0/0, Phase valid, Running Loss valid 109.44303894042969, Time 0.4118356704711914, Overall 3.4041030406951904
# Fold 4/4, Epoch 10/19, Running Loss valid 21.888607788085938, Time 0.41210103034973145, Overall 3.404367685317993
# Fold 4/4, Epoch 11/19, Minibatch 0/0, Phase train, Running Loss train 281.5260009765625, Time 0.43842411041259766, Overall 3.4306912422180176
# Fold 4/4, Epoch 11/19, Running Loss train 13.406000046502976, Time 0.43858957290649414, Overall 3.4308559894561768
# Fold 4/4, Epoch 11/19, Minibatch 0/0, Phase valid, Running Loss valid 99.9771499633789, Time 0.4480137825012207, Overall 3.4402806758880615
# Fold 4/4, Epoch 11/19, Running Loss valid 19.99542999267578, Time 0.4482386112213135, Overall 3.440504550933838
# Fold 4/4, Epoch 12/19, Minibatch 0/0, Phase train, Running Loss train 277.36090087890625, Time 0.47563934326171875, Overall 3.4679067134857178
# Fold 4/4, Epoch 12/19, Running Loss train 13.207661946614584, Time 0.4758121967315674, Overall 3.4680778980255127
# Fold 4/4, Epoch 12/19, Minibatch 0/0, Phase valid, Running Loss valid 96.4022216796875, Time 0.48534297943115234, Overall 3.4776101112365723
# Fold 4/4, Epoch 12/19, Running Loss valid 19.2804443359375, Time 0.4855520725250244, Overall 3.477818250656128
# Fold 4/4, Epoch 13/19, Minibatch 0/0, Phase train, Running Loss train 169.27536010742188, Time 0.5114738941192627, Overall 3.5037412643432617
# Fold 4/4, Epoch 13/19, Running Loss train 8.060731433686756, Time 0.5116534233093262, Overall 3.5039196014404297
# Fold 4/4, Epoch 13/19, Minibatch 0/0, Phase valid, Running Loss valid 98.09268188476562, Time 0.5214524269104004, Overall 3.513719081878662
# Fold 4/4, Epoch 13/19, Running Loss valid 19.618536376953124, Time 0.5216798782348633, Overall 3.513946294784546
# Fold 4/4, Epoch 14/19, Minibatch 0/0, Phase train, Running Loss train 264.99285888671875, Time 0.5459351539611816, Overall 3.5382022857666016
# Fold 4/4, Epoch 14/19, Running Loss train 12.618707566034226, Time 0.5461153984069824, Overall 3.5383810997009277
# Fold 4/4, Epoch 14/19, Minibatch 0/0, Phase valid, Running Loss valid 82.72836303710938, Time 0.5564775466918945, Overall 3.5487453937530518
# Fold 4/4, Epoch 14/19, Running Loss valid 16.545672607421874, Time 0.5566959381103516, Overall 3.548962116241455
# Epoch 00015: reducing learning rate of group 0 to 5.0000e-02.
# Fold 4/4, Epoch 15/19, Minibatch 0/0, Phase train, Running Loss train 205.72140502929688, Time 0.5823788642883301, Overall 3.574646472930908
# Fold 4/4, Epoch 15/19, Running Loss train 9.79625738234747, Time 0.5825426578521729, Overall 3.5748088359832764
# Fold 4/4, Epoch 15/19, Minibatch 0/0, Phase valid, Running Loss valid 72.7471694946289, Time 0.5916540622711182, Overall 3.583921194076538
# Fold 4/4, Epoch 15/19, Running Loss valid 14.54943389892578, Time 0.5918490886688232, Overall 3.584115505218506
# Fold 4/4, Epoch 16/19, Minibatch 0/0, Phase train, Running Loss train 281.6154479980469, Time 0.6174228191375732, Overall 3.609689712524414
# Fold 4/4, Epoch 16/19, Running Loss train 13.410259428478422, Time 0.6175925731658936, Overall 3.609858989715576
# Fold 4/4, Epoch 16/19, Minibatch 0/0, Phase valid, Running Loss valid 75.54800415039062, Time 0.6271228790283203, Overall 3.619389772415161
# Fold 4/4, Epoch 16/19, Running Loss valid 15.109600830078126, Time 0.6273341178894043, Overall 3.619600296020508
# Fold 4/4, Epoch 17/19, Minibatch 0/0, Phase train, Running Loss train 250.3705291748047, Time 0.6557290554046631, Overall 3.647995948791504
# Fold 4/4, Epoch 17/19, Running Loss train 11.922406151181175, Time 0.6559181213378906, Overall 3.648183822631836
# Fold 4/4, Epoch 17/19, Minibatch 0/0, Phase valid, Running Loss valid 134.26356506347656, Time 0.6653482913970947, Overall 3.6576149463653564
# Fold 4/4, Epoch 17/19, Running Loss valid 26.85271301269531, Time 0.6655600070953369, Overall 3.6578264236450195
# Fold 4/4, Epoch 18/19, Minibatch 0/0, Phase train, Running Loss train 242.28924560546875, Time 0.6940605640411377, Overall 3.6863276958465576
# Fold 4/4, Epoch 18/19, Running Loss train 11.53758312406994, Time 0.6942358016967773, Overall 3.686502456665039
# Fold 4/4, Epoch 18/19, Minibatch 0/0, Phase valid, Running Loss valid 88.76190948486328, Time 0.7038204669952393, Overall 3.6960878372192383
# Fold 4/4, Epoch 18/19, Running Loss valid 17.752381896972658, Time 0.7040529251098633, Overall 3.696319580078125
# Fold 4/4, Epoch 19/19, Minibatch 0/0, Phase train, Running Loss train 192.0388641357422, Time 0.7315945625305176, Overall 3.7238616943359375
# Fold 4/4, Epoch 19/19, Running Loss train 9.144707815987724, Time 0.7317771911621094, Overall 3.724043369293213
# Fold 4/4, Epoch 19/19, Minibatch 0/0, Phase valid, Running Loss valid 85.37264251708984, Time 0.7443943023681641, Overall 3.736661195755005
# Fold 4/4, Epoch 19/19, Running Loss valid 17.07452850341797, Time 0.7446386814117432, Overall 3.736905097961426
# It took 3.739767551422119 to train the model.
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Traceback (most recent call last):
#   File "main.py", line 206, in <module>
#     run(data_list=args.data_list,
#   File "main.py", line 163, in run
#     m_obj.run(splits, vecs_, indexes, f'{output_path}', settings['model']['baseline'][baseline_name], settings['model']['cmd'], settings['fair'], merge_skills=False)
#   File "/content/opentf/src/mdl/ntf.py", line 139, in run
#     if 'test' in cmd: self.test(output, splits, indexes, vecs, settings, on_train_valid_set, per_epoch, merge_skills)
# TypeError: test() takes from 6 to 8 positional arguments but 9 were given

# %%
# !ls ../output/toy.dblp.v12.json/

# %%
# !ls ../output/toy.dblp.v12.json/tbnn_emb/t31.s100.m13.l[128].lr0.1.b4.e20.nns3.nsunigram_b.s1
# !ls ../output/toy.dblp.v12.json/tbnn_emb/t31.s100.m13.l[128].lr0.1.b4.e20.nns3.nsunigram_b.s1/2004

# %%
from IPython.display import Image
Image('../output/toy.dblp.v12.json/tbnn_emb/t31.s100.m13.l[128].lr0.1.b4.e20.nns3.nsunigram_b.s1/2004/test.roc.png')

# %%
import pandas as pd
pd.read_csv('../output/toy.dblp.v12.json/tbnn_emb/t31.s100.m13.l[128].lr0.1.b4.e20.nns3.nsunigram_b.s1/2004/test.pred.eval.mean.csv', index_col = 0)
