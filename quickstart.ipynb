# %%
# !sudo apt-get update -y
# !sudo apt-get install python3.8
# !python --version
# !sudo apt-get install python3-pip
# !python -m pip install --upgrade pip
# !ln -sf /usr/bin/python3.8 /usr/bin/python3
# !python --version
# Out:
# Hit:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:4 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Hit:5 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:6 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Hit:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Get:9 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Hit:10 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Hit:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Get:12 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [2,529 kB]
# Get:13 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [2,866 kB]
# Get:14 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [37.5 kB]
# Get:15 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1,070 kB]
# Get:16 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ Packages [82.8 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [40.3 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1,369 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3,346 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [2,671 kB]
# Fetched 14.4 MB in 2s (6,938 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3.8 is already the newest version (3.8.10-0ubuntu1~20.04.8).
# python3.8 set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.
# Python 3.10.12
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   python-pip-whl python3-setuptools python3-wheel
# Suggested packages:
#   python-setuptools-doc
# The following NEW packages will be installed:
#   python-pip-whl python3-pip python3-setuptools python3-wheel
# 0 upgraded, 4 newly installed, 0 to remove and 19 not upgraded.
# Need to get 2,389 kB of archives.
# After this operation, 4,933 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python-pip-whl all 20.0.2-5ubuntu1.9 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-setuptools all 45.2.0-1ubuntu0.1 [330 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-wheel all 0.34.2-1ubuntu0.1 [23.9 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-pip all 20.0.2-5ubuntu1.9 [231 kB]
# Fetched 2,389 kB in 0s (17.2 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 4.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package python-pip-whl.
# (Reading database ... 123105 files and directories currently installed.)
# Preparing to unpack .../python-pip-whl_20.0.2-5ubuntu1.9_all.deb ...
# Unpacking python-pip-whl (20.0.2-5ubuntu1.9) ...
# Selecting previously unselected package python3-setuptools.
# Preparing to unpack .../python3-setuptools_45.2.0-1ubuntu0.1_all.deb ...
# Unpacking python3-setuptools (45.2.0-1ubuntu0.1) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../python3-wheel_0.34.2-1ubuntu0.1_all.deb ...
# Unpacking python3-wheel (0.34.2-1ubuntu0.1) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../python3-pip_20.0.2-5ubuntu1.9_all.deb ...
# Unpacking python3-pip (20.0.2-5ubuntu1.9) ...
# Setting up python3-setuptools (45.2.0-1ubuntu0.1) ...
# Setting up python3-wheel (0.34.2-1ubuntu0.1) ...
# Setting up python-pip-whl (20.0.2-5ubuntu1.9) ...
# Setting up python3-pip (20.0.2-5ubuntu1.9) ...
# Processing triggers for man-db (2.9.1-1) ...
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (23.1.2)
# Python 3.8.10

# %%
# %rm -R opentf/
# !git clone --recursive https://github.com/Fani-Lab/opentf
# %cd opentf
# !pip install virtualenv
# !virtualenv opentf
# !opentf/bin/pip install -r requirements.txt
# !opentf/bin/pip install ipykernel
import sys
sys.path.append("opentf/lib/python3.8/site-packages")
# %cd src/
# Out:
# rm: cannot remove 'opentf/': No such file or directory
# Cloning into 'opentf'...
# remote: Enumerating objects: 6628, done.
# remote: Counting objects: 100% (1625/1625), done.
# remote: Compressing objects: 100% (1116/1116), done.
# remote: Total 6628 (delta 581), reused 1455 (delta 497), pack-reused 5003
# Receiving objects: 100% (6628/6628), 110.81 MiB | 14.61 MiB/s, done.
# Resolving deltas: 100% (2692/2692), done.
# Updating files: 100% (1745/1745), done.
# Submodule 'src/Adila' (https://github.com/fani-lab/Adila.git) registered for path 'src/Adila'
# Cloning into '/content/opentf/src/Adila'...
# remote: Enumerating objects: 778, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 778 (delta 62), reused 33 (delta 14), pack-reused 670
# Receiving objects: 100% (778/778), 16.72 MiB | 16.79 MiB/s, done.
# Resolving deltas: 100% (348/348), done.
# Submodule path 'src/Adila': checked out 'ed7b732ab165177f652a49d6fbf1fa033cfb008e'
# /content/opentf
# Collecting virtualenv
#   Downloading virtualenv-20.23.1-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 13.1 MB/s
# Collecting platformdirs<4,>=3.5.1
#   Downloading platformdirs-3.8.1-py3-none-any.whl (16 kB)
# Collecting filelock<4,>=3.12
#   Downloading filelock-3.12.2-py3-none-any.whl (10 kB)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      |████████████████████████████████| 468 kB 66.9 MB/s
# Installing collected packages: platformdirs, filelock, distlib, virtualenv
# Successfully installed distlib-0.3.6 filelock-3.12.2 platformdirs-3.8.1 virtualenv-20.23.1
# created virtual environment CPython3.8.10.final.0-64 in 864ms
#   creator CPython3Posix(dest=/content/opentf/opentf, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==23.1.2, setuptools==67.8.0, wheel==0.40.0
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator
# Collecting torch>=1.9.0 (from -r requirements.txt (line 1))
#   Downloading torch-2.0.1-cp38-cp38-manylinux1_x86_64.whl (619.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 1.1 MB/s eta 0:00:00
# Collecting scipy==1.9.3 (from -r requirements.txt (line 2))
#   Downloading scipy-1.9.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 43.0 MB/s eta 0:00:00
# Collecting numpy==1.20.3 (from -r requirements.txt (line 3))
#   Downloading numpy-1.20.3-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 82.6 MB/s eta 0:00:00
# Collecting tqdm==4.60.0 (from -r requirements.txt (line 4))
#   Downloading tqdm-4.60.0-py2.py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.8/75.8 kB 6.6 MB/s eta 0:00:00
# Collecting PyYAML==5.4 (from -r requirements.txt (line 5))
#   Downloading PyYAML-5.4-cp38-cp38-manylinux1_x86_64.whl (662 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.2/662.2 kB 4.6 MB/s eta 0:00:00
# Collecting scikit_learn==0.24.2 (from -r requirements.txt (line 6))
#   Downloading scikit_learn-0.24.2-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 63.6 MB/s eta 0:00:00
# Collecting pandas==1.3.3 (from -r requirements.txt (line 7))
#   Downloading pandas-1.3.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 79.6 MB/s eta 0:00:00
# Collecting gensim==3.8.3 (from -r requirements.txt (line 8))
#   Downloading gensim-3.8.3-cp38-cp38-manylinux1_x86_64.whl (24.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 38.9 MB/s eta 0:00:00
# Collecting pytrec-eval-terrier==0.5.2 (from -r requirements.txt (line 9))
#   Downloading pytrec_eval_terrier-0.5.2-cp38-cp38-manylinux2010_x86_64.whl (287 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.4/287.4 kB 33.8 MB/s eta 0:00:00
# Collecting matplotlib==3.4.2 (from -r requirements.txt (line 10))
#   Downloading matplotlib-3.4.2-cp38-cp38-manylinux1_x86_64.whl (10.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 116.4 MB/s eta 0:00:00
# Collecting OpenNMT-py==2.2.0 (from -r requirements.txt (line 11))
#   Downloading OpenNMT_py-2.2.0-py3-none-any.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.8/216.8 kB 22.9 MB/s eta 0:00:00
# Collecting reranking==0.3.6 (from -r requirements.txt (line 12))
#   Downloading reranking-0.3.6-py3-none-any.whl (17 kB)
# Collecting python-dateutil==2.8.2 (from -r requirements.txt (line 14))
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 30.8 MB/s eta 0:00:00
# Collecting joblib>=0.11 (from scikit_learn==0.24.2->-r requirements.txt (line 6))
#   Downloading joblib-1.3.1-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 30.7 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0 (from scikit_learn==0.24.2->-r requirements.txt (line 6))
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting pytz>=2017.3 (from pandas==1.3.3->-r requirements.txt (line 7))
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.3/502.3 kB 41.6 MB/s eta 0:00:00
# Collecting six>=1.5.0 (from gensim==3.8.3->-r requirements.txt (line 8))
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting smart-open>=1.8.1 (from gensim==3.8.3->-r requirements.txt (line 8))
#   Downloading smart_open-6.3.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 7.0 MB/s eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib==3.4.2->-r requirements.txt (line 10))
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib==3.4.2->-r requirements.txt (line 10))
#   Downloading kiwisolver-1.4.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 64.3 MB/s eta 0:00:00
# Collecting pillow>=6.2.0 (from matplotlib==3.4.2->-r requirements.txt (line 10))
#   Downloading Pillow-10.0.0-cp38-cp38-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 75.6 MB/s eta 0:00:00
# Collecting pyparsing>=2.2.1 (from matplotlib==3.4.2->-r requirements.txt (line 10))
#   Downloading pyparsing-3.1.0-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 kB 7.5 MB/s eta 0:00:00
# Collecting torchtext==0.5.0 (from OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading torchtext-0.5.0-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 9.1 MB/s eta 0:00:00
# Collecting configargparse (from OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading ConfigArgParse-1.5.5-py3-none-any.whl (25 kB)
# Collecting tensorboard>=2.3 (from OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 60.7 MB/s eta 0:00:00
# Collecting flask (from OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading Flask-2.3.2-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 12.3 MB/s eta 0:00:00
# Collecting waitress (from OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading waitress-2.1.2-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.8 MB/s eta 0:00:00
# Collecting pyonmttok<2,>=1.23 (from OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading pyonmttok-1.37.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 7.9 MB/s eta 0:00:00
# Collecting requests (from torchtext==0.5.0->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 8.4 MB/s eta 0:00:00
# Collecting sentencepiece (from torchtext==0.5.0->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading sentencepiece-0.1.99-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 81.3 MB/s eta 0:00:00
# Collecting filelock (from torch>=1.9.0->-r requirements.txt (line 1))
#   Using cached filelock-3.12.2-py3-none-any.whl (10 kB)
# Collecting typing-extensions (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting sympy (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 100.7 MB/s eta 0:00:00
# Collecting networkx (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 95.7 MB/s eta 0:00:00
# Collecting jinja2 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 18.9 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 71.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 69.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 107.4 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.9 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 2.5 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 5.6 MB/s eta 0:00:00
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 11.9 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 7.5 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 1.5 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu11==2.14.3 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 2.1 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 11.3 MB/s eta 0:00:00
# Collecting triton==2.0.0 (from torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading triton-2.0.0-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.2/63.2 MB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in ./opentf/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.9.0->-r requirements.txt (line 1)) (67.8.0)
# Requirement already satisfied: wheel in ./opentf/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.9.0->-r requirements.txt (line 1)) (0.40.0)
# Collecting cmake (from triton==2.0.0->torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading cmake-3.26.4-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (24.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 59.8 MB/s eta 0:00:00
# Collecting lit (from triton==2.0.0->torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading lit-16.0.6.tar.gz (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.7/153.7 kB 17.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting absl-py>=0.4 (from tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 15.7 MB/s eta 0:00:00
# Collecting grpcio>=1.48.2 (from tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading grpcio-1.56.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 67.8 MB/s eta 0:00:00
# Collecting google-auth<3,>=1.6.3 (from tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading google_auth-2.21.0-py2.py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.1/182.1 kB 21.0 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8 (from tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading Markdown-3.4.3-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 kB 12.0 MB/s eta 0:00:00
# Collecting protobuf>=3.19.6 (from tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 26.5 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading tensorboard_data_server-0.7.1-py3-none-manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 64.5 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1 (from tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading Werkzeug-2.3.6-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 27.7 MB/s eta 0:00:00
# Collecting itsdangerous>=2.1.2 (from flask->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting click>=8.1.3 (from flask->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading click-8.1.4-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 11.5 MB/s eta 0:00:00
# Collecting blinker>=1.6.2 (from flask->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Collecting importlib-metadata>=3.6.0 (from flask->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading importlib_metadata-6.7.0-py3-none-any.whl (22 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading MarkupSafe-2.1.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting mpmath>=0.19 (from sympy->torch>=1.9.0->-r requirements.txt (line 1))
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 27.9 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 22.2 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting urllib3<2.0 (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 18.0 MB/s eta 0:00:00
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting zipp>=0.5 (from importlib-metadata>=3.6.0->flask->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Collecting charset-normalizer<4,>=2 (from requests->torchtext==0.5.0->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading charset_normalizer-3.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.9/195.9 kB 22.4 MB/s eta 0:00:00
# Collecting idna<4,>=2.5 (from requests->torchtext==0.5.0->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 8.0 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17 (from requests->torchtext==0.5.0->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading certifi-2023.5.7-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.0/157.0 kB 20.1 MB/s eta 0:00:00
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 11.1 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.3->OpenNMT-py==2.2.0->-r requirements.txt (line 11))
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 17.2 MB/s eta 0:00:00
# Building wheels for collected packages: lit
#   Building wheel for lit (pyproject.toml) ... done
#   Created wheel for lit: filename=lit-16.0.6-py3-none-any.whl size=93582 sha256=aa4fb6f2f26770badb0e0705a36f1c3f387f6324bef45d4ddbbd05b63a607d77
#   Stored in directory: /root/.cache/pip/wheels/05/ab/f1/0102fea49a41c753f0e79a1a4012417d5d7ef0f93224694472
# Successfully built lit
# Installing collected packages: sentencepiece, pytz, mpmath, lit, cmake, zipp, waitress, urllib3, typing-extensions, tqdm, threadpoolctl, tensorboard-data-server, sympy, smart-open, six, reranking, PyYAML, pytrec-eval-terrier, pyparsing, pyonmttok, pyasn1, protobuf, pillow, oauthlib, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, numpy, networkx, MarkupSafe, kiwisolver, joblib, itsdangerous, idna, grpcio, filelock, cycler, configargparse, click, charset-normalizer, certifi, cachetools, blinker, absl-py, werkzeug, scipy, rsa, requests, python-dateutil, pyasn1-modules, nvidia-cusolver-cu11, nvidia-cudnn-cu11, jinja2, importlib-metadata, scikit_learn, requests-oauthlib, pandas, matplotlib, markdown, google-auth, gensim, flask, google-auth-oauthlib, tensorboard, triton, torch, torchtext, OpenNMT-py
# Successfully installed MarkupSafe-2.1.3 OpenNMT-py-2.2.0 PyYAML-5.4 absl-py-1.4.0 blinker-1.6.2 cachetools-5.3.1 certifi-2023.5.7 charset-normalizer-3.1.0 click-8.1.4 cmake-3.26.4 configargparse-1.5.5 cycler-0.11.0 filelock-3.12.2 flask-2.3.2 gensim-3.8.3 google-auth-2.21.0 google-auth-oauthlib-1.0.0 grpcio-1.56.0 idna-3.4 importlib-metadata-6.7.0 itsdangerous-2.1.2 jinja2-3.1.2 joblib-1.3.1 kiwisolver-1.4.4 lit-16.0.6 markdown-3.4.3 matplotlib-3.4.2 mpmath-1.3.0 networkx-3.1 numpy-1.20.3 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 oauthlib-3.2.2 pandas-1.3.3 pillow-10.0.0 protobuf-4.23.4 pyasn1-0.5.0 pyasn1-modules-0.3.0 pyonmttok-1.37.1 pyparsing-3.1.0 python-dateutil-2.8.2 pytrec-eval-terrier-0.5.2 pytz-2023.3 requests-2.31.0 requests-oauthlib-1.3.1 reranking-0.3.6 rsa-4.9 scikit_learn-0.24.2 scipy-1.9.3 sentencepiece-0.1.99 six-1.16.0 smart-open-6.3.0 sympy-1.12 tensorboard-2.13.0 tensorboard-data-server-0.7.1 threadpoolctl-3.1.0 torch-2.0.1 torchtext-0.5.0 tqdm-4.60.0 triton-2.0.0 typing-extensions-4.7.1 urllib3-1.26.16 waitress-2.1.2 werkzeug-2.3.6 zipp-3.15.0
# Collecting ipykernel
#   Downloading ipykernel-6.24.0-py3-none-any.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.8/152.8 kB 6.7 MB/s eta 0:00:00
# Collecting comm>=0.1.1 (from ipykernel)
#   Downloading comm-0.1.3-py3-none-any.whl (6.6 kB)
# Collecting debugpy>=1.6.5 (from ipykernel)
#   Downloading debugpy-1.6.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 55.8 MB/s eta 0:00:00
# Collecting ipython>=7.23.1 (from ipykernel)
#   Downloading ipython-8.12.2-py3-none-any.whl (797 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.8/797.8 kB 48.5 MB/s eta 0:00:00
# Collecting jupyter-client>=6.1.12 (from ipykernel)
#   Downloading jupyter_client-8.3.0-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 13.1 MB/s eta 0:00:00
# Collecting jupyter-core!=5.0.*,>=4.12 (from ipykernel)
#   Downloading jupyter_core-5.3.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.7/93.7 kB 9.9 MB/s eta 0:00:00
# Collecting matplotlib-inline>=0.1 (from ipykernel)
#   Downloading matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# Collecting nest-asyncio (from ipykernel)
#   Downloading nest_asyncio-1.5.6-py3-none-any.whl (5.2 kB)
# Collecting packaging (from ipykernel)
#   Downloading packaging-23.1-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 5.6 MB/s eta 0:00:00
# Collecting psutil (from ipykernel)
#   Downloading psutil-5.9.5-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (282 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.1/282.1 kB 23.8 MB/s eta 0:00:00
# Collecting pyzmq>=20 (from ipykernel)
#   Downloading pyzmq-25.1.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 65.7 MB/s eta 0:00:00
# Collecting tornado>=6.1 (from ipykernel)
#   Downloading tornado-6.3.2-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (426 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.9/426.9 kB 41.7 MB/s eta 0:00:00
# Collecting traitlets>=5.4.0 (from ipykernel)
#   Downloading traitlets-5.9.0-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.4/117.4 kB 14.8 MB/s eta 0:00:00
# Collecting backcall (from ipython>=7.23.1->ipykernel)
#   Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting decorator (from ipython>=7.23.1->ipykernel)
#   Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel)
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 78.6 MB/s eta 0:00:00
# Collecting pickleshare (from ipython>=7.23.1->ipykernel)
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 (from ipython>=7.23.1->ipykernel)
#   Downloading prompt_toolkit-3.0.39-py3-none-any.whl (385 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.2/385.2 kB 39.8 MB/s eta 0:00:00
# Collecting pygments>=2.4.0 (from ipython>=7.23.1->ipykernel)
#   Downloading Pygments-2.15.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 61.6 MB/s eta 0:00:00
# Collecting stack-data (from ipython>=7.23.1->ipykernel)
#   Downloading stack_data-0.6.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: typing-extensions in ./opentf/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel) (4.7.1)
# Collecting pexpect>4.3 (from ipython>=7.23.1->ipykernel)
#   Downloading pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=4.8.3 in ./opentf/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel) (6.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./opentf/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Collecting platformdirs>=2.5 (from jupyter-core!=5.0.*,>=4.12->ipykernel)
#   Using cached platformdirs-3.8.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: zipp>=0.5 in ./opentf/lib/python3.8/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel) (3.15.0)
# Collecting parso<0.9.0,>=0.8.0 (from jedi>=0.16->ipython>=7.23.1->ipykernel)
#   Downloading parso-0.8.3-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 12.3 MB/s eta 0:00:00
# Collecting ptyprocess>=0.5 (from pexpect>4.3->ipython>=7.23.1->ipykernel)
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting wcwidth (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel)
#   Downloading wcwidth-0.2.6-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: six>=1.5 in ./opentf/lib/python3.8/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Collecting executing>=1.2.0 (from stack-data->ipython>=7.23.1->ipykernel)
#   Downloading executing-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting asttokens>=2.1.0 (from stack-data->ipython>=7.23.1->ipykernel)
#   Downloading asttokens-2.2.1-py2.py3-none-any.whl (26 kB)
# Collecting pure-eval (from stack-data->ipython>=7.23.1->ipykernel)
#   Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Installing collected packages: wcwidth, pure-eval, ptyprocess, pickleshare, executing, backcall, traitlets, tornado, pyzmq, pygments, psutil, prompt-toolkit, platformdirs, pexpect, parso, packaging, nest-asyncio, decorator, debugpy, asttokens, stack-data, matplotlib-inline, jupyter-core, jedi, comm, jupyter-client, ipython, ipykernel
# Successfully installed asttokens-2.2.1 backcall-0.2.0 comm-0.1.3 debugpy-1.6.7 decorator-5.1.1 executing-1.2.0 ipykernel-6.24.0 ipython-8.12.2 jedi-0.18.2 jupyter-client-8.3.0 jupyter-core-5.3.1 matplotlib-inline-0.1.6 nest-asyncio-1.5.6 packaging-23.1 parso-0.8.3 pexpect-4.8.0 pickleshare-0.7.5 platformdirs-3.8.1 prompt-toolkit-3.0.39 psutil-5.9.5 ptyprocess-0.7.0 pure-eval-0.2.2 pygments-2.15.1 pyzmq-25.1.0 stack-data-0.6.2 tornado-6.3.2 traitlets-5.9.0 wcwidth-0.2.6
# /content/opentf/src

# %%
#!apt-get install --assume-yes p7zip-full
#!wget -O ../data/raw/imdb/name.basics.tsv.gz https://datasets.imdbws.com/name.basics.tsv.gz
#!wget -O ../data/raw/imdb/title.basics.tsv.gz https://datasets.imdbws.com/title.basics.tsv.gz
#!wget -O ../data/raw/imdb/title.principals.tsv.gz https://datasets.imdbws.com/title.principals.tsv.gz
#!7z e ../data/raw/imdb/name.basics.tsv.gz -o../data/raw/imdb/
#!mv ../data/raw/imdb/data.tsv ../data/raw/imdb/name.basics.tsv
#!7z e ../data/raw/imdb/title.basics.tsv.gz -o../data/raw/imdb/
#!mv ../data/raw/imdb/data.tsv ../data/raw/imdb/title.basics.tsv
#!7z e ../data/raw/imdb/title.principals.tsv.gz -o../data/raw/imdb/
#!mv ../data/raw/imdb/data.tsv ../data/raw/imdb/title.principals.tsv

# %%
#!apt-get install --assume-yes p7zip-full
#!wget -O ../data/raw/dblp/dblp.v12.7z https://originalstatic.aminer.cn/misc/dblp.v12.7z
#!7z e ../data/raw/dblp/dblp.v12.7z -o../data/raw/dblp/

# %%
# !cat param.py
# Out:
# import random
# import torch
# import numpy as np
#
# random.seed(0)
# torch.manual_seed(0)
# torch.cuda.manual_seed_all(0)
#
# np.random.seed(0)
#
# settings = {
#     'model':{
#         'baseline': {
#             'random': {
#                 'b': 128
#             },
#             'fnn':{
#                 'l': [128],  # list of number of nodes in each layer
#                 'lr': 0.1,  # learning rate
#                 'b': 128,  # batch size
#                 'e': 20,  # epoch
#                 'nns': 3,  # number of negative samples
#                 'ns': 'unigram_b',  # 'uniform', 'unigram', 'unigram_b'
#             },
#             'bnn':{
#                 'l': [128],  # list of number of nodes in each layer
#                 'lr': 0.1,  # learning rate
#                 'b': 128,  # batch size
#                 'e': 20,  # epoch
#                 'nns': 3,  # number of negative samples
#                 'ns': 'unigram_b',  # 'uniform', 'unigram', 'unigram_b'
#                 's': 1  # # sample_elbo for bnn
#             },
#             'nmt': {
#                 'base_config': './mdl/nmt_config.yaml'
#             },
#             'caser': {},
#             'rrn': {
#                 'with_zero': True
#             },
#             'emb':{
#                 'd': 100,# embedding dimension
#                 'e': 100,# epoch
#                 'dm': 1,# training algorithm. 1: distributed memory (PV-DM), 0: distributed bag of words (PV-DBOW)
#                 'w': 1 #cooccurrence window
#             }
#         },
#         'cmd': ['train', 'test', 'eval', 'fair'],  # 'train', 'test', 'eval', 'plot', 'agg', 'adila'
#         'nfolds': 5,
#         'train_test_split': 0.85,
#         'step_ahead': 2,#for now, it means that whatever are in the last [step_ahead] time interval will be the test set!
#     },
#     'data':{
#         'domain': {
#             'dblp':{},
#             'uspt':{},
#             'imdb':{},
#         },
#         'location_type': 'country', #should be one of 'city', 'state', 'country' and represents the location of members in teams (not the location of teams)
#         'filter': {
#             'min_nteam': 75,
#             'min_team_size': 3,
#         },
#         'parallel': 1,
#         'ncore': 0,# <= 0 for all
#         'bucket_size': 500
#     },
#     'fair': {'np_ratio': None,
#               'fairness': ['det_greedy',],
#               'k_max': None,
#               'fairness_metrics': {'ndkl'},
#               'utility_metrics': {'map_cut_2,5,10'},
#               'eq_op': False,
#               'mode': 0,
#               'core': -1,
#               'attribute': ['gender', 'popularity']},
# }

# %%
# !rm -R ../data/preprocessed/dblp/toy.dblp.v12.json/
# !rm -R ../data/preprocessed/imdb/toy.title.basics.tsv/
# !rm -R ../data/preprocessed/uspt/toy.patent.tsv/

# %%
# %ls
# Out:
# Adila/  computecanada.sh  main.py  misc/     readme.md
# cmn/    eval/             mdl/     param.py

# %%
# !../opentf/bin/python3 main.py -data ../data/raw/dblp/toy.dblp.v12.json -domain dblp -model fnn bnn -fairness det_greedy -attribute popularity
# Out:
# Loading sparse matrices from ./../data/preprocessed/dblp/toy.dblp.v12.json/teamsvecs.pkl ...
# File not found! Generating the sparse matrices ...
# Loading indexes pickle from ./../data/preprocessed/dblp/toy.dblp.v12.json/indexes.pkl ...
# Pickles not found! Reading raw data from ../data/raw/dblp/toy.dblp.v12.json (progress in bytes) ...
#   0% 0/46688 [00:00<?, ?it/s]JSONDecodeError: There has been error in loading json line `[
# `!
# Expecting value: line 2 column 1 (char 2)
# JSONDecodeError: There has been error in loading json line `]`!
# Expecting value: line 1 column 1 (char 0)
# 100% 46664/46688 [00:00<00:00, 4585502.47it/s]
# Indexing members ...
# Indexing skills ...
# Indexing teams ...
# Indexing locations ...
# Indexing teams date (year) ...
# It took 0.000797271728515625 seconds to pickle the data into ./../data/preprocessed/dblp/toy.dblp.v12.json
# It took 0.07131552696228027 seconds to generate and store the sparse matrices of size (31, 53) at ./../data/preprocessed/dblp/toy.dblp.v12.json/teamsvecs.pkl
# Running for (dataset, model): (dblp, fnn) ...
# Fold 0/4, Epoch 0/19, Minibatch 0/0, Phase train, Running Loss train 62.71426010131836, Time 0.023291826248168945, Overall 0.027387142181396484
# Fold 0/4, Epoch 0/19, Running Loss train 3.135713005065918, Time 0.02346205711364746, Overall 0.027556180953979492
# Fold 0/4, Epoch 0/19, Minibatch 0/0, Phase valid, Running Loss valid 13.493390083312988, Time 0.02841019630432129, Overall 0.03250479698181152
# Fold 0/4, Epoch 0/19, Running Loss valid 2.2488983472188315, Time 0.028549671173095703, Overall 0.032644033432006836
# Fold 0/4, Epoch 1/19, Minibatch 0/0, Phase train, Running Loss train 56.81795883178711, Time 0.044690847396850586, Overall 0.04878711700439453
# Fold 0/4, Epoch 1/19, Running Loss train 2.8408979415893554, Time 0.04482150077819824, Overall 0.04891562461853027
# Fold 0/4, Epoch 1/19, Minibatch 0/0, Phase valid, Running Loss valid 14.17101001739502, Time 0.04969668388366699, Overall 0.05379152297973633
# Fold 0/4, Epoch 1/19, Running Loss valid 2.36183500289917, Time 0.04983353614807129, Overall 0.053926944732666016
# Fold 0/4, Epoch 2/19, Minibatch 0/0, Phase train, Running Loss train 44.24309158325195, Time 0.0663306713104248, Overall 0.07042551040649414
# Fold 0/4, Epoch 2/19, Running Loss train 2.212154579162598, Time 0.06648659706115723, Overall 0.07058072090148926
# Fold 0/4, Epoch 2/19, Minibatch 0/0, Phase valid, Running Loss valid 19.75441551208496, Time 0.0720522403717041, Overall 0.07614684104919434
# Fold 0/4, Epoch 2/19, Running Loss valid 3.2924025853474936, Time 0.07219958305358887, Overall 0.0762934684753418
# Fold 0/4, Epoch 3/19, Minibatch 0/0, Phase train, Running Loss train 29.45379066467285, Time 0.0910179615020752, Overall 0.09511327743530273
# Fold 0/4, Epoch 3/19, Running Loss train 1.4726895332336425, Time 0.09116387367248535, Overall 0.09525799751281738
# Fold 0/4, Epoch 3/19, Minibatch 0/0, Phase valid, Running Loss valid 23.601545333862305, Time 0.09623193740844727, Overall 0.1003270149230957
# Fold 0/4, Epoch 3/19, Running Loss valid 3.933590888977051, Time 0.09640216827392578, Overall 0.10049605369567871
# Fold 0/4, Epoch 4/19, Minibatch 0/0, Phase train, Running Loss train 23.174551010131836, Time 0.11269807815551758, Overall 0.11679315567016602
# Fold 0/4, Epoch 4/19, Running Loss train 1.1587275505065917, Time 0.1128530502319336, Overall 0.11694717407226562
# Fold 0/4, Epoch 4/19, Minibatch 0/0, Phase valid, Running Loss valid 25.024845123291016, Time 0.11773109436035156, Overall 0.1218254566192627
# Fold 0/4, Epoch 4/19, Running Loss valid 4.170807520548503, Time 0.11786270141601562, Overall 0.12195682525634766
# Fold 0/4, Epoch 5/19, Minibatch 0/0, Phase train, Running Loss train 27.327308654785156, Time 0.13366174697875977, Overall 0.1377565860748291
# Fold 0/4, Epoch 5/19, Running Loss train 1.3663654327392578, Time 0.13380742073059082, Overall 0.13790154457092285
# Fold 0/4, Epoch 5/19, Minibatch 0/0, Phase valid, Running Loss valid 26.28115463256836, Time 0.13866376876831055, Overall 0.14275813102722168
# Fold 0/4, Epoch 5/19, Running Loss valid 4.3801924387613935, Time 0.13880085945129395, Overall 0.14289450645446777
# Fold 0/4, Epoch 6/19, Minibatch 0/0, Phase train, Running Loss train 16.219404220581055, Time 0.15802836418151855, Overall 0.162123441696167
# Fold 0/4, Epoch 6/19, Running Loss train 0.8109702110290528, Time 0.15840554237365723, Overall 0.16249966621398926
# Fold 0/4, Epoch 6/19, Minibatch 0/0, Phase valid, Running Loss valid 30.575420379638672, Time 0.16352248191833496, Overall 0.1676170825958252
# Fold 0/4, Epoch 6/19, Running Loss valid 5.095903396606445, Time 0.16365504264831543, Overall 0.16774868965148926
# Fold 0/4, Epoch 7/19, Minibatch 0/0, Phase train, Running Loss train 18.457120895385742, Time 0.18178224563598633, Overall 0.18587756156921387
# Fold 0/4, Epoch 7/19, Running Loss train 0.9228560447692871, Time 0.1819312572479248, Overall 0.18602514266967773
# Fold 0/4, Epoch 7/19, Minibatch 0/0, Phase valid, Running Loss valid 31.59212303161621, Time 0.1870584487915039, Overall 0.19115328788757324
# Fold 0/4, Epoch 7/19, Running Loss valid 5.265353838602702, Time 0.18720316886901855, Overall 0.1912975311279297
# Fold 0/4, Epoch 8/19, Minibatch 0/0, Phase train, Running Loss train 20.644256591796875, Time 0.20476245880126953, Overall 0.20885777473449707
# Fold 0/4, Epoch 8/19, Running Loss train 1.0322128295898438, Time 0.2049083709716797, Overall 0.20900273323059082
# Fold 0/4, Epoch 8/19, Minibatch 0/0, Phase valid, Running Loss valid 30.48838996887207, Time 0.2098691463470459, Overall 0.21396374702453613
# Fold 0/4, Epoch 8/19, Running Loss valid 5.081398328145345, Time 0.2100074291229248, Overall 0.21410131454467773
# Fold 0/4, Epoch 9/19, Minibatch 0/0, Phase train, Running Loss train 19.780677795410156, Time 0.22650909423828125, Overall 0.23060393333435059
# Fold 0/4, Epoch 9/19, Running Loss train 0.9890338897705078, Time 0.22666144371032715, Overall 0.23075532913208008
# Fold 0/4, Epoch 9/19, Minibatch 0/0, Phase valid, Running Loss valid 30.420711517333984, Time 0.23180723190307617, Overall 0.2359018325805664
# Fold 0/4, Epoch 9/19, Running Loss valid 5.070118586222331, Time 0.23195672035217285, Overall 0.23605060577392578
# Fold 0/4, Epoch 10/19, Minibatch 0/0, Phase train, Running Loss train 9.82799243927002, Time 0.24846291542053223, Overall 0.25255846977233887
# Fold 0/4, Epoch 10/19, Running Loss train 0.49139962196350095, Time 0.24860620498657227, Overall 0.2527003288269043
# Fold 0/4, Epoch 10/19, Minibatch 0/0, Phase valid, Running Loss valid 40.203880310058594, Time 0.25382018089294434, Overall 0.25791501998901367
# Fold 0/4, Epoch 10/19, Running Loss valid 6.700646718343099, Time 0.25398874282836914, Overall 0.25808262825012207
# Fold 0/4, Epoch 11/19, Minibatch 0/0, Phase train, Running Loss train 18.801475524902344, Time 0.27049922943115234, Overall 0.2745943069458008
# Fold 0/4, Epoch 11/19, Running Loss train 0.9400737762451172, Time 0.27065277099609375, Overall 0.2747471332550049
# Fold 0/4, Epoch 11/19, Minibatch 0/0, Phase valid, Running Loss valid 30.595874786376953, Time 0.2756679058074951, Overall 0.27976250648498535
# Fold 0/4, Epoch 11/19, Running Loss valid 5.099312464396159, Time 0.27583932876586914, Overall 0.27993297576904297
# Epoch 00012: reducing learning rate of group 0 to 5.0000e-02.
# Fold 0/4, Epoch 12/19, Minibatch 0/0, Phase train, Running Loss train 14.113418579101562, Time 0.29285597801208496, Overall 0.2969508171081543
# Fold 0/4, Epoch 12/19, Running Loss train 0.7056709289550781, Time 0.2929971218109131, Overall 0.297091007232666
# Fold 0/4, Epoch 12/19, Minibatch 0/0, Phase valid, Running Loss valid 30.890506744384766, Time 0.29799747467041016, Overall 0.3020923137664795
# Fold 0/4, Epoch 12/19, Running Loss valid 5.148417790730794, Time 0.29813551902770996, Overall 0.3022294044494629
# Fold 0/4, Epoch 13/19, Minibatch 0/0, Phase train, Running Loss train 18.77577018737793, Time 0.31416916847229004, Overall 0.3182647228240967
# Fold 0/4, Epoch 13/19, Running Loss train 0.9387885093688965, Time 0.31431126594543457, Overall 0.3184051513671875
# Fold 0/4, Epoch 13/19, Minibatch 0/0, Phase valid, Running Loss valid 36.75393295288086, Time 0.31932592391967773, Overall 0.32342028617858887
# Fold 0/4, Epoch 13/19, Running Loss valid 6.12565549214681, Time 0.31946563720703125, Overall 0.3235597610473633
# Fold 0/4, Epoch 14/19, Minibatch 0/0, Phase train, Running Loss train 11.035259246826172, Time 0.33812761306762695, Overall 0.3422226905822754
# Fold 0/4, Epoch 14/19, Running Loss train 0.5517629623413086, Time 0.33826732635498047, Overall 0.3423612117767334
# Fold 0/4, Epoch 14/19, Minibatch 0/0, Phase valid, Running Loss valid 33.634498596191406, Time 0.34337902069091797, Overall 0.3474738597869873
# Fold 0/4, Epoch 14/19, Running Loss valid 5.605749766031901, Time 0.34352660179138184, Overall 0.34762048721313477
# Fold 0/4, Epoch 15/19, Minibatch 0/0, Phase train, Running Loss train 21.083236694335938, Time 0.36053943634033203, Overall 0.36463475227355957
# Fold 0/4, Epoch 15/19, Running Loss train 1.054161834716797, Time 0.36068272590637207, Overall 0.3647770881652832
# Fold 0/4, Epoch 15/19, Minibatch 0/0, Phase valid, Running Loss valid 38.38726806640625, Time 0.36572790145874023, Overall 0.36982297897338867
# Fold 0/4, Epoch 15/19, Running Loss valid 6.397878011067708, Time 0.36585569381713867, Overall 0.3699495792388916
# Fold 0/4, Epoch 16/19, Minibatch 0/0, Phase train, Running Loss train 15.614261627197266, Time 0.3882107734680176, Overall 0.3923056125640869
# Fold 0/4, Epoch 16/19, Running Loss train 0.7807130813598633, Time 0.3883535861968994, Overall 0.39244723320007324
# Fold 0/4, Epoch 16/19, Minibatch 0/0, Phase valid, Running Loss valid 40.47874450683594, Time 0.3925015926361084, Overall 0.39659595489501953
# Fold 0/4, Epoch 16/19, Running Loss valid 6.746457417805989, Time 0.3926270008087158, Overall 0.39672064781188965
# Fold 0/4, Epoch 17/19, Minibatch 0/0, Phase train, Running Loss train 11.675141334533691, Time 0.40753650665283203, Overall 0.41163134574890137
# Fold 0/4, Epoch 17/19, Running Loss train 0.5837570667266846, Time 0.4076530933380127, Overall 0.4117467403411865
# Fold 0/4, Epoch 17/19, Minibatch 0/0, Phase valid, Running Loss valid 34.45796203613281, Time 0.41234683990478516, Overall 0.4164414405822754
# Fold 0/4, Epoch 17/19, Running Loss valid 5.742993672688802, Time 0.41248464584350586, Overall 0.4165785312652588
# Fold 0/4, Epoch 18/19, Minibatch 0/0, Phase train, Running Loss train 8.832579612731934, Time 0.42753005027770996, Overall 0.4316246509552002
# Fold 0/4, Epoch 18/19, Running Loss train 0.44162898063659667, Time 0.4276423454284668, Overall 0.4317359924316406
# Fold 0/4, Epoch 18/19, Minibatch 0/0, Phase valid, Running Loss valid 34.035743713378906, Time 0.4321165084838867, Overall 0.43621110916137695
# Fold 0/4, Epoch 18/19, Running Loss valid 5.672623952229817, Time 0.43224191665649414, Overall 0.43633604049682617
# Fold 0/4, Epoch 19/19, Minibatch 0/0, Phase train, Running Loss train 25.159082412719727, Time 0.44965028762817383, Overall 0.45374512672424316
# Fold 0/4, Epoch 19/19, Running Loss train 1.2579541206359863, Time 0.44979000091552734, Overall 0.45388364791870117
# Fold 0/4, Epoch 19/19, Minibatch 0/0, Phase valid, Running Loss valid 33.77218246459961, Time 0.45450901985168457, Overall 0.4586038589477539
# Fold 0/4, Epoch 19/19, Running Loss valid 5.6286970774332685, Time 0.45464515686035156, Overall 0.4587392807006836
# Fold 1/4, Epoch 0/19, Minibatch 0/0, Phase train, Running Loss train 62.89884948730469, Time 0.016277790069580078, Overall 0.47821640968322754
# Fold 1/4, Epoch 0/19, Running Loss train 2.995183308919271, Time 0.016415834426879883, Overall 0.47835254669189453
# Fold 1/4, Epoch 0/19, Minibatch 0/0, Phase valid, Running Loss valid 11.704445838928223, Time 0.020780086517333984, Overall 0.48271846771240234
# Fold 1/4, Epoch 0/19, Running Loss valid 2.3408891677856447, Time 0.020926237106323242, Overall 0.4828624725341797
# Fold 1/4, Epoch 1/19, Minibatch 0/0, Phase train, Running Loss train 51.396934509277344, Time 0.038411617279052734, Overall 0.5003492832183838
# Fold 1/4, Epoch 1/19, Running Loss train 2.4474730718703497, Time 0.03855156898498535, Overall 0.50048828125
# Fold 1/4, Epoch 1/19, Minibatch 0/0, Phase valid, Running Loss valid 11.400910377502441, Time 0.04282975196838379, Overall 0.5047667026519775
# Fold 1/4, Epoch 1/19, Running Loss valid 2.2801820755004885, Time 0.04297614097595215, Overall 0.5049128532409668
# Fold 1/4, Epoch 2/19, Minibatch 0/0, Phase train, Running Loss train 32.789268493652344, Time 0.05945301055908203, Overall 0.5213909149169922
# Fold 1/4, Epoch 2/19, Running Loss train 1.5613937377929688, Time 0.05960512161254883, Overall 0.5215415954589844
# Fold 1/4, Epoch 2/19, Minibatch 0/0, Phase valid, Running Loss valid 9.632389068603516, Time 0.06375694274902344, Overall 0.5256936550140381
# Fold 1/4, Epoch 2/19, Running Loss valid 1.926477813720703, Time 0.06389880180358887, Overall 0.5258347988128662
# Fold 1/4, Epoch 3/19, Minibatch 0/0, Phase train, Running Loss train 17.599075317382812, Time 0.08010554313659668, Overall 0.5420427322387695
# Fold 1/4, Epoch 3/19, Running Loss train 0.8380512055896577, Time 0.08023929595947266, Overall 0.54217529296875
# Fold 1/4, Epoch 3/19, Minibatch 0/0, Phase valid, Running Loss valid 12.045702934265137, Time 0.08449029922485352, Overall 0.5464272499084473
# Fold 1/4, Epoch 3/19, Running Loss valid 2.4091405868530273, Time 0.08463287353515625, Overall 0.5465700626373291
# Fold 1/4, Epoch 4/19, Minibatch 0/0, Phase train, Running Loss train 22.20928192138672, Time 0.10094690322875977, Overall 0.5628840923309326
# Fold 1/4, Epoch 4/19, Running Loss train 1.0575848533993675, Time 0.10112333297729492, Overall 0.5630598068237305
# Fold 1/4, Epoch 4/19, Minibatch 0/0, Phase valid, Running Loss valid 6.162274360656738, Time 0.10517621040344238, Overall 0.5671133995056152
# Fold 1/4, Epoch 4/19, Running Loss valid 1.2324548721313477, Time 0.10530638694763184, Overall 0.5672428607940674
# Fold 1/4, Epoch 5/19, Minibatch 0/0, Phase train, Running Loss train 31.390235900878906, Time 0.12347555160522461, Overall 0.5854134559631348
# Fold 1/4, Epoch 5/19, Running Loss train 1.4947731381370908, Time 0.12363529205322266, Overall 0.5855722427368164
# Fold 1/4, Epoch 5/19, Minibatch 0/0, Phase valid, Running Loss valid 7.986185073852539, Time 0.12810611724853516, Overall 0.5900435447692871
# Fold 1/4, Epoch 5/19, Running Loss valid 1.5972370147705077, Time 0.1282353401184082, Overall 0.5901718139648438
# Fold 1/4, Epoch 6/19, Minibatch 0/0, Phase train, Running Loss train 24.28365707397461, Time 0.14486980438232422, Overall 0.6068069934844971
# Fold 1/4, Epoch 6/19, Running Loss train 1.1563646225702195, Time 0.14500021934509277, Overall 0.6069364547729492
# Fold 1/4, Epoch 6/19, Minibatch 0/0, Phase valid, Running Loss valid 14.989298820495605, Time 0.1491556167602539, Overall 0.6110928058624268
# Fold 1/4, Epoch 6/19, Running Loss valid 2.997859764099121, Time 0.1492927074432373, Overall 0.6112287044525146
# Fold 1/4, Epoch 7/19, Minibatch 0/0, Phase train, Running Loss train 25.836502075195312, Time 0.16577529907226562, Overall 0.6277129650115967
# Fold 1/4, Epoch 7/19, Running Loss train 1.2303096226283483, Time 0.1659250259399414, Overall 0.627861499786377
# Fold 1/4, Epoch 7/19, Minibatch 0/0, Phase valid, Running Loss valid 12.855713844299316, Time 0.17022371292114258, Overall 0.6321604251861572
# Fold 1/4, Epoch 7/19, Running Loss valid 2.5711427688598634, Time 0.17035889625549316, Overall 0.6322956085205078
# Fold 1/4, Epoch 8/19, Minibatch 0/0, Phase train, Running Loss train 19.26841926574707, Time 0.1869966983795166, Overall 0.6489334106445312
# Fold 1/4, Epoch 8/19, Running Loss train 0.9175437745593843, Time 0.18712329864501953, Overall 0.6490600109100342
# Fold 1/4, Epoch 8/19, Minibatch 0/0, Phase valid, Running Loss valid 21.173856735229492, Time 0.1912069320678711, Overall 0.6531438827514648
# Fold 1/4, Epoch 8/19, Running Loss valid 4.234771347045898, Time 0.19133710861206055, Overall 0.6532738208770752
# Fold 1/4, Epoch 9/19, Minibatch 0/0, Phase train, Running Loss train 15.552143096923828, Time 0.2072892189025879, Overall 0.6692264080047607
# Fold 1/4, Epoch 9/19, Running Loss train 0.7405782427106585, Time 0.2074108123779297, Overall 0.6693470478057861
# Fold 1/4, Epoch 9/19, Minibatch 0/0, Phase valid, Running Loss valid 20.14832305908203, Time 0.21149563789367676, Overall 0.6734328269958496
# Fold 1/4, Epoch 9/19, Running Loss valid 4.029664611816406, Time 0.21165871620178223, Overall 0.6735951900482178
# Fold 1/4, Epoch 10/19, Minibatch 0/0, Phase train, Running Loss train 25.021390914916992, Time 0.23045849800109863, Overall 0.6923961639404297
# Fold 1/4, Epoch 10/19, Running Loss train 1.1914948054722376, Time 0.23059463500976562, Overall 0.6925323009490967
# Fold 1/4, Epoch 10/19, Minibatch 0/0, Phase valid, Running Loss valid 23.885204315185547, Time 0.23475885391235352, Overall 0.6966953277587891
# Fold 1/4, Epoch 10/19, Running Loss valid 4.77704086303711, Time 0.23490357398986816, Overall 0.6968402862548828
# Fold 1/4, Epoch 11/19, Minibatch 0/0, Phase train, Running Loss train 25.38947105407715, Time 0.25092196464538574, Overall 0.7128586769104004
# Fold 1/4, Epoch 11/19, Running Loss train 1.209022431146531, Time 0.25103163719177246, Overall 0.712968111038208
# Fold 1/4, Epoch 11/19, Minibatch 0/0, Phase valid, Running Loss valid 26.60730743408203, Time 0.2550077438354492, Overall 0.7169449329376221
# Fold 1/4, Epoch 11/19, Running Loss valid 5.321461486816406, Time 0.2551305294036865, Overall 0.7170665264129639
# Fold 1/4, Epoch 12/19, Minibatch 0/0, Phase train, Running Loss train 16.845849990844727, Time 0.2710392475128174, Overall 0.7329761981964111
# Fold 1/4, Epoch 12/19, Running Loss train 0.802183332897368, Time 0.27115821838378906, Overall 0.7330946922302246
# Fold 1/4, Epoch 12/19, Minibatch 0/0, Phase valid, Running Loss valid 29.94708824157715, Time 0.2751736640930176, Overall 0.7371103763580322
# Fold 1/4, Epoch 12/19, Running Loss valid 5.989417648315429, Time 0.27530360221862793, Overall 0.7372403144836426
# Fold 1/4, Epoch 13/19, Minibatch 0/0, Phase train, Running Loss train 20.71160316467285, Time 0.2918431758880615, Overall 0.7537803649902344
# Fold 1/4, Epoch 13/19, Running Loss train 0.9862668173653739, Time 0.2919652462005615, Overall 0.7539012432098389
# Fold 1/4, Epoch 13/19, Minibatch 0/0, Phase valid, Running Loss valid 31.966880798339844, Time 0.29608631134033203, Overall 0.7580235004425049
# Fold 1/4, Epoch 13/19, Running Loss valid 6.393376159667969, Time 0.2962174415588379, Overall 0.7581536769866943
# Fold 1/4, Epoch 14/19, Minibatch 0/0, Phase train, Running Loss train 16.83731460571289, Time 0.3134610652923584, Overall 0.7753984928131104
# Fold 1/4, Epoch 14/19, Running Loss train 0.8017768859863281, Time 0.31357860565185547, Overall 0.7755155563354492
# Fold 1/4, Epoch 14/19, Minibatch 0/0, Phase valid, Running Loss valid 29.739187240600586, Time 0.31763482093811035, Overall 0.7795712947845459
# Fold 1/4, Epoch 14/19, Running Loss valid 5.947837448120117, Time 0.31775355339050293, Overall 0.7796897888183594
# Fold 1/4, Epoch 15/19, Minibatch 0/0, Phase train, Running Loss train 17.817535400390625, Time 0.33371496200561523, Overall 0.7956521511077881
# Fold 1/4, Epoch 15/19, Running Loss train 0.8484540666852679, Time 0.33385300636291504, Overall 0.7957897186279297
# Fold 1/4, Epoch 15/19, Minibatch 0/0, Phase valid, Running Loss valid 30.439796447753906, Time 0.3379175662994385, Overall 0.7998545169830322
# Fold 1/4, Epoch 15/19, Running Loss valid 6.087959289550781, Time 0.33803796768188477, Overall 0.7999744415283203
# Epoch 00016: reducing learning rate of group 0 to 5.0000e-02.
# Fold 1/4, Epoch 16/19, Minibatch 0/0, Phase train, Running Loss train 19.479488372802734, Time 0.35690951347351074, Overall 0.8188467025756836
# Fold 1/4, Epoch 16/19, Running Loss train 0.9275946844191778, Time 0.3570406436920166, Overall 0.818976640701294
# Fold 1/4, Epoch 16/19, Minibatch 0/0, Phase valid, Running Loss valid 30.08045768737793, Time 0.36094117164611816, Overall 0.822878360748291
# Fold 1/4, Epoch 16/19, Running Loss valid 6.016091537475586, Time 0.36112022399902344, Overall 0.823056697845459
# Fold 1/4, Epoch 17/19, Minibatch 0/0, Phase train, Running Loss train 23.848888397216797, Time 0.3771970272064209, Overall 0.8391339778900146
# Fold 1/4, Epoch 17/19, Running Loss train 1.135661352248419, Time 0.3773157596588135, Overall 0.8392517566680908
# Fold 1/4, Epoch 17/19, Minibatch 0/0, Phase valid, Running Loss valid 28.601160049438477, Time 0.38142943382263184, Overall 0.8433666229248047
# Fold 1/4, Epoch 17/19, Running Loss valid 5.720232009887695, Time 0.3815591335296631, Overall 0.8434958457946777
# Fold 1/4, Epoch 18/19, Minibatch 0/0, Phase train, Running Loss train 10.932768821716309, Time 0.39749693870544434, Overall 0.8594341278076172
# Fold 1/4, Epoch 18/19, Running Loss train 0.520608039129348, Time 0.3976128101348877, Overall 0.859548807144165
# Fold 1/4, Epoch 18/19, Minibatch 0/0, Phase valid, Running Loss valid 32.29781723022461, Time 0.4017298221588135, Overall 0.8636670112609863
# Fold 1/4, Epoch 18/19, Running Loss valid 6.459563446044922, Time 0.4018821716308594, Overall 0.863818883895874
# Fold 1/4, Epoch 19/19, Minibatch 0/0, Phase train, Running Loss train 6.717739582061768, Time 0.41903114318847656, Overall 0.8809688091278076
# Fold 1/4, Epoch 19/19, Running Loss train 0.31989236105056035, Time 0.4191617965698242, Overall 0.8810980319976807
# Fold 1/4, Epoch 19/19, Minibatch 0/0, Phase valid, Running Loss valid 26.951889038085938, Time 0.423537015914917, Overall 0.885474443435669
# Fold 1/4, Epoch 19/19, Running Loss valid 5.390377807617187, Time 0.42368197441101074, Overall 0.8856182098388672
# Fold 2/4, Epoch 0/19, Minibatch 0/0, Phase train, Running Loss train 67.0121841430664, Time 0.014915227890014648, Overall 0.9036264419555664
# Fold 2/4, Epoch 0/19, Running Loss train 3.191056387765067, Time 0.015042543411254883, Overall 0.9037532806396484
# Fold 2/4, Epoch 0/19, Minibatch 0/0, Phase valid, Running Loss valid 12.900025367736816, Time 0.03729081153869629, Overall 0.9260015487670898
# Fold 2/4, Epoch 0/19, Running Loss valid 2.580005073547363, Time 0.03744387626647949, Overall 0.9261534214019775
# Fold 2/4, Epoch 1/19, Minibatch 0/0, Phase train, Running Loss train 64.3685302734375, Time 0.05318570137023926, Overall 0.9418954849243164
# Fold 2/4, Epoch 1/19, Running Loss train 3.0651681082589284, Time 0.053298234939575195, Overall 0.9420080184936523
# Fold 2/4, Epoch 1/19, Minibatch 0/0, Phase valid, Running Loss valid 6.960123538970947, Time 0.05734539031982422, Overall 0.9460551738739014
# Fold 2/4, Epoch 1/19, Running Loss valid 1.3920247077941894, Time 0.057463884353637695, Overall 0.9461736679077148
# Fold 2/4, Epoch 2/19, Minibatch 0/0, Phase train, Running Loss train 42.58934020996094, Time 0.07383513450622559, Overall 0.9625458717346191
# Fold 2/4, Epoch 2/19, Running Loss train 2.0280638195219494, Time 0.07398104667663574, Overall 0.9626905918121338
# Fold 2/4, Epoch 2/19, Minibatch 0/0, Phase valid, Running Loss valid 6.630851745605469, Time 0.07833456993103027, Overall 0.9670450687408447
# Fold 2/4, Epoch 2/19, Running Loss valid 1.3261703491210937, Time 0.07846522331237793, Overall 0.967174768447876
# Fold 2/4, Epoch 3/19, Minibatch 0/0, Phase train, Running Loss train 32.77325439453125, Time 0.1012105941772461, Overall 0.9899213314056396
# Fold 2/4, Epoch 3/19, Running Loss train 1.5606311616443453, Time 0.10134100914001465, Overall 0.9900505542755127
# Fold 2/4, Epoch 3/19, Minibatch 0/0, Phase valid, Running Loss valid 3.7333309650421143, Time 0.1056528091430664, Overall 0.99436354637146
# Fold 2/4, Epoch 3/19, Running Loss valid 0.7466661930084229, Time 0.10579347610473633, Overall 0.9945027828216553
# Fold 2/4, Epoch 4/19, Minibatch 0/0, Phase train, Running Loss train 31.483177185058594, Time 0.12230229377746582, Overall 1.0110125541687012
# Fold 2/4, Epoch 4/19, Running Loss train 1.4991989135742188, Time 0.1224508285522461, Overall 1.0111749172210693
# Fold 2/4, Epoch 4/19, Minibatch 0/0, Phase valid, Running Loss valid 3.6342058181762695, Time 0.1266183853149414, Overall 1.015329122543335
# Fold 2/4, Epoch 4/19, Running Loss valid 0.7268411636352539, Time 0.12674999237060547, Overall 1.0154602527618408
# Fold 2/4, Epoch 5/19, Minibatch 0/0, Phase train, Running Loss train 18.197547912597656, Time 0.14301085472106934, Overall 1.031721591949463
# Fold 2/4, Epoch 5/19, Running Loss train 0.8665499005998883, Time 0.1431596279144287, Overall 1.031869649887085
# Fold 2/4, Epoch 5/19, Minibatch 0/0, Phase valid, Running Loss valid 3.428286075592041, Time 0.14743566513061523, Overall 1.036146879196167
# Fold 2/4, Epoch 5/19, Running Loss valid 0.6856572151184082, Time 0.14757657051086426, Overall 1.0362863540649414
# Fold 2/4, Epoch 6/19, Minibatch 0/0, Phase train, Running Loss train 14.279206275939941, Time 0.1639862060546875, Overall 1.052696704864502
# Fold 2/4, Epoch 6/19, Running Loss train 0.6799622036161876, Time 0.1641836166381836, Overall 1.0528936386108398
# Fold 2/4, Epoch 6/19, Minibatch 0/0, Phase valid, Running Loss valid 7.982638835906982, Time 0.168548583984375, Overall 1.0572590827941895
# Fold 2/4, Epoch 6/19, Running Loss valid 1.5965277671813964, Time 0.1687147617340088, Overall 1.0574250221252441
# Fold 2/4, Epoch 7/19, Minibatch 0/0, Phase train, Running Loss train 16.575489044189453, Time 0.18333220481872559, Overall 1.0720431804656982
# Fold 2/4, Epoch 7/19, Running Loss train 0.7893090021042597, Time 0.1835014820098877, Overall 1.072211503982544
# Fold 2/4, Epoch 7/19, Minibatch 0/0, Phase valid, Running Loss valid 15.821167945861816, Time 0.18897032737731934, Overall 1.0776808261871338
# Fold 2/4, Epoch 7/19, Running Loss valid 3.164233589172363, Time 0.18915390968322754, Overall 1.077864170074463
# Fold 2/4, Epoch 8/19, Minibatch 0/0, Phase train, Running Loss train 35.862083435058594, Time 0.20563340187072754, Overall 1.094344139099121
# Fold 2/4, Epoch 8/19, Running Loss train 1.707718258812314, Time 0.20576238632202148, Overall 1.0944724082946777
# Fold 2/4, Epoch 8/19, Minibatch 0/0, Phase valid, Running Loss valid 18.033451080322266, Time 0.21144318580627441, Overall 1.1001536846160889
# Fold 2/4, Epoch 8/19, Running Loss valid 3.606690216064453, Time 0.21158099174499512, Overall 1.1002907752990723
# Fold 2/4, Epoch 9/19, Minibatch 0/0, Phase train, Running Loss train 36.48210525512695, Time 0.22792482376098633, Overall 1.116635799407959
# Fold 2/4, Epoch 9/19, Running Loss train 1.7372431073869978, Time 0.22808098793029785, Overall 1.1167912483215332
# Fold 2/4, Epoch 9/19, Minibatch 0/0, Phase valid, Running Loss valid 20.3493709564209, Time 0.2322688102722168, Overall 1.1209790706634521
# Fold 2/4, Epoch 9/19, Running Loss valid 4.06987419128418, Time 0.23239874839782715, Overall 1.1211082935333252
# Fold 2/4, Epoch 10/19, Minibatch 0/0, Phase train, Running Loss train 34.15285110473633, Time 0.24904274940490723, Overall 1.1377534866333008
# Fold 2/4, Epoch 10/19, Running Loss train 1.6263262430826824, Time 0.2491910457611084, Overall 1.1379013061523438
# Fold 2/4, Epoch 10/19, Minibatch 0/0, Phase valid, Running Loss valid 2.8085319995880127, Time 0.2535843849182129, Overall 1.1422948837280273
# Fold 2/4, Epoch 10/19, Running Loss valid 0.5617063999176025, Time 0.253711462020874, Overall 1.142420768737793
# Fold 2/4, Epoch 11/19, Minibatch 0/0, Phase train, Running Loss train 19.24724769592285, Time 0.27016305923461914, Overall 1.1588735580444336
# Fold 2/4, Epoch 11/19, Running Loss train 0.9165356045677548, Time 0.27028536796569824, Overall 1.1589953899383545
# Fold 2/4, Epoch 11/19, Minibatch 0/0, Phase valid, Running Loss valid 5.2179460525512695, Time 0.27488279342651367, Overall 1.1635932922363281
# Fold 2/4, Epoch 11/19, Running Loss valid 1.043589210510254, Time 0.2750129699707031, Overall 1.1637229919433594
# Fold 2/4, Epoch 12/19, Minibatch 0/0, Phase train, Running Loss train 33.7504768371582, Time 0.2919468879699707, Overall 1.1806576251983643
# Fold 2/4, Epoch 12/19, Running Loss train 1.6071655636742002, Time 0.2920875549316406, Overall 1.1807973384857178
# Fold 2/4, Epoch 12/19, Minibatch 0/0, Phase valid, Running Loss valid 6.168686389923096, Time 0.29639101028442383, Overall 1.1851017475128174
# Fold 2/4, Epoch 12/19, Running Loss valid 1.2337372779846192, Time 0.29653310775756836, Overall 1.1852433681488037
# Fold 2/4, Epoch 13/19, Minibatch 0/0, Phase train, Running Loss train 23.207921981811523, Time 0.3125908374786377, Overall 1.2013013362884521
# Fold 2/4, Epoch 13/19, Running Loss train 1.105139141991025, Time 0.31270408630371094, Overall 1.201413869857788
# Fold 2/4, Epoch 13/19, Minibatch 0/0, Phase valid, Running Loss valid 8.781145095825195, Time 0.31696128845214844, Overall 1.205672025680542
# Fold 2/4, Epoch 13/19, Running Loss valid 1.7562290191650392, Time 0.3171060085296631, Overall 1.2058155536651611
# Fold 2/4, Epoch 14/19, Minibatch 0/0, Phase train, Running Loss train 18.25078773498535, Time 0.3329293727874756, Overall 1.221639633178711
# Fold 2/4, Epoch 14/19, Running Loss train 0.8690851302373976, Time 0.33304667472839355, Overall 1.2217564582824707
# Fold 2/4, Epoch 14/19, Minibatch 0/0, Phase valid, Running Loss valid 2.2615103721618652, Time 0.33719611167907715, Overall 1.2259066104888916
# Fold 2/4, Epoch 14/19, Running Loss valid 0.452302074432373, Time 0.33732008934020996, Overall 1.226029634475708
# Fold 2/4, Epoch 15/19, Minibatch 0/0, Phase train, Running Loss train 28.77548599243164, Time 0.3533594608306885, Overall 1.242070198059082
# Fold 2/4, Epoch 15/19, Running Loss train 1.37026123773484, Time 0.3535149097442627, Overall 1.2422246932983398
# Fold 2/4, Epoch 15/19, Minibatch 0/0, Phase valid, Running Loss valid 8.8562593460083, Time 0.35761475563049316, Overall 1.2463252544403076
# Fold 2/4, Epoch 15/19, Running Loss valid 1.7712518692016601, Time 0.3577454090118408, Overall 1.246455192565918
# Fold 2/4, Epoch 16/19, Minibatch 0/0, Phase train, Running Loss train 27.104217529296875, Time 0.373584508895874, Overall 1.262294054031372
# Fold 2/4, Epoch 16/19, Running Loss train 1.2906770252046131, Time 0.3737001419067383, Overall 1.2624101638793945
# Fold 2/4, Epoch 16/19, Minibatch 0/0, Phase valid, Running Loss valid 5.100404739379883, Time 0.3778219223022461, Overall 1.2665324211120605
# Fold 2/4, Epoch 16/19, Running Loss valid 1.0200809478759765, Time 0.3779566287994385, Overall 1.2666661739349365
# Fold 2/4, Epoch 17/19, Minibatch 0/0, Phase train, Running Loss train 32.517494201660156, Time 0.3985867500305176, Overall 1.2872974872589111
# Fold 2/4, Epoch 17/19, Running Loss train 1.5484521048409599, Time 0.39879941940307617, Overall 1.2875096797943115
# Fold 2/4, Epoch 17/19, Minibatch 0/0, Phase valid, Running Loss valid 6.071877479553223, Time 0.40229082107543945, Overall 1.291001319885254
# Fold 2/4, Epoch 17/19, Running Loss valid 1.2143754959106445, Time 0.40243005752563477, Overall 1.291139841079712
# Fold 2/4, Epoch 18/19, Minibatch 0/0, Phase train, Running Loss train 22.86707305908203, Time 0.4178905487060547, Overall 1.30660080909729
# Fold 2/4, Epoch 18/19, Running Loss train 1.0889082409086681, Time 0.4180030822753906, Overall 1.3067123889923096
# Fold 2/4, Epoch 18/19, Minibatch 0/0, Phase valid, Running Loss valid 6.941075325012207, Time 0.42203664779663086, Overall 1.310746431350708
# Fold 2/4, Epoch 18/19, Running Loss valid 1.3882150650024414, Time 0.422177791595459, Overall 1.3108878135681152
# Fold 2/4, Epoch 19/19, Minibatch 0/0, Phase train, Running Loss train 19.33847427368164, Time 0.43777894973754883, Overall 1.3264896869659424
# Fold 2/4, Epoch 19/19, Running Loss train 0.9208797273181734, Time 0.43790459632873535, Overall 1.3266141414642334
# Fold 2/4, Epoch 19/19, Minibatch 0/0, Phase valid, Running Loss valid 1.7035934925079346, Time 0.44190025329589844, Overall 1.330610752105713
# Fold 2/4, Epoch 19/19, Running Loss valid 0.3407186985015869, Time 0.442018985748291, Overall 1.3307280540466309
# Fold 3/4, Epoch 0/19, Minibatch 0/0, Phase train, Running Loss train 67.87638854980469, Time 0.01731729507446289, Overall 1.350951910018921
# Fold 3/4, Epoch 0/19, Running Loss train 3.232208978562128, Time 0.01743793487548828, Overall 1.351072072982788
# Fold 3/4, Epoch 0/19, Minibatch 0/0, Phase valid, Running Loss valid 20.320114135742188, Time 0.02141857147216797, Overall 1.3550527095794678
# Fold 3/4, Epoch 0/19, Running Loss valid 4.064022827148437, Time 0.021543025970458984, Overall 1.3551771640777588
# Fold 3/4, Epoch 1/19, Minibatch 0/0, Phase train, Running Loss train 50.53109359741211, Time 0.039156436920166016, Overall 1.3727912902832031
# Fold 3/4, Epoch 1/19, Running Loss train 2.4062425522577193, Time 0.040236473083496094, Overall 1.373871088027954
# Fold 3/4, Epoch 1/19, Minibatch 0/0, Phase valid, Running Loss valid 15.164619445800781, Time 0.045419931411743164, Overall 1.3790538311004639
# Fold 3/4, Epoch 1/19, Running Loss valid 3.0329238891601564, Time 0.04554128646850586, Overall 1.3791749477386475
# Fold 3/4, Epoch 2/19, Minibatch 0/0, Phase train, Running Loss train 34.52818298339844, Time 0.06157183647155762, Overall 1.3952064514160156
# Fold 3/4, Epoch 2/19, Running Loss train 1.6441991896856398, Time 0.06169772148132324, Overall 1.3953313827514648
# Fold 3/4, Epoch 2/19, Minibatch 0/0, Phase valid, Running Loss valid 16.593807220458984, Time 0.06580018997192383, Overall 1.3994345664978027
# Fold 3/4, Epoch 2/19, Running Loss valid 3.318761444091797, Time 0.06593036651611328, Overall 1.399564266204834
# Fold 3/4, Epoch 3/19, Minibatch 0/0, Phase train, Running Loss train 28.82463836669922, Time 0.0812523365020752, Overall 1.414886236190796
# Fold 3/4, Epoch 3/19, Running Loss train 1.372601826985677, Time 0.0813591480255127, Overall 1.4149928092956543
# Fold 3/4, Epoch 3/19, Minibatch 0/0, Phase valid, Running Loss valid 21.980443954467773, Time 0.08523917198181152, Overall 1.4188728332519531
# Fold 3/4, Epoch 3/19, Running Loss valid 4.396088790893555, Time 0.08534812927246094, Overall 1.4189817905426025
# Fold 3/4, Epoch 4/19, Minibatch 0/0, Phase train, Running Loss train 26.640588760375977, Time 0.10136723518371582, Overall 1.4350011348724365
# Fold 3/4, Epoch 4/19, Running Loss train 1.2685994647798085, Time 0.10148167610168457, Overall 1.435114860534668
# Fold 3/4, Epoch 4/19, Minibatch 0/0, Phase valid, Running Loss valid 23.140783309936523, Time 0.10553979873657227, Overall 1.4391741752624512
# Fold 3/4, Epoch 4/19, Running Loss valid 4.628156661987305, Time 0.10566306114196777, Overall 1.4392971992492676
# Fold 3/4, Epoch 5/19, Minibatch 0/0, Phase train, Running Loss train 12.317014694213867, Time 0.1213693618774414, Overall 1.4550034999847412
# Fold 3/4, Epoch 5/19, Running Loss train 0.5865245092482794, Time 0.1214745044708252, Overall 1.4551076889038086
# Fold 3/4, Epoch 5/19, Minibatch 0/0, Phase valid, Running Loss valid 41.924041748046875, Time 0.12526321411132812, Overall 1.458897352218628
# Fold 3/4, Epoch 5/19, Running Loss valid 8.384808349609376, Time 0.12537074089050293, Overall 1.4590041637420654
# Fold 3/4, Epoch 6/19, Minibatch 0/0, Phase train, Running Loss train 20.624347686767578, Time 0.14078545570373535, Overall 1.474419355392456
# Fold 3/4, Epoch 6/19, Running Loss train 0.9821117946079799, Time 0.14090347290039062, Overall 1.4745373725891113
# Fold 3/4, Epoch 6/19, Minibatch 0/0, Phase valid, Running Loss valid 33.35353088378906, Time 0.1466841697692871, Overall 1.4803187847137451
# Fold 3/4, Epoch 6/19, Running Loss valid 6.670706176757813, Time 0.14926505088806152, Overall 1.4828994274139404
# Fold 3/4, Epoch 7/19, Minibatch 0/0, Phase train, Running Loss train 19.836772918701172, Time 0.16666913032531738, Overall 1.5003035068511963
# Fold 3/4, Epoch 7/19, Running Loss train 0.9446082342238653, Time 0.1667804718017578, Overall 1.5004143714904785
# Fold 3/4, Epoch 7/19, Minibatch 0/0, Phase valid, Running Loss valid 51.578956604003906, Time 0.1706552505493164, Overall 1.5042893886566162
# Fold 3/4, Epoch 7/19, Running Loss valid 10.31579132080078, Time 0.17077970504760742, Overall 1.5044136047363281
# Fold 3/4, Epoch 8/19, Minibatch 0/0, Phase train, Running Loss train 14.64824390411377, Time 0.1875319480895996, Overall 1.5211665630340576
# Fold 3/4, Epoch 8/19, Running Loss train 0.6975354240054176, Time 0.18764591217041016, Overall 1.5212795734405518
# Fold 3/4, Epoch 8/19, Minibatch 0/0, Phase valid, Running Loss valid 38.29242706298828, Time 0.19189000129699707, Overall 1.5255248546600342
# Fold 3/4, Epoch 8/19, Running Loss valid 7.658485412597656, Time 0.19202136993408203, Overall 1.525655746459961
# Fold 3/4, Epoch 9/19, Minibatch 0/0, Phase train, Running Loss train 16.29279899597168, Time 0.20899415016174316, Overall 1.5426294803619385
# Fold 3/4, Epoch 9/19, Running Loss train 0.7758475712367466, Time 0.2091214656829834, Overall 1.542754888534546
# Fold 3/4, Epoch 9/19, Minibatch 0/0, Phase valid, Running Loss valid 47.07456588745117, Time 0.2136077880859375, Overall 1.5472428798675537
# Fold 3/4, Epoch 9/19, Running Loss valid 9.414913177490234, Time 0.21374297142028809, Overall 1.547377586364746
# Fold 3/4, Epoch 10/19, Minibatch 0/0, Phase train, Running Loss train 14.519548416137695, Time 0.2299790382385254, Overall 1.5636138916015625
# Fold 3/4, Epoch 10/19, Running Loss train 0.6914070674351284, Time 0.23010945320129395, Overall 1.5637433528900146
# Fold 3/4, Epoch 10/19, Minibatch 0/0, Phase valid, Running Loss valid 64.30027770996094, Time 0.23445463180541992, Overall 1.568089246749878
# Fold 3/4, Epoch 10/19, Running Loss valid 12.860055541992187, Time 0.23458552360534668, Overall 1.5682199001312256
# Fold 3/4, Epoch 11/19, Minibatch 0/0, Phase train, Running Loss train 11.734477996826172, Time 0.2557106018066406, Overall 1.589346170425415
# Fold 3/4, Epoch 11/19, Running Loss train 0.558784666515532, Time 0.2558400630950928, Overall 1.5894737243652344
# Fold 3/4, Epoch 11/19, Minibatch 0/0, Phase valid, Running Loss valid 72.63427734375, Time 0.25998735427856445, Overall 1.5936214923858643
# Fold 3/4, Epoch 11/19, Running Loss valid 14.52685546875, Time 0.26013708114624023, Overall 1.593770980834961
# Fold 3/4, Epoch 12/19, Minibatch 0/0, Phase train, Running Loss train 16.287330627441406, Time 0.2758619785308838, Overall 1.6094963550567627
# Fold 3/4, Epoch 12/19, Running Loss train 0.7755871727353051, Time 0.27597737312316895, Overall 1.6096115112304688
# Fold 3/4, Epoch 12/19, Minibatch 0/0, Phase valid, Running Loss valid 76.4717788696289, Time 0.2799875736236572, Overall 1.6136219501495361
# Fold 3/4, Epoch 12/19, Running Loss valid 15.294355773925782, Time 0.28011202812194824, Overall 1.613745927810669
# Epoch 00013: reducing learning rate of group 0 to 5.0000e-02.
# Fold 3/4, Epoch 13/19, Minibatch 0/0, Phase train, Running Loss train 8.214170455932617, Time 0.2959256172180176, Overall 1.6295602321624756
# Fold 3/4, Epoch 13/19, Running Loss train 0.39115097409202937, Time 0.2960360050201416, Overall 1.629669189453125
# Fold 3/4, Epoch 13/19, Minibatch 0/0, Phase valid, Running Loss valid 76.00479888916016, Time 0.2998223304748535, Overall 1.6334567070007324
# Fold 3/4, Epoch 13/19, Running Loss valid 15.200959777832031, Time 0.29995179176330566, Overall 1.6335852146148682
# Fold 3/4, Epoch 14/19, Minibatch 0/0, Phase train, Running Loss train 19.75815200805664, Time 0.31542158126831055, Overall 1.6490559577941895
# Fold 3/4, Epoch 14/19, Running Loss train 0.9408643813360305, Time 0.31552743911743164, Overall 1.6491611003875732
# Fold 3/4, Epoch 14/19, Minibatch 0/0, Phase valid, Running Loss valid 79.45247650146484, Time 0.319227933883667, Overall 1.6528618335723877
# Fold 3/4, Epoch 14/19, Running Loss valid 15.890495300292969, Time 0.3193626403808594, Overall 1.652996301651001
# Fold 3/4, Epoch 15/19, Minibatch 0/0, Phase train, Running Loss train 4.506253242492676, Time 0.33455967903137207, Overall 1.6681947708129883
# Fold 3/4, Epoch 15/19, Running Loss train 0.21458348773774646, Time 0.33467769622802734, Overall 1.668311595916748
# Fold 3/4, Epoch 15/19, Minibatch 0/0, Phase valid, Running Loss valid 99.70198059082031, Time 0.33830809593200684, Overall 1.6719419956207275
# Fold 3/4, Epoch 15/19, Running Loss valid 19.940396118164063, Time 0.3384280204772949, Overall 1.6721596717834473
# Fold 3/4, Epoch 16/19, Minibatch 0/0, Phase train, Running Loss train 8.886896133422852, Time 0.3544917106628418, Overall 1.6881263256072998
# Fold 3/4, Epoch 16/19, Running Loss train 0.42318553016299293, Time 0.35460948944091797, Overall 1.6882431507110596
# Fold 3/4, Epoch 16/19, Minibatch 0/0, Phase valid, Running Loss valid 114.34217834472656, Time 0.35840725898742676, Overall 1.6920416355133057
# Fold 3/4, Epoch 16/19, Running Loss valid 22.868435668945313, Time 0.35851573944091797, Overall 1.6921494007110596
# Fold 3/4, Epoch 17/19, Minibatch 0/0, Phase train, Running Loss train 8.537256240844727, Time 0.373307466506958, Overall 1.706941843032837
# Fold 3/4, Epoch 17/19, Running Loss train 0.4065360114687965, Time 0.37341856956481934, Overall 1.707052230834961
# Fold 3/4, Epoch 17/19, Minibatch 0/0, Phase valid, Running Loss valid 101.61919403076172, Time 0.3772909641265869, Overall 1.7109248638153076
# Fold 3/4, Epoch 17/19, Running Loss valid 20.323838806152345, Time 0.37741589546203613, Overall 1.7110493183135986
# Fold 3/4, Epoch 18/19, Minibatch 0/0, Phase train, Running Loss train 5.183207988739014, Time 0.39163899421691895, Overall 1.7252733707427979
# Fold 3/4, Epoch 18/19, Running Loss train 0.24681942803519114, Time 0.39174437522888184, Overall 1.7253780364990234
# Fold 3/4, Epoch 18/19, Minibatch 0/0, Phase valid, Running Loss valid 81.25391387939453, Time 0.3955256938934326, Overall 1.7291595935821533
# Fold 3/4, Epoch 18/19, Running Loss valid 16.250782775878907, Time 0.39563894271850586, Overall 1.7292726039886475
# Fold 3/4, Epoch 19/19, Minibatch 0/0, Phase train, Running Loss train 16.77395248413086, Time 0.4103424549102783, Overall 1.7439773082733154
# Fold 3/4, Epoch 19/19, Running Loss train 0.7987596421014695, Time 0.4104642868041992, Overall 1.74409818649292
# Fold 3/4, Epoch 19/19, Minibatch 0/0, Phase valid, Running Loss valid 100.36331939697266, Time 0.4150044918060303, Overall 1.7486388683319092
# Fold 3/4, Epoch 19/19, Running Loss valid 20.072663879394533, Time 0.4151465892791748, Overall 1.7487976551055908
# Fold 4/4, Epoch 0/19, Minibatch 0/0, Phase train, Running Loss train 65.69478607177734, Time 0.014950037002563477, Overall 1.7666981220245361
# Fold 4/4, Epoch 0/19, Running Loss train 3.1283231462751115, Time 0.015103340148925781, Overall 1.7668497562408447
# Fold 4/4, Epoch 0/19, Minibatch 0/0, Phase valid, Running Loss valid 17.102703094482422, Time 0.01941537857055664, Overall 1.7711622714996338
# Fold 4/4, Epoch 0/19, Running Loss valid 3.420540618896484, Time 0.019554615020751953, Overall 1.77130126953125
# Fold 4/4, Epoch 1/19, Minibatch 0/0, Phase train, Running Loss train 50.872047424316406, Time 0.0369720458984375, Overall 1.7887194156646729
# Fold 4/4, Epoch 1/19, Running Loss train 2.422478448776972, Time 0.037138938903808594, Overall 1.7888853549957275
# Fold 4/4, Epoch 1/19, Minibatch 0/0, Phase valid, Running Loss valid 13.65554141998291, Time 0.041292428970336914, Overall 1.793039321899414
# Fold 4/4, Epoch 1/19, Running Loss valid 2.731108283996582, Time 0.04150247573852539, Overall 1.7932491302490234
# Fold 4/4, Epoch 2/19, Minibatch 0/0, Phase train, Running Loss train 38.99824523925781, Time 0.05672740936279297, Overall 1.8084747791290283
# Fold 4/4, Epoch 2/19, Running Loss train 1.8570592971075148, Time 0.0568547248840332, Overall 1.808600902557373
# Fold 4/4, Epoch 2/19, Minibatch 0/0, Phase valid, Running Loss valid 13.229655265808105, Time 0.060800790786743164, Overall 1.8125474452972412
# Fold 4/4, Epoch 2/19, Running Loss valid 2.645931053161621, Time 0.06093764305114746, Overall 1.812683343887329
# Fold 4/4, Epoch 3/19, Minibatch 0/0, Phase train, Running Loss train 34.05793762207031, Time 0.07741904258728027, Overall 1.8291661739349365
# Fold 4/4, Epoch 3/19, Running Loss train 1.6218065534319197, Time 0.07755303382873535, Overall 1.829298973083496
# Fold 4/4, Epoch 3/19, Minibatch 0/0, Phase valid, Running Loss valid 16.238861083984375, Time 0.08171629905700684, Overall 1.8334624767303467
# Fold 4/4, Epoch 3/19, Running Loss valid 3.247772216796875, Time 0.0818338394165039, Overall 1.8335800170898438
# Fold 4/4, Epoch 4/19, Minibatch 0/0, Phase train, Running Loss train 25.692148208618164, Time 0.09806418418884277, Overall 1.849811315536499
# Fold 4/4, Epoch 4/19, Running Loss train 1.2234356289818173, Time 0.09819698333740234, Overall 1.8499433994293213
# Fold 4/4, Epoch 4/19, Minibatch 0/0, Phase valid, Running Loss valid 20.763479232788086, Time 0.10240030288696289, Overall 1.854146957397461
# Fold 4/4, Epoch 4/19, Running Loss valid 4.152695846557617, Time 0.1025245189666748, Overall 1.8542704582214355
# Fold 4/4, Epoch 5/19, Minibatch 0/0, Phase train, Running Loss train 24.96883201599121, Time 0.11858916282653809, Overall 1.8703360557556152
# Fold 4/4, Epoch 5/19, Running Loss train 1.1889920007614863, Time 0.11872339248657227, Overall 1.8704700469970703
# Fold 4/4, Epoch 5/19, Minibatch 0/0, Phase valid, Running Loss valid 27.65744972229004, Time 0.12295389175415039, Overall 1.8747007846832275
# Fold 4/4, Epoch 5/19, Running Loss valid 5.5314899444580075, Time 0.12310099601745605, Overall 1.8748481273651123
# Fold 4/4, Epoch 6/19, Minibatch 0/0, Phase train, Running Loss train 39.857261657714844, Time 0.1443166732788086, Overall 1.8960635662078857
# Fold 4/4, Epoch 6/19, Running Loss train 1.897964840843564, Time 0.1444706916809082, Overall 1.896216869354248
# Fold 4/4, Epoch 6/19, Minibatch 0/0, Phase valid, Running Loss valid 31.511104583740234, Time 0.1486344337463379, Overall 1.900381088256836
# Fold 4/4, Epoch 6/19, Running Loss valid 6.3022209167480465, Time 0.14896559715270996, Overall 1.900712013244629
# Fold 4/4, Epoch 7/19, Minibatch 0/0, Phase train, Running Loss train 25.28790283203125, Time 0.16809439659118652, Overall 1.9198410511016846
# Fold 4/4, Epoch 7/19, Running Loss train 1.2041858491443453, Time 0.1682736873626709, Overall 1.9200201034545898
# Fold 4/4, Epoch 7/19, Minibatch 0/0, Phase valid, Running Loss valid 29.65654945373535, Time 0.17253661155700684, Overall 1.924283742904663
# Fold 4/4, Epoch 7/19, Running Loss valid 5.9313098907470705, Time 0.17286014556884766, Overall 1.924607276916504
# Fold 4/4, Epoch 8/19, Minibatch 0/0, Phase train, Running Loss train 28.05084228515625, Time 0.18799805641174316, Overall 1.9397451877593994
# Fold 4/4, Epoch 8/19, Running Loss train 1.33575439453125, Time 0.18814659118652344, Overall 1.939892292022705
# Fold 4/4, Epoch 8/19, Minibatch 0/0, Phase valid, Running Loss valid 35.61595153808594, Time 0.19242215156555176, Overall 1.9441814422607422
# Fold 4/4, Epoch 8/19, Running Loss valid 7.123190307617188, Time 0.19256377220153809, Overall 1.944309949874878
# Fold 4/4, Epoch 9/19, Minibatch 0/0, Phase train, Running Loss train 32.6871452331543, Time 0.20849204063415527, Overall 1.9602386951446533
# Fold 4/4, Epoch 9/19, Running Loss train 1.5565307253882998, Time 0.20861506462097168, Overall 1.9603610038757324
# Fold 4/4, Epoch 9/19, Minibatch 0/0, Phase valid, Running Loss valid 38.44313049316406, Time 0.21268033981323242, Overall 1.9644269943237305
# Fold 4/4, Epoch 9/19, Running Loss valid 7.688626098632812, Time 0.21280694007873535, Overall 1.9645533561706543
# Fold 4/4, Epoch 10/19, Minibatch 0/0, Phase train, Running Loss train 20.750194549560547, Time 0.22958874702453613, Overall 1.9813358783721924
# Fold 4/4, Epoch 10/19, Running Loss train 0.988104502360026, Time 0.22970890998840332, Overall 1.9814550876617432
# Fold 4/4, Epoch 10/19, Minibatch 0/0, Phase valid, Running Loss valid 40.615089416503906, Time 0.23374104499816895, Overall 1.985487937927246
# ...
# Fold 4/4, Epoch 5/19, Running Loss valid 15.723435974121093, Time 0.11623191833496094, Overall 2.7688775062561035
# Fold 4/4, Epoch 6/19, Minibatch 0/0, Phase train, Running Loss train 281.26922607421875, Time 0.13875460624694824, Overall 2.79140043258667
# Fold 4/4, Epoch 6/19, Running Loss train 13.393772670200892, Time 0.13887500762939453, Overall 2.7915196418762207
# Fold 4/4, Epoch 6/19, Minibatch 0/0, Phase valid, Running Loss valid 102.33460235595703, Time 0.1440291404724121, Overall 2.7966744899749756
# Fold 4/4, Epoch 6/19, Running Loss valid 20.466920471191408, Time 0.14415335655212402, Overall 2.796797752380371
# Fold 4/4, Epoch 7/19, Minibatch 0/0, Phase train, Running Loss train 304.8406066894531, Time 0.15809106826782227, Overall 2.8107361793518066
# Fold 4/4, Epoch 7/19, Running Loss train 14.516219366164435, Time 0.15820574760437012, Overall 2.8108503818511963
# Fold 4/4, Epoch 7/19, Minibatch 0/0, Phase valid, Running Loss valid 116.80184936523438, Time 0.16351008415222168, Overall 2.8161559104919434
# Fold 4/4, Epoch 7/19, Running Loss valid 23.360369873046874, Time 0.16362309455871582, Overall 2.816267967224121
# Fold 4/4, Epoch 8/19, Minibatch 0/0, Phase train, Running Loss train 218.84918212890625, Time 0.1777958869934082, Overall 2.8304412364959717
# Fold 4/4, Epoch 8/19, Running Loss train 10.421389625186013, Time 0.17789363861083984, Overall 2.830538511276245
# Fold 4/4, Epoch 8/19, Minibatch 0/0, Phase valid, Running Loss valid 84.73246765136719, Time 0.18301868438720703, Overall 2.8356642723083496
# Fold 4/4, Epoch 8/19, Running Loss valid 16.946493530273436, Time 0.18316340446472168, Overall 2.835808515548706
# Fold 4/4, Epoch 9/19, Minibatch 0/0, Phase train, Running Loss train 311.3430480957031, Time 0.19709348678588867, Overall 2.849738597869873
# Fold 4/4, Epoch 9/19, Running Loss train 14.82585943312872, Time 0.19719767570495605, Overall 2.8498423099517822
# Fold 4/4, Epoch 9/19, Minibatch 0/0, Phase valid, Running Loss valid 63.94920349121094, Time 0.20232486724853516, Overall 2.8549699783325195
# Fold 4/4, Epoch 9/19, Running Loss valid 12.789840698242188, Time 0.20244550704956055, Overall 2.855090379714966
# Fold 4/4, Epoch 10/19, Minibatch 0/0, Phase train, Running Loss train 182.5721435546875, Time 0.2171034812927246, Overall 2.869748592376709
# Fold 4/4, Epoch 10/19, Running Loss train 8.693911597842263, Time 0.21720647811889648, Overall 2.8698513507843018
# Fold 4/4, Epoch 10/19, Minibatch 0/0, Phase valid, Running Loss valid 84.10595703125, Time 0.22233295440673828, Overall 2.8749780654907227
# Fold 4/4, Epoch 10/19, Running Loss valid 16.82119140625, Time 0.22245526313781738, Overall 2.8751003742218018
# Fold 4/4, Epoch 11/19, Minibatch 0/0, Phase train, Running Loss train 269.44464111328125, Time 0.23626923561096191, Overall 2.8889145851135254
# Fold 4/4, Epoch 11/19, Running Loss train 12.830697195870536, Time 0.23636507987976074, Overall 2.889009714126587
# Fold 4/4, Epoch 11/19, Minibatch 0/0, Phase valid, Running Loss valid 94.4412841796875, Time 0.2415001392364502, Overall 2.8941454887390137
# Fold 4/4, Epoch 11/19, Running Loss valid 18.8882568359375, Time 0.24161052703857422, Overall 2.8942551612854004
# Fold 4/4, Epoch 12/19, Minibatch 0/0, Phase train, Running Loss train 250.40087890625, Time 0.2554666996002197, Overall 2.9081122875213623
# Fold 4/4, Epoch 12/19, Running Loss train 11.923851376488095, Time 0.2555665969848633, Overall 2.9082114696502686
# Fold 4/4, Epoch 12/19, Minibatch 0/0, Phase valid, Running Loss valid 109.69734954833984, Time 0.2607452869415283, Overall 2.9133903980255127
# Fold 4/4, Epoch 12/19, Running Loss valid 21.93946990966797, Time 0.2608613967895508, Overall 2.913506031036377
# Fold 4/4, Epoch 13/19, Minibatch 0/0, Phase train, Running Loss train 136.77487182617188, Time 0.2755320072174072, Overall 2.92817759513855
# Fold 4/4, Epoch 13/19, Running Loss train 6.513089134579613, Time 0.2756350040435791, Overall 2.9282796382904053
# Fold 4/4, Epoch 13/19, Minibatch 0/0, Phase valid, Running Loss valid 84.2767105102539, Time 0.28108906745910645, Overall 2.933734655380249
# Fold 4/4, Epoch 13/19, Running Loss valid 16.85534210205078, Time 0.2812080383300781, Overall 2.9338529109954834
# Epoch 00014: reducing learning rate of group 0 to 5.0000e-02.
# Fold 4/4, Epoch 14/19, Minibatch 0/0, Phase train, Running Loss train 286.5164794921875, Time 0.2956721782684326, Overall 2.948317289352417
# Fold 4/4, Epoch 14/19, Running Loss train 13.643641880580358, Time 0.2957925796508789, Overall 2.948437452316284
# Fold 4/4, Epoch 14/19, Minibatch 0/0, Phase valid, Running Loss valid 64.07288360595703, Time 0.3011133670806885, Overall 2.953758716583252
# Fold 4/4, Epoch 14/19, Running Loss valid 12.814576721191406, Time 0.3012392520904541, Overall 2.9538838863372803
# Fold 4/4, Epoch 15/19, Minibatch 0/0, Phase train, Running Loss train 200.6886749267578, Time 0.31529879570007324, Overall 2.9679441452026367
# Fold 4/4, Epoch 15/19, Running Loss train 9.556603567940849, Time 0.3154001235961914, Overall 2.9680447578430176
# Fold 4/4, Epoch 15/19, Minibatch 0/0, Phase valid, Running Loss valid 68.1082534790039, Time 0.32121729850769043, Overall 2.973862648010254
# Fold 4/4, Epoch 15/19, Running Loss valid 13.621650695800781, Time 0.32134461402893066, Overall 2.973989248275757
# Fold 4/4, Epoch 16/19, Minibatch 0/0, Phase train, Running Loss train 211.82745361328125, Time 0.3355753421783447, Overall 2.98822021484375
# Fold 4/4, Epoch 16/19, Running Loss train 10.08702160063244, Time 0.3357052803039551, Overall 2.9883501529693604
# Fold 4/4, Epoch 16/19, Minibatch 0/0, Phase valid, Running Loss valid 64.29167175292969, Time 0.34104061126708984, Overall 2.9936859607696533
# Fold 4/4, Epoch 16/19, Running Loss valid 12.858334350585938, Time 0.341170072555542, Overall 2.993814706802368
# Fold 4/4, Epoch 17/19, Minibatch 0/0, Phase train, Running Loss train 211.84683227539062, Time 0.3553049564361572, Overall 3.0079503059387207
# Fold 4/4, Epoch 17/19, Running Loss train 10.08794439406622, Time 0.3554372787475586, Overall 3.008082389831543
# Fold 4/4, Epoch 17/19, Minibatch 0/0, Phase valid, Running Loss valid 110.48436737060547, Time 0.361663818359375, Overall 3.0143091678619385
# Fold 4/4, Epoch 17/19, Running Loss valid 22.096873474121093, Time 0.3618357181549072, Overall 3.014482021331787
# Fold 4/4, Epoch 18/19, Minibatch 0/0, Phase train, Running Loss train 216.23460388183594, Time 0.378741979598999, Overall 3.0313875675201416
# Fold 4/4, Epoch 18/19, Running Loss train 10.296885899135045, Time 0.37887120246887207, Overall 3.0315158367156982
# Fold 4/4, Epoch 18/19, Minibatch 0/0, Phase valid, Running Loss valid 83.25033569335938, Time 0.38559389114379883, Overall 3.0382392406463623
# Fold 4/4, Epoch 18/19, Running Loss valid 16.650067138671876, Time 0.38571619987487793, Overall 3.038360834121704
# Fold 4/4, Epoch 19/19, Minibatch 0/0, Phase train, Running Loss train 189.91323852539062, Time 0.3992147445678711, Overall 3.0518598556518555
# Fold 4/4, Epoch 19/19, Running Loss train 9.043487548828125, Time 0.39931273460388184, Overall 3.051957130432129
# Fold 4/4, Epoch 19/19, Minibatch 0/0, Phase valid, Running Loss valid 81.71934509277344, Time 0.4044933319091797, Overall 3.057138442993164
# Fold 4/4, Epoch 19/19, Running Loss valid 16.343869018554688, Time 0.4045987129211426, Overall 3.057243585586548
# It took 3.0587947368621826 to train the model.
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Building pytrec_eval input for 5 instances ...
# Evaluating {'P_2,5,10', 'ndcg_cut_2,5,10', 'map_cut_2,5,10', 'recall_2,5,10'} ...
# Averaging ...
# Building pytrec_eval input for 5 instances ...
# Evaluating {'P_2,5,10', 'ndcg_cut_2,5,10', 'map_cut_2,5,10', 'recall_2,5,10'} ...
# Averaging ...
# Building pytrec_eval input for 5 instances ...
# Evaluating {'P_2,5,10', 'ndcg_cut_2,5,10', 'map_cut_2,5,10', 'recall_2,5,10'} ...
# Averaging ...
# Building pytrec_eval input for 5 instances ...
# Evaluating {'P_2,5,10', 'ndcg_cut_2,5,10', 'map_cut_2,5,10', 'recall_2,5,10'} ...
# Averaging ...
# Building pytrec_eval input for 5 instances ...
# Evaluating {'P_2,5,10', 'ndcg_cut_2,5,10', 'map_cut_2,5,10', 'recall_2,5,10'} ...
# Averaging ...
# ####################################################################################################
# Reranking for the baseline ../output/toy.dblp.v12.json/bnn/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/f1.test.pred ...
# Loading attribute labels ...
# Loading attribute labels failed! Generating popularity labels at ../output/toy.dblp.v12.json/bnn/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/rerank/stats.pkl ...
# Loading reranking results ...
# Loading re-ranking results failed! Reranking the predictions based on det_greedy for top-None ...
# 100% 5/5 [00:00<00:00, 129.71it/s]
# 100% 5/5 [00:00<00:00, 81284.96it/s]
# Loading fairness evaluation results before and after reranking ...
# Loading fairness results failed! Evaluating fairness metric {'ndkl'} ...
# 100% 5/5 [00:00<00:00, 7592.87it/s]
# Loading utility metric evaluation results before and after reranking ...
#  Loading utility metric results failed! Evaluating utility metric {'map_cut_2,5,10'} ...
# Building pytrec_eval input for 5 instances ...
# Evaluating {'map_cut_2,5,10'} ...
# Averaging ...
# Pipeline for the baseline ../output/toy.dblp.v12.json/bnn/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/f1.test.pred completed by <_MainProcess name='MainProcess' parent=None started>! 0.05859541893005371
# ####################################################################################################
# ####################################################################################################
# Reranking for the baseline ../output/toy.dblp.v12.json/bnn/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/f3.test.pred ...
# Loading attribute labels ...
# Loading attribute labels failed! Generating popularity labels at ../output/toy.dblp.v12.json/bnn/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/rerank/stats.pkl ...
# Loading reranking results ...
# Loading re-ranking results failed! Reranking the predictions based on det_greedy for top-None ...
# 100% 5/5 [00:00<00:00, 148.42it/s]
# 100% 5/5 [00:00<00:00, 77385.68it/s]
# Loading fairness evaluation results before and after reranking ...
# Loading fairness results failed! Evaluating fairness metric {'ndkl'} ...
# 100% 5/5 [00:00<00:00, 7989.15it/s]
# Loading utility metric evaluation results before and after reranking ...
#  Loading utility metric results failed! Evaluating utility metric {'map_cut_2,5,10'} ...
# Building pytrec_eval input for 5 instances ...
# Evaluating {'map_cut_2,5,10'} ...
# Averaging ...
# Pipeline for the baseline ../output/toy.dblp.v12.json/bnn/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/f3.test.pred completed by <_MainProcess name='MainProcess' parent=None started>! 0.05463123321533203
# ####################################################################################################
# ####################################################################################################
# Reranking for the baseline ../output/toy.dblp.v12.json/bnn/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/f0.test.pred ...
# Loading attribute labels ...
# Loading attribute labels failed! Generating popularity labels at ../output/toy.dblp.v12.json/bnn/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/rerank/stats.pkl ...
# Loading reranking results ...
# Loading re-ranking results failed! Reranking the predictions based on det_greedy for top-None ...
# 100% 5/5 [00:00<00:00, 137.24it/s]
# 100% 5/5 [00:00<00:00, 83220.32it/s]
# Loading fairness evaluation results before and after reranking ...
# Loading fairness results failed! Evaluating fairness metric {'ndkl'} ...
# 100% 5/5 [00:00<00:00, 7481.81it/s]
# Loading utility metric evaluation results before and after reranking ...
#  Loading utility metric results failed! Evaluating utility metric {'map_cut_2,5,10'} ...
# Building pytrec_eval input for 5 instances ...
# Evaluating {'map_cut_2,5,10'} ...
# Averaging ...
# Pipeline for the baseline ../output/toy.dblp.v12.json/bnn/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/f0.test.pred completed by <_MainProcess name='MainProcess' parent=None started>! 0.057726383209228516
# ####################################################################################################
# ####################################################################################################
# Reranking for the baseline ../output/toy.dblp.v12.json/bnn/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/f4.test.pred ...
# Loading attribute labels ...
# Loading attribute labels failed! Generating popularity labels at ../output/toy.dblp.v12.json/bnn/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/rerank/stats.pkl ...
# Loading reranking results ...
# Loading re-ranking results failed! Reranking the predictions based on det_greedy for top-None ...
# 100% 5/5 [00:00<00:00, 121.14it/s]
# 100% 5/5 [00:00<00:00, 59747.92it/s]
# Loading fairness evaluation results before and after reranking ...
# Loading fairness results failed! Evaluating fairness metric {'ndkl'} ...
# 100% 5/5 [00:00<00:00, 4657.23it/s]
# Loading utility metric evaluation results before and after reranking ...
#  Loading utility metric results failed! Evaluating utility metric {'map_cut_2,5,10'} ...
# Building pytrec_eval input for 5 instances ...
# Evaluating {'map_cut_2,5,10'} ...
# Averaging ...
# Pipeline for the baseline ../output/toy.dblp.v12.json/bnn/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/f4.test.pred completed by <_MainProcess name='MainProcess' parent=None started>! 0.06519198417663574
# ####################################################################################################
# ####################################################################################################
# Reranking for the baseline ../output/toy.dblp.v12.json/bnn/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/f2.test.pred ...
# Loading attribute labels ...
# Loading attribute labels failed! Generating popularity labels at ../output/toy.dblp.v12.json/bnn/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/rerank/stats.pkl ...
# Loading reranking results ...
# Loading re-ranking results failed! Reranking the predictions based on det_greedy for top-None ...
# 100% 5/5 [00:00<00:00, 142.20it/s]
# 100% 5/5 [00:00<00:00, 97541.95it/s]
# Loading fairness evaluation results before and after reranking ...
# Loading fairness results failed! Evaluating fairness metric {'ndkl'} ...
# 100% 5/5 [00:00<00:00, 7839.82it/s]
# Loading utility metric evaluation results before and after reranking ...
#  Loading utility metric results failed! Evaluating utility metric {'map_cut_2,5,10'} ...
# Building pytrec_eval input for 5 instances ...
# Evaluating {'map_cut_2,5,10'} ...
# Averaging ...
# Pipeline for the baseline ../output/toy.dblp.v12.json/bnn/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/t31.s10.m13.l[128].lr0.1.b128.e20.nns3.nsunigram_b.s1/f2.test.pred completed by <_MainProcess name='MainProcess' parent=None started>! 0.05569291114807129
# ####################################################################################################

# %%
# !ls ../output/toy.dblp.v12.json/
# Out:
# bnn  fnn
